# %%
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
import winsound
import calendar
import datetime
import time
import re
import os

# %%
name = "m_enginering2.txt"
with open(name, "r") as f:
    line = f.read().strip() 
    downloaded = int(line)
    cur_downloaded = 0

# %%
def startdownload(download_dir, url, name):
    global cur_downloaded, downloaded
    with open(name, "r") as f:
        line = f.read().strip() 
        downloaded = int(line)
        cur_downloaded = 0
    print(cur_downloaded, downloaded)
    # download_dir = r"D:\zhiwangpdf\0715"
    edge_options = Options()
    prefs = {
        "download.default_directory": download_dir,
        "profile.default_content_settings.popups": 0,
        "directory_upgrade": True
    }
    User_Agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'
    edge_options.add_argument(f"user-agent={User_Agent}")
    edge_options.add_experimental_option("prefs", prefs)
    # edge_options.add_argument("--headless")  # 在后台运行浏览器

    # 设置Edge驱动路径
    webdriver_service = Service(r"E:\bingdownload\edgedriver_win64\msedgedriver.exe")
    # url = "https://cdfd.cnki.net/dejournals/#/cdfd/science"
    driver = webdriver.Edge(service=webdriver_service, options=edge_options)
    driver.get(url)
    time.sleep(2)
    
    #查找开始下载的year_month
    month_elmets = driver.find_elements(By.XPATH, '//div[@class="conneritembottomr"]/ul/li/a')
    i, j  = 0, len(month_elmets)
    print(i, j)
    while i < j:
        month_elmets[i].click()
        time.sleep(5)
        try:
            nums = driver.find_element(By.XPATH, '//div[@class="contentsbottomrb"]/div/span').text
            nums_list = re.findall(r"\d+", nums)
            nums = int("".join(nums_list))
            print(f"year month has pdfs:{nums}")
        except Exception as e:
            print(f"year month has pdfs:{nums}")
            print(e)
            nums = 0
        if nums == 0:
            driver.quit()
            driver = None
            break
        i += 1
        if cur_downloaded + nums <= downloaded:
            cur_downloaded += nums
            driver.back()
            time.sleep(5)
        else:
            break
        month_elmets = driver.find_elements(By.XPATH, '//div[@class="conneritembottomr"]/ul/li/a')
    return driver

def download_onepage(driver, name):
    # print(button[1].get_attribute("disabled"))
    cnt = 0
    flag = download_pdfs(driver, name)
    cnt += flag
    button = driver.find_elements(By.XPATH, '//div[@class="contentsbottomrb"]//button')
    while button[1].get_attribute("disabled") == None:
        button[1].click()
        # time.sleep(4)
        flag = download_pdfs(driver, name)
        cnt += flag
        if cnt == 2:
            driver.quit()
            return None
        button = driver.find_elements(By.XPATH, '//div[@class="contentsbottomrb"]//button')
    # flag = download_pdfs(driver, name)
    driver.quit()
    return None

def download_pdfs(driver, name):
    global downloaded, cur_downloaded 
    pdfs = driver.find_elements(By.XPATH, "//tbody/tr[@class='el-table__row']/td[1]/div[@class='cell']/a")
    main_window = driver.current_window_handle
    if cur_downloaded + len(pdfs) <= downloaded:
        cur_downloaded += len(pdfs)
        time.sleep(1)
        return False
    else:
        time.sleep(4)
        pdfs = driver.find_elements(By.XPATH, "//tbody/tr[@class='el-table__row']/td[1]/div[@class='cell']/a")
    i = 1
    window_set = set([main_window])
    for pdf in pdfs:
        try:
            print(pdf.text)
            pdf.click()
            time.sleep(2)
        except Exception as e:
            print("pdf html error.")
        windows = driver.window_handles
        # 切换到新窗口
        for window in windows:
            if window not in window_set:
                driver.switch_to.window(window)
                window_set.add(window)
                break
        try:
            dl_pdf = driver.find_element(By.XPATH, "//div[@id='DownLoadParts']/div/ul/li[3]/a")
            dl_pdf.click()
            time.sleep(2)
            #添加新产生的页面
            windows = driver.window_handles
            for window in windows:
                if window not in window_set:
                    window_set.add(window)
        except Exception as e:
            print(f"An error occurred")
        # time.sleep(2)
        driver.switch_to.window(main_window)
        i += 1
    cur_downloaded += len(pdfs)
    windows = driver.window_handles
    # 切换到新窗口
    time.sleep(20)
    for window in windows:
        try:
            if window != main_window:
                driver.switch_to.window(window)
                driver.close()
                time.sleep(0.5)
        except Exception as e:
            print(f"An error occurred when close window")
    driver.switch_to.window(main_window)
    with open(name, "w") as f:
        f.write(f"{cur_downloaded}")
    return True

# %%
while True:
    url = "https://cdfd.cnki.net/dejournals/#/cmfd/engineering2"
    download_dir = r"G:\zhiwangpdf\0716"
    try:
        driver = startdownload(download_dir, url, name)
        download_onepage(driver, name)
    except Exception as e:
        print(e)
# Out:
# 0 1578
# 0 243
# year month has pdfs:7500
# 军工电缆生产线计量测控单元研究与组网设计
# 动态三维场景中迷彩伪装效果评估方法
# 基于组合基函数的变换域隐蔽抗干扰通信研究
# 面向舰空移动通信的OTFS均衡技术研究
# 基于深度学习的雷达干扰识别方法研究
# SAR欺骗干扰技术与干扰效果评估方法研究
# 基于协同突防的组网雷达干扰资源分配技术研究
# An error occurred
# 基于深度学习的数字自干扰对消算法研究
# 宽带雷达信号距离成像干扰技术研究
# An error occurred
# 基于深度强化学习的协同干扰决策研究
# 大带宽数字信道化雷达侦察干扰技术研究与实现
# 干扰机的数字域自干扰对消技术研究
# 间歇采样转发式干扰的特征提取与识别方法研究
# MSK相干接收下的干扰效能分析
# 衰落信道下Link-16数据链关键技术研究
# An error occurred
# 基于盲源分离的交叉极化干扰对消技术研究
# 基于机器学习的雷达自适应干扰技术研究
# 基于三维地形图的GBSM空—空信道建模方法研究
# 基于物理层参数决策的自适应通信干扰技术研究
# 雷达信号干扰方法与干扰策略研究
# An error occurred when close window
# An error occurred when close window
# 通信辐射源定位技术研究
# 分布式地空无线监测接收系统关键性技术研究
# 雷达自适应干扰策略及评估方法研究
# 雷达有源干扰识别方法的研究与实现
# 优化算法在多站协同干扰资源分配中的关键技术研究
# 基于深度强化学习和博弈论的雷达抗干扰技术研究
# 自适应伪装系统激发控制及伪装方案设计研究
# 高速铁路对旅游业发展影响研究——以山西省为例
# 中国铁路HRB局货运营销中心发展战略研究
# 中欧班列的开通与地级市FDI流动
# 面向东盟国家来华留学生的“铁路客运服务汉语”教材设计
# 铁路物流园区服务质量评价研究
# 基于轴辐式理论的中欧班列物流运输网络优化研究
# 基于收益管理的高速铁路票价与票额协同优化
# 基于实物期权的高铁项目建设时机研究——以甬台温高铁为例
# 中国参与泛亚铁路项目建设模式研究
# 高速铁路对甘肃省沿线县域经济发展的影响研究
# 数字化对乌克兰铁路公司网上销售的影响：案例研究
# 高铁发展对中国城市出口技术复杂度的影响研究
# A公司ZT海外高铁项目风险管理研究
# 0 1618
# 0 243
# year month has pdfs:7500
# A公司管理人员绩效管理满意度研究
# 中欧班列低碳多式联运路径优化研究
# 北京铁路局集团公司邯郸货运中心货运服务质量评价研究
# 铁路货场综合服务能力评价研究
# 秦皇岛东站货运发展战略研究
# 高铁企业国际声誉形成机理及提升策略研究
# 高铁项目全寿命周期费用风险管理研究
# An error occurred
# 铁路运营企业运输效率测度及影响因素研究
# 高速铁路的区域科技创新协调效应研究——以京津冀区域为例
# 基于DMAIC模型的中欧班列运行质量评价及改进研究
# 基于GWR的高速铁路对城市群的经济影响对比研究——以京津冀和长三角城市群为例
# HS铁路专用线项目投资风险评价研究
# 高铁轨道路基结构动力响应与累积变形研究
# An error occurred
# 道岔辙叉护轨间隔取值范围的优化研究
# 普速工务安全管理案例研究——以A工务段为例
# 基于动静态响应信号的钢轨踏面裂纹识别研究
# 基于柔性轮轨结构的车轮多边形对车辆动力学影响的研究
# 某城轨车刚柔耦合动力学及构架疲劳分析
# 基于有限元法的高速轮轨蠕滑特性分析
# An error occurred
# 铁路防护墙对爆炸冲击波传播影响的数值研究
# An error occurred when close window
# 轨缝处的轮轨接触力学分析及优化设计
# 基于车体振动响应的轨道异常检测及可视化研究
# An error occurred
# 1000吨轮胎式提梁机液压行走驱动系统设计与性能分析
# 基于车致振动响应的无砟轨道病害诊断研究
# 季冻区高速铁路路桥过渡段路基温度场以及沉降研究
# An error occurred
# 路基冻胀下高速铁路钢轨平顺性及疲劳寿命研究
# 高速列车荷载下CFG桩复合地基动态响应特性研究
# 滨海软土地区桩承式加筋路堤沉降性状研究
# An error occurred
# 京张高铁沿线风吹雪灾害防治数值模拟研究
# 钢渣道砟劣化规律试验研究
# 复合谐波荷载作用下高速铁路钢轨型面演变规律研究
# 轮轨复合伤损作用下扣件系统劣化机理研究
# 用于中高频振动监测的FBG加速度传感器设计与性能研究
# 中高频差动测量压电加速度传感器设计与仿真研究
# 桩承式加筋路堤受力及变形特性模型试验与数值模拟研究
# 基于BIM平台的铁路实体选线技术及系统研究
# An error occurred
# 振动荷载作用下列车-桥梁-基坑支护-土体耦合系统力学响应
# 基于功率流理论的轨道板裂缝识别方法研究
# 基于TOPSIS与灰色关联分析的钢轨减磨策略优选研究
# 城市轨道交通轮轨力间接测量方法研究
# An error occurred when close window
# 0 1658
# 0 243
# year month has pdfs:7500
# 轨缝处的轮轨接触力学分析及优化设计
# 基于车体振动响应的轨道异常检测及可视化研究
# 1000吨轮胎式提梁机液压行走驱动系统设计与性能分析
# An error occurred
# 基于车致振动响应的无砟轨道病害诊断研究
# An error occurred
# 季冻区高速铁路路桥过渡段路基温度场以及沉降研究
# 路基冻胀下高速铁路钢轨平顺性及疲劳寿命研究
# 高速列车荷载下CFG桩复合地基动态响应特性研究
# 滨海软土地区桩承式加筋路堤沉降性状研究
# 京张高铁沿线风吹雪灾害防治数值模拟研究
# 钢渣道砟劣化规律试验研究
# 复合谐波荷载作用下高速铁路钢轨型面演变规律研究
# 轮轨复合伤损作用下扣件系统劣化机理研究
# 用于中高频振动监测的FBG加速度传感器设计与性能研究
# 中高频差动测量压电加速度传感器设计与仿真研究
# 桩承式加筋路堤受力及变形特性模型试验与数值模拟研究
# 基于BIM平台的铁路实体选线技术及系统研究
# 振动荷载作用下列车-桥梁-基坑支护-土体耦合系统力学响应
# 基于功率流理论的轨道板裂缝识别方法研究
# 基于TOPSIS与灰色关联分析的钢轨减磨策略优选研究
# 城市轨道交通轮轨力间接测量方法研究
# An error occurred when close window
# 1435mm/1000mm三线套轨铁路轨枕阻力特性研究与结构设计
# An error occurred
# 基于构架姿态的轨道几何形位解算方法研究
# 高速铁路综合维修计划编制方法研究与系统设计
# BIM背景下基于GT-SD的铁路工程造价控制研究
# 基于模态分析和超声检测的铁路弹条扣压力测量方法研究
# 铁路工程建设全过程造价影响因素及造价体系研究
# An error occurred
# 基于超声导波的道岔尖轨伤损检测技术研究
# 轮对刚—柔建模的重载机车牵引过程轮轨粘着及动力作用
# 基于车-轨-浮置板耦合模型的车轴应力响应与浮置板振动特性分析
# 基于群体智能优化算法的高速铁路钢轨磨耗预测及廓形多目标优化设计
# 铁路道岔轨底超声导波探伤关键技术研究
# CRTSⅢ型轨道板封锚机器人应用及控制研究
# 铁路除沙车仿生除沙铲设计及减阻耐磨分析
# CRTS Ⅲ型轨道板模具喷涂脱模剂机器人研发
# 大跨度铁路桥梁端抽屉式伸缩轨道研究
# 盾构施工下穿既有高铁路基变形规律研究
# 水热力作用下铁路基床泥浆特性与侵入道砟机理研究
# 基于深度强化学习的铁路线路方案生成方法研究
# 考虑冻融影响的高速铁路路基橡胶粉改性复合基床表层疲劳耐久性研究
# 季节性冻土区重载铁路路基填料冻胀变形研究
# An error occurred when close window
# 0 1679
# 0 243
# year month has pdfs:7500
# 基于多物理量耦合的微纳卫星电源分系统仿真及状态预测
# 基于姿态反馈的空-地导弹变结构制导律研究
# 面向空中机动目标的多弹协同跟踪制导方法研究
# 氧环境下镁颗粒点火及燃烧特性研究
# 海上热发射高温冲刷特性研究与热防护设计
# 筒内壁检测清洗机器人系统设计与运动控制研究
# 入水冲击对导弹壳体及药柱响应影响的数值研究
# An error occurred
# 基于δ-GLMB滤波器的机动多目标跟踪技术的研究
# 导弹发动机油箱用数字比例阀方案及稳压特性研究
# An error occurred
# 基于MBSE的导弹突防联合设计和仿真系统的设计与开发
# 考虑滚动轴承故障的燃机动力涡轮转子—机匣系统动力学特性研究
# 舰船辐射噪声多维特征提取方法研究
# 舰船辐射噪声线谱增强技术研究
# 近场噪声源高分辨定位方法研究
# An error occurred
# 螺旋桨激励水下航行器艉部振动声辐射研究
# 舰船尾迹红外特性及检测方法研究
# 三氟一溴甲烷灭火系统设计与流场仿真
# An error occurred
# 基于YOLOv5的舰船尾迹检测
# 航母编队模拟对抗训练系统交互界面设计与评价
# An error occurred
# 金属燃料双闭式循环热电混合动力系统仿真及性能分析
# An error occurred
# 轴箱加速度在搭载式轨检仪轨道几何形位解算中的应用研究
# 基于声发射的钢轨脆性断裂检测方法研究
# 电渗作用下非饱和土路基排水效果研究
# 大跨度铁路桥梁端可伸缩式轨道结构设计研究
# An error occurred
# 钢弹簧失能下车辆-浮置板轨道振动特性及检测研究
# 挂载式动态轨道检查仪数据采集系统研究
# An error occurred
# 基于车致轨道振动响应的无缝线路温度力识别方法研究
# 土工格栅加筋橡胶碎石混合料强度与变形特性试验研究
# An error occurred
# 准米三线套轨铁路道岔动力学特性研究
# 面向移动终端的铁路交互选线方法及实现技术研究
# 铁路冻害路基人工主动供热系统与冻胀防控效果研究
# 橡胶-玄武岩纤维复合改性水泥稳定碎石力学性能研究
# An error occurred
# 高陡黄土边坡降雨失稳风险评价与护坡措施优选分析
# 盾构下穿高铁路基地表沉降关键控制技术
# 长大隧道施工中有轨运输轨道高低不平顺估计研究
# 考虑列车荷载作用的隧道-边坡抗滑桩控制方法
# An error occurred
# 振动荷载作用下路基土体电阻率演化规律研究
# 断簧对车辆—浮置板轨道耦合系统振动特性的影响研究
# 冻融作用下重载铁路路基填料宏微观变形演化机理研究
# An error occurred
# 磨料水射流修复钢轨的廓形拟合与工艺参数优化研究
# An error occurred when close window
# An error occurred when close window
# 0 1718
# 0 243
# year month has pdfs:7500
# 高寒地区铁路路基病害特征及整治技术研究
# 基于IDA的桥上无缝线路地震易损性研究
# 多维地震作用下道岔梁梁体响应行为研究
# 高速铁路道岔梁桥地震响应分析
# 一种主桁整体可展的铁路抢修梁研究
# 高铁施工装备用液压盘式制动器极值预测及疲劳寿命分析
# An error occurred
# 车致空隙水压作用下无砟轨道CA砂浆层脱空病害发展研究
# 基于图像处理的钢轨表面缺陷检测系统设计
# 恒阻吸能锚杆剪切形变智能识别方法研究
# 用于钢轨损伤探测的光纤光栅超声波传感器
# 准池铁路路基病害整治技术研究
# 道岔尖轨压力顶弯数学模型及分段顶弯仿真研究
# An error occurred
# 道岔基本轨分段顶弯数学模型研究
# 高锰钢辙叉感应加热数值模拟及实验分析
# 埃及斋月十日城铁路项目风险管理研究
# 地聚物改良铁路路基黄土静力学与渗透机理研究
# 加筋土挡墙筋材反包锚固机理及设计方法研究
# 蒸养混凝土力学性能及在盐雾中氯离子传输研究
# An error occurred
# 高速铁路轨道结构地震作用响应机理与分析方法研究
# 高速铁路跨填方区黄土力学特性及路基动力响应研究
# An error occurred when close window
# N铁路与G高速公路公铁并行路段施工项目安全风险评估
# An error occurred
# 交直交异步电机牵引试验平台测控系统开发
# An error occurred
# 新型绝缘气体开关柜的电场及温度场仿真研究
# 基于磁流体动力学的弓网电弧侵蚀研究
# 既有铁路电气化改造项目施工安全风险管理研究——以集通铁路电气化改造项目为例
# An error occurred
# 电气化铁路对埋地管道交流干扰防护措施及优化技术研究
# 铁路电力远动系统组网优化研究
# 高铁供电网控制电缆弱磁场分布特性与侦测定位技术研究
# 基于FEKO的高铁弓网离线电气特性研究
# An error occurred
# 牵引侧母线二次回路典型故障模型与自动投切装置研究
# 基于Faster R-CNN与EfficientNet网络的接触网吊弦故障检测
# An error occurred
# 基于EfficientDet与Vision Transformer网络的接触网吊弦状态检测
# 重载铁路10kV电力线故障行波同步测量技术与实时定位系统研究
# 基于无人机巡检的高铁接触网螺母及开口销状态分析研究
# An error occurred
# 基于多导体传输线理论的电气化铁路牵引回流分布研究
# 联合IHGS-VMD与MKRVM的城轨牵引电流特征识别算法研究
# 基于供电能力模型的重载铁路牵引变电所特殊工况研究
# 基于无人机和深度学习的隔离开关非接触测量研究
# 弓网燃弧电磁辐射信号的检测分析系统设计研究
# An error occurred
# 基于深度学习的高铁接触网构件缺陷图像识别软件设计
# An error occurred when close window
# 0 1758
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 1758
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 1758
# 0 243
# year month has pdfs:7500
# N铁路与G高速公路公铁并行路段施工项目安全风险评估
# 基于时域信号特征的牵引主变差动保护算法研究与工程实现
# 高铁接触网受流特性影响因素研究
# 高速铁路吊弦损伤智能识别技术研究
# 双弓条件下吊弦疲劳损伤特性研究
# An error occurred
# 基于分数阶模型的弓网系统振动控制研究
# 基于分数阶模型的弓网系统动力学分析
# An error occurred
# 厚圆砾层深基坑双排桩受力变形及设计参数分析
# 多车模式下地铁隧道活塞风对站台屏蔽门故障影响研究
# 面向ACC的工程设计规范和设计模型的表达与存储研究
# 面向地铁设计自动合规性检查的IFC模型数据处理方法研究
# BIM正向设计模式下地铁车站智能辅助设计方法研究
# 基于多源数据的杭州地铁站域空间发展协调性评价及规划策略
# 大断面矩形通道密贴下穿对既有车站影响及变形控制研究
# 既有隧道上方黏土地层卸荷回弹特性研究
# 地铁基坑工程施工风险评价研究
# 复杂条件下小半径曲线隧道盾构力学特性研究
# 地铁通道明暗挖结合施工邻近密集管线变形特性及参数优化研究
# 城市轨道交通PPP项目运营期绩效评价研究
# 地铁公共区突发火灾事件应急疏散研究
# An error occurred when close window
# 弓网离线放电过程中的电气特性及其温度分布研究
# 基于BIM的地铁车站管线综合避让优化及深化设计应用研究
# 寒区高铁隧道洞口工程施工风险评价及对策研究
# An error occurred
# 基于Petri网的地铁火灾应急预案建模与性能分析
# 交流牵引试验平台测控系统开发
# 大连地铁后盐站深基坑变形特性与优化设计研究
# 基于BIM技术的地铁工程可视化管理研究
# 地铁隧道内线路平纵断面调整方法研究
# 地铁车站突发火灾应急联动机制研究
# 基于探地雷达的地铁整体道床病害检测技术研究
# 地铁车站建设投资动态预测与控制方法研究
# An error occurred
# 地铁车站建设安全风险预测与控制方法研究
# 基于车内噪声与轴箱振动加速度响应的波磨检测方法研究
# 考虑乘客特征的地铁车站闸机通行能力研究
# 基于BIM与VR的地铁站出入口布局研究
# 混合式磁悬浮列车磁轨关系及力学特性分析
# 基于声子晶体的浮置板轨道减振研究
# 盾构渣土资源化处理系统研究
# 考虑基床系数折减的下穿既有隧道变形预测方法研究
# 装配式明挖地铁隧道运营期安全性能研究
# 0 1798
# 0 243
# year month has pdfs:7500
# 钢波纹板加固重载铁路在役涵洞适应性研究
# 土工格室加筋碎石复合体静动三轴试验研究
# 牵引传动试验平台能馈装置研究与检测软件设计
# W地铁长丹区间盾构施工进度控制研究
# 济南地铁4号线项目施工阶段风险管理研究
# 入硬岩地下连续墙施工工艺研究
# 高速铁路全封闭声屏障列车风压特性研究
# 换乘地铁车站同期建成施工控制技术
# 钢弹簧浮置板轨下基础施工偏差传递规律及应用研究
# An error occurred
# 地铁车辆段TOD开发上盖建筑振动舒适度研究
# 软土地区新建地铁深基坑施工对既有结构的影响研究
# 徐州某地铁车站施工效应及环框梁优化设计研究
# 混合及贴附通风方式下地铁屏蔽门渗漏风对岛式站台夏季热环境的影响
# 基于西安北站的地铁车站设备管理用房热环境及气流组织优化设计
# 地铁环控系统温度传感器软故障的检测与诊断方法研究
# 地铁车站环控通风系统控制方案及运行策略优化研究
# 变热流边界作用下地铁隧道周围土壤的热蓄积效应研究
# An error occurred
# 基于IEC61850的地铁牵引网故障记录与测距装置研究
# 重载铁路高压断路器运行状态评价策略研究与工程实现
# 地铁直流母线电压谐振成因与进线保护优化研究
# An error occurred when close window
# 高温超导磁悬浮列车永磁轨道优化及分析
# PBA工法地铁车站施工安全风险评价研究
# 盾构下穿既有地铁区间变形与控制影响研究
# An error occurred
# 地铁浮置板轨道结构动态响应研究及参数影响分析
# 永磁轨道在不同曲率与纵向开断下的电-磁-力耦合特性
# T市地铁1号线学府街东口站深基坑施工安全风险评价与控制研究
# QD地铁4号线机电安装工程进度管理研究
# An error occurred
# 新建隧道上穿诱发既有盾构隧道纵向变形机制及失效概率分析
# 都市圈多层次轨道交通网络的可达性研究
# 地铁车站结构基于易损性的抗震性能评估
# 黄土暗挖地铁车站3T结构体系多工序施工时空影响特征研究
# 地震作用下地铁车站动力响应分析及参数化研究
# 高边坡PBA暗挖地铁车站及区间衔接段施工稳定性影响研究
# An error occurred
# 基于灰色关联分析法的地铁施工安全风险管理研究
# 黄土地区深基坑开挖对既有盾构隧道影响分析
# 西安地区基坑开挖对下卧既有地铁隧道影响研究
# An error occurred
# 基于贝叶斯网络优化的物元可拓城市地铁网络韧性评估及优化策略研究
# 轨道交通站点周边土地利用多目标优化方法
# 跨地裂缝带高速铁路复合地基-路基动力响应研究
# An error occurred
# 软流塑地层盾构近距离下穿既有隧道施工影响及控制技术研究
# An error occurred when close window
# 0 1838
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 1838
# 0 243
# year month has pdfs:7500
# 西安某地铁车站结构振动台试验研究
# 基坑开挖对既有下卧地铁隧道变形影响及抗浮措施研究
# Y型地铁隧道烟气流动特性与温度分布规律研究
# An error occurred
# 城市轨道交通网络韧性评估与最优恢复策略研究
# 地铁盾构施工规范知识图谱构建及应用研究
# An error occurred
# 西安市城市轨道交通接驳公交线路优化研究
# 考虑公交接驳的城市轨道交通网络韧性评估及关键站点识别
# An error occurred
# 地铁车站出入口装配式侧墙U型筋搭接连接节点受弯性能研究
# 盾构下穿既有区间隧道施工扰动特性及预加固技术研究
# An error occurred
# 青岛某地铁变截面隧道开挖围岩变形特征研究
# “TOD”视角下青岛城市轨道站域空间优化策略研究——以青岛“李村”地铁站为例
# 轨道交通站域地下空间防灾韧性研究——以青岛北站为例
# 青岛滨海区地铁站域空间步行友好性评价及优化策略研究
# 基于情景演化的岛式地铁车站火灾烟气运移及人员疏散模拟研究
# 青岛地铁隧道穿越断层破碎带突涌水灾害稳定性分析及防控
# 地下水渗流对地铁源热泵毛细管前端换热器传热特性的影响
# 地铁源热泵系统全热过程协同特性研究
# An error occurred
# 复合地层沉桩施工对侧方既有地铁隧道的影响研究
# 复杂支护条件的软岩隧道系统可靠度分析
# 污水管线渗漏对地铁隧道结构及周边地层影响机理研究
# An error occurred when close window
# An error occurred when close window
# 浅覆土盾构隧道近距离上跨既有地铁隧道变形影响研究
# 城市轨道站点服务范围识别与接驳方案优化研究
# 导流功能管片的试验研究与应用
# 中强风化花岗岩地层地铁盾构施工土体与结构变形研究
# 基于韧性视角的地铁系统防火能力度量
# 基于长期监测数据的复杂地层盾构施工地表沉降与掘进参数研究
# 基于车桥耦合的大跨度钢-混变截面简支轨道梁性能评价研究
# 预弯波形钢腹板钢箱—混凝土组合轨道梁力学性能分析及截面参数研究
# 新型跨座式单轨减隔震支座动力性能分析
# QD地铁6号线H站装配式明挖地铁车站施工安全风险管理研究
# 基于动态贝叶斯网络的地铁盾构施工安全风险评估研究
# 商业综合体与地铁内部衔接空间设计研究——以青岛地铁为例
# 宁波地区黏砂互层软黏土的动力特性及长期变形研究
# 跨地裂缝带地铁隧道衬砌结构的力学响应研究
# 大跨度双连拱隧道下穿既有轨道交通扰动影响与变形控制技术研究
# An error occurred
# 电力隧道顶管法施工上跨既有地铁施工扰动机制与控制技术研究
# 客流特征视角下的城市轨道交通网络脆弱性
# 考虑土—结构相互作用的地铁车站抗震性能研究
# 基于出行链的城市轨道交通接驳方式选择研究
# An error occurred
# 西安地铁热湿环境测试与热舒适性评价——以地铁2号线为例
# 0 1878
# 0 243
# year month has pdfs:7500
# 地铁荷载作用下黄土动力特性与微观结构研究
# 基于Modelica建模仿真的地铁通风空调系统控制策略及能耗模拟研究
# 软土地区复杂地下空间近接施工影响规律及控制措施研究
# 高速地铁地下站台屏蔽门气动压力研究
# 高速地铁列车由明线进入隧道行驶引起的压力波动研究
# 城市轨道交通排水改造两阶段投资决策研究
# 地铁综合联调项目协同管理研究
# 地铁PPP项目建设期绩效评价研究
# 基于节能操纵及再生制动能利用的地铁列车综合节能运行研究
# 高原双动力机车牵引通风系统仿真计算研究
# 基于贝叶斯网络的动车组传动系统可靠性分析
# 突变风场对高速列车受电弓气动特性影响
# An error occurred
# 基于灵敏度分析的动车组转向架构架结构优化
# 一种12V240H机车柴油机中凸变椭圆组合活塞的设计与研究
# An error occurred
# 16V280ZJ型柴油机冷却式喷油器的设计与研究
# 动车组闸片摩擦磨损分析及寿命预测研究
# An error occurred
# 高原双源动力机车柴油机空滤系统仿真分析
# 动车组车载真空断路器真空度在线检测研究
# 基于永磁同步电机的动车组变流传动系统仿真分析
# 基于数据挖掘动车组车轮运用镟修管理研究与实现
# An error occurred when close window
# An error occurred when close window
# An error occurred when close window
# 电辅助增压的米勒循环柴油机性能优化仿真研究
# 高速列车仿生受电弓弓头气动与噪声特性数值研究
# 导流罩设计对高速列车受电弓空气动力学性能的影响
# An error occurred
# 某城际列车车下设备安装强度及疲劳分析
# 动车组空调风道与车厢气流组织分析及优化研究
# 高速列车受电弓气动噪声源仿真及降噪设计
# 受电弓弓头下表面结构对气动性能及噪声特性的影响
# An error occurred
# 动车组用电涡流缓速器的设计及仿真分析
# 列车受电弓气动特性研究及国产自主研发软件INTESIM的应用
# An error occurred
# 电力机车复冷装置降噪研究
# HXD3C型机车牵引齿轮全寿命分析与研究
# 旋转叶片式涡旋管分离器性能数值分析
# 基于工位制节拍化生产的电力机车驱动组装现场管理研究
# An error occurred
# 基于数据驱动的高速列车牵引系统早期故障实时诊断
# 基于白光共聚焦的轮轴微划痕检测系统研究
# 车轮多边形与齿轮传动多激励作用对动车动力学性能的影响
# 基于用户体验的磁悬浮车人机界面交互设计研究
# 高速磁悬浮车—桥耦合动力响应研究
# 基于自抗扰的永磁直线同步电机自适应观测无传感控制
# 磁浮系统恒磁场对无源应答器影响研究
# An error occurred
# An error occurred when close window
# 0 1918
# 0 0
# list index out of range
# 0 1918
# 0 243
# year month has pdfs:7500
# 基于模糊神经网络的重载列车运行控制策略研究
# 城市轨道交通列车节能运行优化研究
# 高速动车组转向架故障分析研究
# 混合型磁悬浮系统非线性悬浮力建模及其振动特性研究
# 二自由度磁浮系统垂向非线性动力学及反馈控制研究
# 高温超导悬浮架系统振动特性研究和性能评估
# 利用轴重转移的四轴电力机车黏着控制策略研究
# 铁路机车空气悬挂系统动力学与振动控制研究
# An error occurred
# Γ型悬臂梁式压电加速度传感器设计与仿真研究
# 高速铁路动车组运用及客运乘务计划优化研究
# 高可靠大容量列车通信网络性能评估及预测
# 基于视觉和激光雷达的城市轨道交通列车主动防撞检测系统研究
# 基于竞争威布尔的地铁列车关键部件维修策略优化研究
# 基于双光谱融合的走行部温度在线检测技术研究
# 面向增材修复的铁路货车车钩表面瑕疵检测方法
# 铁路货车轴承故障诊断方法研究
# 货车车体泡棉板烘干设备的设计研究
# 轨道客车内饰板材的智能柔性喷胶系统
# 车辆刮刷系统改进设计及分析
# 面向全周期多维度的轨道列车关键部件MBD建模规范构建
# An error occurred when close window
# An error occurred when close window
# An error occurred when close window
# 散粒体货物对敞车侧壁压力分布试验研究
# 高速列车空调风道及客室多组分混合气体内流场数值分析
# 轨道列车关键部件加工工艺知识图谱构建及工艺推理研究
# 地铁蓄电池箱的有限元分析与轻量化研究
# 某铁路车辆维修企业安全生产双重预防机制研究
# Goodman-Smith疲劳方法研究及其在轨道车辆的应用
# 局部表面纳米化正方形多胞防爬器吸能特性的研究
# 高速列车轨旁系统声流场特征及分析方法
# 基于自由变形技术的车头外形多目标优化设计
# 高摩合成材料不同试验方法的研究
# 轨道车辆焊接结构三维穿透裂纹强度分析
# 局部表面纳米化六边形多胞列车防爬器吸能特性的研究
# 基于BiLSTM-CRF的车轴疲劳裂纹声发射信号预测研究
# 针对铝合金车体的高效有限元建模及后处理方法研究
# 铁路货车制动状态在线监测系统设计
# 某地铁转向架构架疲劳性能研究
# 基于声信号的列车轴承故障诊断研究
# 高速列车风阻制动板气动特性及制动效果研究
# PM2.5在轨道车辆内扩散的模拟分析
# 轨道车辆底架结构轻量化研究
# 0 1958
# 0 243
# year month has pdfs:7500
# 基于PSO-DBN的车轴疲劳裂纹声发射信号识别分析
# 某铁路货运罐箱结构虚拟疲劳试验研究
# 车轮多边形对高速列车动力学性能的影响研究
# 基于改进一维CNN的车轴疲劳裂纹声发射信号识别分析
# 铁路货车车体瞬态响应及其焊缝疲劳评估
# 基于柔性建模的转向架部件动力学性能分析
# 重载列车空气制动系统适配性研究
# 地铁车厢内流场数值仿真与人体热舒适性分析
# 轨道车辆悬挂系统半主动控制研究
# 病毒飞沫在城轨车辆内传播方式的模拟分析
# An error occurred
# 自适应高速转向架蛇行稳定与不稳定相互转变条件
# 高速列车车窗隔声性能研究
# An error occurred
# 焊接接头数据库的开发与应用
# 地铁车车体疲劳分析及结构优化研究
# An error occurred
# 市域D型车车体疲劳分析及尺寸优化
# 基于VMD排列熵-CNN的车轴疲劳裂纹声发射信号识别研究
# 磨耗工况下高速列车半主动控制仿真分析及硬件在环实验研究
# 高速铁道车辆动态响应及振动传递路径贡献分析
# An error occurred
# 声发射技术在高铁齿轮箱箱体损伤检测中的应用研究
# 基于Simulink与UM的高速列车轴箱轴承动力学建模与故障仿真分析
# An error occurred
# An error occurred when close window
# 空气弹簧悬挂系统的非线性动力学分析及半主动控制
# 铁路客车自动上水系统研究
# 铁路平车刚柔耦合动力学建模及碰撞过程纵向动态行为研究
# An error occurred
# 基于动力学—数据驱动模型分析的高速列车轴箱轴承故障诊断研究
# 基于共振稀疏分解的轮对轴承故障诊断
# An error occurred
# 高速列车空气弹簧系统动力学特性及内部流场分析
# 基于双目立体视觉的高速列车齿轮箱表面缺陷检测研究
# 滚动轴承外圈力学性能与微观组织演化
# 基于时频分析与自适应筛选滤波的高速列车轴承故障诊断研究
# 横风下重载货运列车的气动特性与动力学分析研究
# An error occurred
# 基于尺度空间理论的高速列车轴箱轴承故障诊断方法研究
# 基于恒等映射多层极限学习机的高速列车车轮踏面磨耗预测及型面优化研究
# An error occurred
# 高速列车轴箱轴承服役性能退化规律与寿命预测研究
# 高速列车齿轮箱箱体疲劳寿命分析
# 自动上水装置控制系统研究
# An error occurred
# 小样本下基于深度神经网络的列车轴承表面缺陷检测方法研究
# 钢桁腹混凝土桥的车桥耦合振动分析与损伤研究
# 石家庄地铁列车引发周围建筑物振声响应及减隔振措施研究
# 超导变压器的设计及优化
# 钢板结合连续梁车桥耦合振动与结构噪声分析
# An error occurred when close window
# 0 1998
# 0 243
# year month has pdfs:7500
# 铁路货车车体静强度试验台优化设计
# 冬夏季节地铁出行者热舒适需求及关键影响因素研究
# 质量分布对高速铁道车辆动力学性能的影响分析
# 地铁车辆空调机组箱体的有限元分析及结构优化
# 服役环境下考虑柔性构架的高速列车刚柔耦合模型动力学研究
# 重载货运列车曲线及道岔运行过程轮轴配合面损伤研究
# 重载列车长大下坡制动过程踏面白层形成机理研究
# 铁路货车车钩铸造编号的视觉识别研究
# 城轨车体称重调簧算法优化与称重台软件开发
# 重载列车长大下坡制动过程疲劳裂纹萌生及扩展机理研究
# 基于深度学习的列车轮对踏面损伤检测算法研究
# 地铁列车辅助逆变器Simulink模型构建与故障诊断
# 铁路客车铜基粉末冶金闸片摩擦性能及寿命预测研究
# 高速列车轴箱偏斜滚子轴承热混合润滑分析
# 高铁齿轮箱角接触球轴承热混合润滑分析
# 闸瓦钢背产品参数在线自动检测系统研究
# 复杂背景下的铁路货车车号识别与闸瓦定位研究
# 磁悬浮系统中多芯复合Nb3Sn超导线磁热稳定性分析
# 高速铁路下无线通信网络的越区切换方案研究
# 基于遗传算法的列车ATO运行曲线优化方法研究
# An error occurred when close window
# An error occurred when close window
# 一种简单的中继辅助铁路通信LTE-R资源分配方案
# UWB在无人驾驶轨道交通中的应用研究
# An error occurred
# 基于径向基神经网络的列车速度自适应滑模控制研究
# 应答器传输单元滤波性能优化研究
# XS铁路信号系统运营期风险管理研究
# GSM-R铁路移动通信动态检测关键技术研究与实现
# 翻车机橡胶板安装方式对敞车内倾弯矩影响研究
# 靠车板安装高度对车辆内倾弯矩影响研究
# 城市地铁停车换乘的路径优化与诱导
# 铁路浮动票价对大学生出行行为的影响研究
# 城市轨道交通车站客流拥挤识别及仿真优化
# 城市轨道交通分时段票价研究
# 京雄城际铁路列车开行方案优化
# 考虑竞合关系的城市轨道交通周边常规公交线网优化研究
# An error occurred
# 基于鲁棒优化的高速铁路票额两阶段分配模型研究
# 基于服务质量的地铁乘客生活满意度研究
# 疫情下城市地铁站行人组织研究
# 基于鲁棒优化的城市轨道交通列车弹性发车间隔研究
# 区间失效条件下城市轨道交通网络客流分配研究
# 城市轨道交通站点换乘方式及接驳设施规模预测
# 0 2038
# 0 243
# year month has pdfs:7500
# 考虑乘客路径选择的城市轨道交通列车交路方案优化
# 高铁与城市轨道交通换乘系统的客流控制
# An error occurred
# 城市轨道交通大客流传播机理及疏散方案研究
# 东南亚货物出口欧洲集装箱铁路运输路径选择研究
# 基于数字孪生的大型铁路客运站技术作业仿真研究
# 高铁货运需求分析及列车开行方案设计
# 考虑乘客安全的地铁换乘站流线仿真研究
# 市郊铁路合理站间距和开行方案研究
# 铁路旅客运输服务质量综合评价体系研究
# 多制式枢纽站城市轨道交通时刻表优化研究
# 基于深度学习的火车站人流量统计及LabVIEW实现
# An error occurred
# 基于地铁与常规公交换乘的行程优化
# 基于EEMD-LSTM地铁OD短时预测
# 铁路客运站到发线运用计划优化研究
# An error occurred
# 北京中心城区轨道交通网络与城市空间结构耦合研究
# 考虑空铁联运衔接的城际铁路列车时刻表优化
# 衔接机场的地铁列车时刻表优化
# An error occurred
# 基于神经网络模型的城市轨道交通短时客流预测
# 铁路客运站候车室运用计划编制研究
# 基于深度学习的城市轨道交通客流量预测研究
# An error occurred when close window
# An error occurred when close window
# 基于大数据的轨道交通客流分析
# 冀中南地区中欧班列集货中心选址研究
# 昆明东站下行系统分类线运用和配流优化研究
# 铁路站场整体式面板包裹式加筋土挡墙稳定性分析
# 单线铁路摘挂列车运行图优化
# 邯黄—和邢通道铁路运输竞争力研究
# 基于深度学习的铁路客站人群计数与应用方法研究
# 疫情防控常态下石家庄地铁乘客满意度评价研究
# 基于鲸鱼优化算法的地铁服务质量优化方法研究
# An error occurred
# 长大隧道施工有轨运输调度管理系统研究
# 基于累积前景理论的城市轨道交通中断下应急接驳公交研究
# An error occurred
# 在建长大隧道有轨运输组织方法研究
# 基于深度学习的地铁乘客拥挤度识别研究
# 邯黄铁路多站联合调度优化方法研究
# 基于视频和北斗定位的站场地面安全预警防护系统
# 疫情条件下客运站客流组织优化研究——以天津西站为例
# 城市轨道交通网络客流大数据可视化与客流预测研究
# 基于开行追踪列车的邯黄铁路通过能力加强方案研究
# 单线铁路枢纽站衔接区间运行图优化
# 铁路综合视频监控系统中目标跟踪算法及其应用技术研究
# 0 2077
# 0 0
# list index out of range
# 0 2077
# 0 243
# year month has pdfs:7500
# 基于大数据的轨道交通客流分析
# 冀中南地区中欧班列集货中心选址研究
# 昆明东站下行系统分类线运用和配流优化研究
# An error occurred
# 铁路站场整体式面板包裹式加筋土挡墙稳定性分析
# 单线铁路摘挂列车运行图优化
# 邯黄—和邢通道铁路运输竞争力研究
# 基于深度学习的铁路客站人群计数与应用方法研究
# 疫情防控常态下石家庄地铁乘客满意度评价研究
# An error occurred
# 基于鲸鱼优化算法的地铁服务质量优化方法研究
# 长大隧道施工有轨运输调度管理系统研究
# 基于累积前景理论的城市轨道交通中断下应急接驳公交研究
# 在建长大隧道有轨运输组织方法研究
# 基于深度学习的地铁乘客拥挤度识别研究
# 邯黄铁路多站联合调度优化方法研究
# 基于视频和北斗定位的站场地面安全预警防护系统
# 疫情条件下客运站客流组织优化研究——以天津西站为例
# An error occurred
# 城市轨道交通网络客流大数据可视化与客流预测研究
# 基于开行追踪列车的邯黄铁路通过能力加强方案研究
# 单线铁路枢纽站衔接区间运行图优化
# 铁路综合视频监控系统中目标跟踪算法及其应用技术研究
# 某车务段中间站调车安全风险评价与管控研究
# 铁路货运专线小运转调度优化研究
# 基于组合模型的地铁客流预测研究与应用
# 基于灰色系统理论的青岛地铁运营服务质量研究
# 基于组合站域的建成环境对网络OD客流的影响研究
# An error occurred
# 节假日城市轨道交通网络关键站点识别及短时客流预测研究
# 城市轨道交通客流分析及系统设计研究
# An error occurred
# 基于短时预测的轨道交通客流滞留线路多站点协同控制研究
# 考虑节能需求的城市轨道交通列车运行优化方法
# 早晚高峰客流下基于客流流线灵敏度的地铁站客流组织优化与评价
# 多源数据驱动下建成环境对交通小区地铁通勤出行行为的影响研究
# An error occurred
# 土地利用对轨道交通车站客流影响分析及土地属性更新
# 基于时空特征的城市轨道交通线网短时客流预测研究
# 城市轨道交通站点可达性对客流量影响研究——以西安市为例
# 大客流干扰下多层地铁网络韧性度量与优化研究
# 城市轨道交通列车跳站与客流控制协同优化研究
# An error occurred
# 大客流干扰下多层公交—地铁网络的韧性评估及优化研究
# 降雨环境下城市轨道交通客流波动规律与预测研究
# An error occurred
# 基于时空异质性的城市轨道交通车站客流影响机理研究
# 基于都市圈多层次轨道网融合的市域轨道交通客流预测方法
# An error occurred when close window
# 0 2099
# 0 0
# list index out of range
# 0 2099
# 0 243
# year month has pdfs:7500
# 某车务段中间站调车安全风险评价与管控研究
# 铁路货运专线小运转调度优化研究
# An error occurred
# 基于组合模型的地铁客流预测研究与应用
# 基于灰色系统理论的青岛地铁运营服务质量研究
# 基于组合站域的建成环境对网络OD客流的影响研究
# 节假日城市轨道交通网络关键站点识别及短时客流预测研究
# 城市轨道交通客流分析及系统设计研究
# 基于短时预测的轨道交通客流滞留线路多站点协同控制研究
# 考虑节能需求的城市轨道交通列车运行优化方法
# 早晚高峰客流下基于客流流线灵敏度的地铁站客流组织优化与评价
# An error occurred
# 多源数据驱动下建成环境对交通小区地铁通勤出行行为的影响研究
# 土地利用对轨道交通车站客流影响分析及土地属性更新
# 基于时空特征的城市轨道交通线网短时客流预测研究
# 城市轨道交通站点可达性对客流量影响研究——以西安市为例
# 大客流干扰下多层地铁网络韧性度量与优化研究
# 城市轨道交通列车跳站与客流控制协同优化研究
# 大客流干扰下多层公交—地铁网络的韧性评估及优化研究
# 降雨环境下城市轨道交通客流波动规律与预测研究
# 基于时空异质性的城市轨道交通车站客流影响机理研究
# An error occurred
# 基于都市圈多层次轨道网融合的市域轨道交通客流预测方法
# An error occurred when close window
# 基于碳中和的集装箱公铁联运成本研究
# 基于系统动力学的海铁联运集疏运系统适应性研究
# An error occurred
# 快递业空铁联运网络构建及运输路径选择
# 基于空铁联运方式旅客时间价值估算的联程客票定价研究
# 基于旅客出行特征的多种交通方式换乘方案研究
# An error occurred
# 城市客运交通枢纽选址方法研究
# 城市综合客运枢纽换乘设施规模研究
# An error occurred
# 基于多车型电动物流车的城市协同配送路径优化研究
# An error occurred
# 英国BIM标准研究
# 基于SLAM的智能物流配送车关键技术研究
# 考虑合作稳定性的多式联运合作伙伴选择研究
# 考虑服务质量的绿色多式联运路径优化研究
# 基于资源目录的交通运输信息资源共享方法
# 快递企业视角下农村物流配送自提点选址问题研究——以泾阳县域为例
# 基于机器学习的多式联运风险评估方法研究
# 基于BAM-DEA的我国省级交通运输系统碳排放动态效率及其异质性分析
# 面向越野机动的多层次通行环境模型与多目标路径规划算法研究
# 不同碳税机制下集装箱多式联运路径优化研究
# 交通基础设施数字化管理平台建设研究
# 中小城市公路客运枢纽选址分析及交通影响评价
# An error occurred when close window
# 0 2138
# 0 0
# list index out of range
# 0 2138
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2138
# 0 243
# year month has pdfs:7500
# 基于碳中和的集装箱公铁联运成本研究
# 基于系统动力学的海铁联运集疏运系统适应性研究
# 快递业空铁联运网络构建及运输路径选择
# 基于空铁联运方式旅客时间价值估算的联程客票定价研究
# An error occurred
# 基于旅客出行特征的多种交通方式换乘方案研究
# 城市客运交通枢纽选址方法研究
# 城市综合客运枢纽换乘设施规模研究
# 基于多车型电动物流车的城市协同配送路径优化研究
# An error occurred
# 英国BIM标准研究
# 基于SLAM的智能物流配送车关键技术研究
# 考虑合作稳定性的多式联运合作伙伴选择研究
# 考虑服务质量的绿色多式联运路径优化研究
# An error occurred
# 基于资源目录的交通运输信息资源共享方法
# 快递企业视角下农村物流配送自提点选址问题研究——以泾阳县域为例
# 基于机器学习的多式联运风险评估方法研究
# 基于BAM-DEA的我国省级交通运输系统碳排放动态效率及其异质性分析
# 面向越野机动的多层次通行环境模型与多目标路径规划算法研究
# 不同碳税机制下集装箱多式联运路径优化研究
# 交通基础设施数字化管理平台建设研究
# 中小城市公路客运枢纽选址分析及交通影响评价
# An error occurred when close window
# An error occurred when close window
# 城市快递中转站选址研究——以石家庄市长安区为例
# 城市交通枢纽步行网络链接空间优化——以幸福林带咸宁路为例
# 城市轨道交通站点共享单车衔接需求预测
# 城市轨道交通与常规公交的竞合关系研究
# 基于博弈—可拓云模型的石家庄市轨道交通与常规公交换乘服务评价研究
# 疫情期间大学生公共出行方式选择行为分析
# 极端气象灾害下城市公交—地铁双层网络韧性研究
# 城市群公共交通全链可达性与公平性测算方法和评价研究
# 基于人工智能的集装箱logo图像修复以及识别
# 基于深度学习的集装箱编码识别系统设计与实现
# 考虑节点换装的中欧集装箱多式联运路径优化研究
# An error occurred
# 考虑弹性波传播路径的管道声发射损伤识别和空间定位研究
# An error occurred
# 基于超声导波技术的管道空间识别方法研究
# 基于FLUENT的管输临界不淤流速预测研究
# 自主水下管道巡检机器人的设计
# 严苛条件下客运索道传动系统运行故障智能识别方法研究
# 昆山市农村公路养护管理问题研究
# An error occurred
# S高速数据资源运营公司商业模式设计研究
# 基于熵权法-BP神经网络模型的网络货运经营者信用风险预测研究
# LY公司工程师绩效考核体系优化研究
# An error occurred
# An error occurred when close window
# 0 2160
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2160
# 0 243
# year month has pdfs:7500
# 基于系统动力学的高速公路PPP项目资金缺口政府补助测算研究
# 协同治理视角下高速公路沿线土地综合整治问题研究——以崇左至爱店口岸段试点项目为例
# 高速公路PPP项目协同治理机制研究——以E项目为例
# 基础设施公募REITs融资模式研究——以浙商沪杭甬REIT为例
# 整体性治理视角下“路长制”运行中的问题及对策研究——以广元市朝天区为例
# T市网络货运企业税收负担分析及应对措施
# HB高速客服中心服务质量优化策略研究
# G公司销售绩效评价方法优化研究
# 基于多主体博弈的高速公路货车差异化收费方案研究
# 基于高速公路“服务区+物流”模式的新型物流网络优化研究
# 转企改制背景下XF高速公路公司中层管理人岗匹配研究
# 沪杭甬高速REITs融资案例研究
# H高速公路集团资金集中管理效果评价研究
# S市公路工程重点项目建设政府监管研究
# An error occurred
# 基于出行剩余理论的定制客运停靠站点选择机理研究
# 高速公路主题型服务区顾客冲动消费行为影响研究
# 长江经济带公路运输效率测度及其空间溢出效应研究
# 基于BOT模式的JH高速公路运营期风险管理研究
# BY集团定制客运客户开发研究
# 基于离散元方法的沥青混合料抗裂性能研究
# An error occurred
# An error occurred when close window
# 基于改进YOLO网络的公路路面病害检测方法研究
# 基于表面能理论的沥青路面灌缝胶粘附性研究
# 碱激发胶凝材料稳定碎石耐久性研究
# 基于SBS-T的干法改性沥青混合料路用性能及影响因素研究
# 基于细观结构协同效应的沥青混凝土低温开裂行为研究
# 公路滑坡敏感性评价方法研究——以广西壮族自治区为例
# 基于多传感器信息融合的洒水车行人防喷溅系统研究
# 基于深度学习及图像处理的沥青路面裂缝检测方法研究
# 基于深度学习的路面裂缝检测算法研究与应用
# 预应力互锚式挡土墙结构受力特征与应用研究
# 土工格室加筋在高填方挡墙路基中的作用机制研究
# 开孔土工格室的力学性能及其在高填方路基中的适用性研究
# 白云质石灰岩沥青混合料组成设计与应用研究
# 多聚磷酸与聚氨酯复合改性沥青的机理及路用性能研究
# 快硬微膨胀高抗裂养护材料制备及性能研究
# 路桥过渡段沥青路面结构裂缝扩展与刚度协调研究
# 基于倾斜摄影和BIM技术的高速公路施工监测研究
# 季铵盐/壳聚糖复合物用于乳化沥青的研究
# 基于单螺杆连续挤出制备超活化胶粉及其改性沥青性能的研究
# 基于深度神经网络的道路缺陷识别
# 0 2199
# 0 243
# year month has pdfs:7500
# 碳纤维-石墨导电沥青混合料的碳纤维分散程度研究
# 橡胶沥青混合料的级配优化设计与工程应用
# 电动绿篱机修剪障碍检测与控制系统研究
# An error occurred
# 基于深度学习的混凝土道路裂缝图像检测方法研究
# 基于表面改性的玉米秸秆纤维沥青胶浆性能研究
# An error occurred
# 土工格栅加筋对路基土侵蚀过程影响的透明土材料试验研究
# 沥青路面典型隐性病害三维探地雷达识别应用研究
# An error occurred
# 温度与橡胶粉掺量对橡胶沥青阻尼降噪性能研究
# RAP冷再生技术在微表处的应用研究
# 内蒙古西部地区SMA沥青路面合理结构研究
# 动态荷载下的沥青混合料疲劳性能研究
# 高寒地区改性沥青混合料性能研究
# An error occurred
# 农牧区水泥路面病害检测算法研究
# 沥青路面隐形病害的三维雷达图谱特征分析与应用
# 煤直接液化残渣复合高粘改性沥青开发及性能研究
# 基于全景图像语义分割的农牧区水泥混凝土路面病害检测研究
# An error occurred
# 沥青混合料四点弯曲疲劳特性数值模拟研究
# 煤直接液化残渣复合改性沥青混合料路用性能研究
# 基于Web与Andriod平台的农村公路养护信息交互系统的设计与研发
# An error occurred
# 动载作用下沥青混合料永久变形特性研究
# An error occurred when close window
# 基于Andriod平台的路面病害无损检测系统
# 高碳铬铁渣稀浆封层路用性能研究
# 农牧区道路边沟病害智能化检测研究
# 温度对橡胶颗粒沥青混合料阻尼降噪的影响分析
# 基于机器视觉的沥青路面坑槽三维重建与分析研究
# 玻璃纤维沥青混合料路用性能多尺度研究
# 大连地区植物根系固土作用及护坡稳定性研究
# 辽东滨海地区大型岩质边坡地震响应研究
# 锚杆联合植物根系护坡的综合评价研究
# 硅灰石对水泥基复合材料性能的影响
# 大别山区森林小流域道路侵蚀泥沙的坡面传输路径特征及其影响
# 基于寒区气候特点的沥青路面低温抗裂关键技术研究
# 酸雨对沥青及混合料性能影响与劣化机理多尺度研究
# 多聚磷酸/SBS复合生物质改性沥青材料组成设计及力学性能研究
# 旧水泥混凝土路面共振碎石化仿真及工程应用研究
# An error occurred
# 基于半圆弯曲试验的大粒径沥青混合料断裂及疲劳性能研究
# 公路边坡工程施工期风险辨识及其应用研究
# 净味沥青性能及除味机理研究
# An error occurred
# 废旧电池改性沥青效果评估、微观机理及其混合料性能研究
# An error occurred
# 填石料压实评价方法和变形性能研究
# An error occurred when close window
# An error occurred when close window
# 0 2238
# 0 243
# year month has pdfs:7500
# 基于非零应矩理论的隧道路面结构分析方法及试验研究
# 竖向荷载及强降雨作用下粗粒土填料挡墙土压力演化规律及稳定性研究
# 基于数据挖掘的市政道路工程投资估算模型研究
# 路面高性能机制砂水泥混凝土组成设计与性能研究
# 基于离散元法的避险车道集料特性对失控车辆停车过程的影响研究
# 水性环氧树脂/SBR复合改性乳化沥青的制备及其薄层罩面性能研究
# 用作路堤填料的废弃铸造砂力学特性试验研究
# 基于深度学习的路面病害检测研究
# 基于深度学习的路面质量检测研究
# 泡沫轻质土的力学性能及其在道路工程中的应用研究
# 公路工程施工安全风险评价及措施研究——以G104静霸公路段改建工程为例
# 蒙屏高速公路边坡锚固混凝土框格梁受力现场试验研究
# 玄武岩-聚乙烯醇混杂纤维半刚性基层抗裂性能研究
# 内掺法疏水改性水泥基材料制备及性能研究
# 京新高速梧木段极端温度下路面结构病害风险区划研究
# RET-SBR复合改性沥青及其混合料路用性能研究
# An error occurred
# 装配式水泥混凝土路面板块结构与施工关键技术优化研究
# 基于分子动力学的沥青二次再生机理及性能评价研究
# An error occurred
# 城市垃圾焚烧飞灰与铁尾矿在沥青路面基层中的应用研究
# 基于U-Net的路面裂纹分割算法研究
# An error occurred when close window
# 容东片区窄路密网模式分析与道路设计方案实践
# M高速公路沥青路面养护质量动态优化控制系统研究
# 基于BIM+GIS的道路改建设计辅助决策系统的研发
# An error occurred
# 基于Transformer网络的沥青路面裂缝筛选与分割
# 高速公路沥青路面使用性能评价及预防性养护对策研究
# 基于改进YOLOv5的路面缺陷检测系统设计
# An error occurred
# 电气化公路光储系统的能量管理研究
# 光伏电气化公路供电系统动态潮流优化研究
# An error occurred
# 基于DCT试验的沥青混合料抗裂性能综合评价及影响因素分析
# 基于SCB试验的沥青混合料评价指标选择及开裂过程模拟
# 基于物元理论与目标检测算法的道路施工进度管理方法及系统研究
# 新元高速公路市政化改造对既有道路网影响及新区快速路布局研究
# 活性炭复合土工布加筋煤矸石路基力学行为及污染物处理研究
# 连续压实滚轮振动响应特性及影响因素研究
# 西南山区高填方斜坡路基变形和稳定性控制技术
# 基于高密度电法的高速公路路基病害无损检测方法及应用研究
# 交通荷载作用下尾矿砂路基动力特性研究
# 基于加筋效应的局部塌陷区上覆路基变形机理试验研究
# An error occurred
# 干湿循环下包边尾矿砂路堤边坡稳定性研究
# An error occurred
# 桩承式加筋路堤土拱效应模型试验与数值模拟研究
# An error occurred
# An error occurred when close window
# 0 2278
# 0 243
# year month has pdfs:7500
# 容东片区窄路密网模式分析与道路设计方案实践
# M高速公路沥青路面养护质量动态优化控制系统研究
# 基于BIM+GIS的道路改建设计辅助决策系统的研发
# An error occurred
# 基于Transformer网络的沥青路面裂缝筛选与分割
# An error occurred
# 高速公路沥青路面使用性能评价及预防性养护对策研究
# 基于改进YOLOv5的路面缺陷检测系统设计
# An error occurred
# 电气化公路光储系统的能量管理研究
# 光伏电气化公路供电系统动态潮流优化研究
# An error occurred
# 基于DCT试验的沥青混合料抗裂性能综合评价及影响因素分析
# 基于SCB试验的沥青混合料评价指标选择及开裂过程模拟
# An error occurred
# 基于物元理论与目标检测算法的道路施工进度管理方法及系统研究
# 新元高速公路市政化改造对既有道路网影响及新区快速路布局研究
# An error occurred
# 活性炭复合土工布加筋煤矸石路基力学行为及污染物处理研究
# 连续压实滚轮振动响应特性及影响因素研究
# 西南山区高填方斜坡路基变形和稳定性控制技术
# 基于高密度电法的高速公路路基病害无损检测方法及应用研究
# 交通荷载作用下尾矿砂路基动力特性研究
# 基于加筋效应的局部塌陷区上覆路基变形机理试验研究
# 干湿循环下包边尾矿砂路堤边坡稳定性研究
# 桩承式加筋路堤土拱效应模型试验与数值模拟研究
# An error occurred when close window
# 路堑风致积雪分布演化规律及断面影响研究
# 基于胎-路耦合作用的沥青路面结构细观力学行为分析
# 铁尾矿在沥青混合料中的适用性研究
# 多年冻土区路基冷负荷计算模型及人工制冷防融沉效果研究
# 通定高速公路湿陷性黄土边坡综合风险研究
# 透水混凝土路面清理效果及透水寿命预测研究
# 车载作用下检查井周围沥青路面响应特性分析
# An error occurred
# 未来气候条件下河北省路面全寿命周期费用分析研究
# 基于离散元法含有微裂缝沥青路面车-路耦合动力学响应
# An error occurred
# 城市道路工程全寿命周期碳排放测算及多情景模拟预测研究
# 基于分子动力学模拟的高掺量橡胶改性沥青耐老化性能研究
# 基于碰撞仿真的路桥过渡段新型护栏结构优化设计
# 基于颗粒流的非均质水泥稳定碎石细观力学研究
# 不同老化方式对髙掺量橡胶改性沥青及其混合料的性能影响
# 煤矸石粉改性橡胶沥青混合料路用性能研究
# An error occurred
# 基于离散元法的沥青路面反射裂缝扩展规律研究
# 基于深度学习的路面裂缝检测及分割方法研究
# 斜坡软土路基的变形特征及控制技术研究
# 基于XFEM的多场耦合作用下沥青路面反射裂缝疲劳扩展研究
# An error occurred
# 振动压路机非线性特性响应及振动控制研究
# An error occurred when close window
# 0 2299
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2299
# 0 243
# year month has pdfs:7500
# 路堑风致积雪分布演化规律及断面影响研究
# 基于胎-路耦合作用的沥青路面结构细观力学行为分析
# 铁尾矿在沥青混合料中的适用性研究
# An error occurred
# 多年冻土区路基冷负荷计算模型及人工制冷防融沉效果研究
# 通定高速公路湿陷性黄土边坡综合风险研究
# 透水混凝土路面清理效果及透水寿命预测研究
# 车载作用下检查井周围沥青路面响应特性分析
# 未来气候条件下河北省路面全寿命周期费用分析研究
# 基于离散元法含有微裂缝沥青路面车-路耦合动力学响应
# 城市道路工程全寿命周期碳排放测算及多情景模拟预测研究
# 基于分子动力学模拟的高掺量橡胶改性沥青耐老化性能研究
# 基于碰撞仿真的路桥过渡段新型护栏结构优化设计
# An error occurred
# 基于颗粒流的非均质水泥稳定碎石细观力学研究
# 不同老化方式对髙掺量橡胶改性沥青及其混合料的性能影响
# An error occurred
# 煤矸石粉改性橡胶沥青混合料路用性能研究
# 基于离散元法的沥青路面反射裂缝扩展规律研究
# An error occurred
# 基于深度学习的路面裂缝检测及分割方法研究
# 斜坡软土路基的变形特征及控制技术研究
# 基于XFEM的多场耦合作用下沥青路面反射裂缝疲劳扩展研究
# 振动压路机非线性特性响应及振动控制研究
# An error occurred when close window
# An error occurred when close window
# 基于BIM的矮塔斜拉转体桥施工监测技术研究
# An error occurred
# 无人机贴近摄影测量的桥梁表观病害检测方法研究
# 冰盖下组合桥墩局部冲刷特性与新型防冲措施防护机理研究
# 基于型钢砼材料的斜拉桥桥塔抗震性能研究
# 钢绞线拉索式防落梁装置抗冲击性能试验研究
# 铝合金桁架人行桥人致振动与减振
# 部分充填式窄幅钢箱-砼组合梁负弯矩下刚度分析
# 部分充填式窄幅钢箱-UHPC组合梁抗裂性能研究
# 空洞对双圆盾构隧道地震易损性的影响研究
# 含裂纹桥梁拉索高强钢丝的腐蚀断裂机理与受力性能分析
# 基于编码图的桥梁异常数据检测及损伤状态识别
# 600 m混凝土拱桥主拱圈组合法施工研究
# An error occurred
# 劲性骨架拱桥主拱圈混凝土分环浇筑的环间界面受力性能研究
# 柔性及刚性铺装正交异性钢桥面板疲劳性能评估与结构优化
# 多跨拱桥面内力学特性的传递矩阵法研究
# 桥梁施工安全管理评价研究
# UHPC-T形梁横向力学性能分析
# 钢管混凝土拱桥抗震承载力和两层面优化设计
# An error occurred
# 基于非线性能量阱的斜拉索参数振动抑制研究
# 新型叠合梁独塔斜拉桥力学性能与试验研究
# An error occurred when close window
# 0 2339
# 0 243
# year month has pdfs:7500
# 路堑风致积雪分布演化规律及断面影响研究
# 千米级新型桁架拱桥力学性能研究及试设计
# 新型悬索桥力学性能研究及试验验证
# 桥梁钢的疲劳裂纹扩展性能：应力比、微观组织及单峰过载的影响
# An error occurred
# 连续刚构桥中跨跨中增设桥墩加固法的加固效应研究
# 采用黏滞阻尼器的自复位桥梁体系抗震性能研究
# 基于材料劣化的近海桥梁抗震性能研究
# 1000t提梁机的结构设计与性能分析
# 基于数字图像相关技术的桥梁结构变形测试研究
# 超大吨位箱梁预制场功能区规划与制（存）梁台座方案设计
# An error occurred
# 规避频率禁区的桥梁结构抗震加固优化设计方法研究
# An error occurred
# 基于车桥耦合振动分析的钢—混组合梁桥冲击系数比较研究
# An error occurred
# 桥梁转体施工防倾覆参数预警及可视化系统设计
# 基于模糊PID的桥梁转体施工液压系统压力控制研究
# 公路装配式预应力小箱梁纵向开裂机理研究
# 基于柳州桥梁文化的旅游文创研究与应用
# 非对称单索面钢箱梁独塔斜拉桥地震响应分析
# 预应力简支梁相似模型研究
# An error occurred
# 桥塔遮风效应对车-桥系统气动特性影响
# 预应力混凝土连续梁桥疲劳强度的有限元分析
# An error occurred when close window
# An error occurred when close window
# 非对称独塔转体斜拉桥成桥索力优化与合理施工状态研究
# 钢桁架铁路桥梁疲劳强度的有限元分析
# 高速铁路钢箱系杆拱桥的疲劳特性分析
# 基于多点动挠度的桥梁结构损伤识别研究
# 地震动扭转分量对大跨度斜拉桥易损性影响
# 基于多孔-裂隙模型的桥梁主缆内部场数值分析与实验
# 悬索桥主缆通风数据分析与除湿状态评估研究
# 悬索桥主缆除湿系统参数优化
# EPS板减载条件下高填方箱涵长期受力特性与减载效果评价
# 基于优化深度网络模型的高铁架桥机安全制动系统故障诊断研究
# 基于三维胎—路细观耦合模型的沥青铺装层动力学行为研究
# （42.85+72+72+75+42.85）m连续梁桥施工监控研究与实践
# 重庆地铁（43.6+45.2+43.6）m连续刚构桥地震响应分析
# 某双塔三跨连续钢桁梁悬索桥施工过程抗风稳定性分析
# 起重装备制动系统图像状态识别及动力学分析
# 铁路应急抢修桥梁液压自适应支座控制策略研究
# 基于机器视觉的桥梁智能检测系统设计及研究
# 波形钢腹板连续梁桥同步异位施工力学性能精细化分析
# 北江特大桥施工BIM技术深化应用研究
# 装配式空心板桥铰缝损伤与横向预应力加固关键技术研究
# 0 2375
# 0 243
# year month has pdfs:7500
# 非对称独塔转体斜拉桥成桥索力优化与合理施工状态研究
# 钢桁架铁路桥梁疲劳强度的有限元分析
# 高速铁路钢箱系杆拱桥的疲劳特性分析
# 基于多点动挠度的桥梁结构损伤识别研究
# 地震动扭转分量对大跨度斜拉桥易损性影响
# 基于多孔-裂隙模型的桥梁主缆内部场数值分析与实验
# 悬索桥主缆通风数据分析与除湿状态评估研究
# 悬索桥主缆除湿系统参数优化
# EPS板减载条件下高填方箱涵长期受力特性与减载效果评价
# An error occurred
# 基于优化深度网络模型的高铁架桥机安全制动系统故障诊断研究
# 基于三维胎—路细观耦合模型的沥青铺装层动力学行为研究
# （42.85+72+72+75+42.85）m连续梁桥施工监控研究与实践
# 重庆地铁（43.6+45.2+43.6）m连续刚构桥地震响应分析
# 某双塔三跨连续钢桁梁悬索桥施工过程抗风稳定性分析
# An error occurred
# 起重装备制动系统图像状态识别及动力学分析
# 铁路应急抢修桥梁液压自适应支座控制策略研究
# 基于机器视觉的桥梁智能检测系统设计及研究
# An error occurred
# 波形钢腹板连续梁桥同步异位施工力学性能精细化分析
# 北江特大桥施工BIM技术深化应用研究
# 装配式空心板桥铰缝损伤与横向预应力加固关键技术研究
# An error occurred
# An error occurred when close window
# 大跨人行悬索桥纵横加劲主梁涡振特性与气动控制措施研究
# 悬索桥吊索腐蚀及疲劳寿命分析
# 采用盆式橡胶支座的矮墩连续梁桥地震易损性分析
# 波形钢腹板连续梁桥施工监控BIM平台的设计与应用
# 预应力混凝土箱型梁桥参数化建模的研究与施工监控平台开发
# 跨淳河路大桥（60+100+100+60）m连续梁施工监控研究与实践
# 基于车桥耦合振动分析的梁式桥动力响应及损伤识别研究
# 钢—混凝土组合梁桥损伤识别研究
# 采用UHPC/ECC后浇连接的预制墩柱抗震性能研究
# 沥青桥面铺装层缩尺模型裂缝扩展行为研究
# 多年冻土区桥梁钻孔灌注桩工作性态研究
# 高速铁路矮塔斜拉桥施工监控研究
# 车辆荷载作用下变截面连续箱梁桥动力响应及冲击系数分析
# 斜拉桥损伤诊断的有限元建模与数据提取方法研究
# 宁盐上行联络线（72+120+72）m连续梁桥施工监控研究与实践
# 高铁桥梁钢筋施工BIM技术深化应用研究
# 中承式人行悬索桥的力学性能及与下承式悬索桥的对比分析
# 极端竖向偏载下独柱墩桥抗倾覆性能与提升技术研究
# 铁路矮塔斜拉桥日照温度场及温度效应分析
# 基于索力监测的斜拉索损伤识别研究
# An error occurred when close window
# 0 2398
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2398
# 0 243
# year month has pdfs:7500
# 基于BIM的矮塔斜拉转体桥施工监测技术研究
# 千米级新型桁架拱桥力学性能研究及试设计
# 新型悬索桥力学性能研究及试验验证
# 桥梁钢的疲劳裂纹扩展性能：应力比、微观组织及单峰过载的影响
# 连续刚构桥中跨跨中增设桥墩加固法的加固效应研究
# 采用黏滞阻尼器的自复位桥梁体系抗震性能研究
# 基于材料劣化的近海桥梁抗震性能研究
# 1000t提梁机的结构设计与性能分析
# 基于数字图像相关技术的桥梁结构变形测试研究
# 超大吨位箱梁预制场功能区规划与制（存）梁台座方案设计
# 规避频率禁区的桥梁结构抗震加固优化设计方法研究
# 基于车桥耦合振动分析的钢—混组合梁桥冲击系数比较研究
# 桥梁转体施工防倾覆参数预警及可视化系统设计
# 基于模糊PID的桥梁转体施工液压系统压力控制研究
# 公路装配式预应力小箱梁纵向开裂机理研究
# An error occurred
# 基于柳州桥梁文化的旅游文创研究与应用
# An error occurred
# 非对称单索面钢箱梁独塔斜拉桥地震响应分析
# 预应力简支梁相似模型研究
# An error occurred
# 桥塔遮风效应对车-桥系统气动特性影响
# 预应力混凝土连续梁桥疲劳强度的有限元分析
# An error occurred when close window
# 沥青桥面铺装车辙动态响应与水损害模拟研究
# 装配式变截面波形钢腹板组合箱梁横向受力性能研究
# 栏杆构造对流线型箱梁涡激振动性能影响的试验研究
# 不同行人作用模型下的人行桥横向振动研究
# （120+3×180+120）m公铁两用大桥主引桥碰撞效应及控制
# 滦河特大桥120m钢箱系杆拱桥设计研究及施工监控
# 独柱墩桥梁抗震性能与抗震加固措施研究
# 基于分级耗能型板式铅阻尼器半刚接整体桥的纵向抗震性能研究
# 带耗能横梁的双薄壁摇摆桥墩拟静力试验及抗震韧性分析
# 车-桥耦合作用下受损梁体动力特性分析
# 沥青摊铺下波形钢腹板箱梁温度场及桥面板温度效应研究
# 基于温度作用-时空劣化的大跨钢桁梁斜拉桥服役性态演化规律研究
# 基于不同塔梁形式下多塔斜拉桥的力学性能分析
# 基于数据挖掘的斜拉桥损伤诊断模型算法研究
# 附加变形对大跨度公铁两用斜拉桥车桥响应影响分析
# 基于BIM的连续梁桥零号块支架设计技术研究与应用
# 节段预制拼装变截面波形钢腹板组合箱梁抗剪性能研究
# 波形钢腹板PC组合槽型梁动力性能研究
# 青榄海特大桥施工BIM技术深化应用研究
# 钢桥面板焊接残余应力数值模拟及影响因素分析
# An error occurred when close window
# 0 2437
# 0 243
# year month has pdfs:7500
# 基于Andriod平台的路面病害无损检测系统
# 拱桥半刚性吊杆更换关键技术研究
# 采用摩擦摆支座的矮墩连续梁桥地震易损性分析
# 设置不同耗能横梁的双薄壁摇摆桥墩抗震性能试验研究及其易损性评价
# （42.85+72+72+75+42.85）m连续梁桥地震响应分析
# 曲线连续双箱组合梁桥静力性能有限元分析
# Rayleigh波对跨河谷拱桥地震动输入和地震反应影响研究
# 长联多跨波形钢腹板连续梁桥施工监控关键技术研究
# 基于BIM与VR的桥梁施工风险管理与安全仿真研究
# 基于温度场和胎—路接触应力的桥面铺装动力学行为分析
# 拴结式桥梁检查车结构优化设计与履带行走系统研究
# 斜交框构桥下穿重载铁路施工监测及变形特性分析
# 索承式人行悬索桥的受力行为及人致振动研究
# 基于索力监测的系杆拱桥吊杆损伤识别研究
# 斜拉桥损伤诊断模型验证与性能提升方法研究
# 新型材料桥面板人行悬索桥力学性能研究
# 南崇铁路（60+100+60）m连续梁桥地震响应分析
# 考虑滑道不平顺条件下大跨度箱梁桥转体安全性能研究
# 基于增量动力分析的铁路超高墩地震易损性分析
# 铁路连续梁桥基于自复位防屈曲支撑的纵向抗震性能研究
# An error occurred when close window
# An error occurred when close window
# 既有铁路T梁整孔换架特种运输车力学分析及结构优化研究
# 连续梁桥正负刚度联动控制减震装置应用设计及减震性能分析
# 车—路—桥耦合振动系统建模方法研究
# 基于格拉姆角场和卷积神经网络的斜拉索疲劳损伤识别研究
# 锁定-粘滞阻尼器系统在大跨悬索桥的应用
# 低收缩高韧性混杂纤维增强桥面铺装混凝土性能研究
# An error occurred
# 基于计算机视觉的桥梁结构损伤识别方法研究
# 基于实测温度场钢箱梁温度效应分析
# 考虑曲线梁桥简化分析方法的大件运输载重限值研究
# 柔性气动措施风致振动响应及其运用
# 桥梁缆索锚固区图像增强与异常检测方法研究
# 爆炸荷载作用下钢-混凝土组合梁桥动态力学响应及损伤机理研究
# 基于经验模态分解的孔道压浆质量冲击回波法分析
# 隔涡板对分离式双箱梁涡振性能的影响研究
# 预应力锚索框架梁加固拱桥台后边坡的稳定性研究
# 基于本征正交分解和动态模态分解的分离式双箱梁涡振特性分析
# 桥墩病害攀爬检测环形视觉扫描作业机器人系统
# 冲击作用下钢筋混凝土梁损伤特征与剩余承载性能研究
# 考虑焊接残余应力的钢桁桥整体节点疲劳性能研究
# 基于系留式飞爬机器人的桥梁底面裂缝检测平台研究
# 0 2477
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2477
# 0 243
# year month has pdfs:7500
# 既有铁路T梁整孔换架特种运输车力学分析及结构优化研究
# 连续梁桥正负刚度联动控制减震装置应用设计及减震性能分析
# 车—路—桥耦合振动系统建模方法研究
# 基于格拉姆角场和卷积神经网络的斜拉索疲劳损伤识别研究
# 锁定-粘滞阻尼器系统在大跨悬索桥的应用
# 低收缩高韧性混杂纤维增强桥面铺装混凝土性能研究
# 基于计算机视觉的桥梁结构损伤识别方法研究
# 基于实测温度场钢箱梁温度效应分析
# An error occurred
# 考虑曲线梁桥简化分析方法的大件运输载重限值研究
# 柔性气动措施风致振动响应及其运用
# 桥梁缆索锚固区图像增强与异常检测方法研究
# An error occurred
# 爆炸荷载作用下钢-混凝土组合梁桥动态力学响应及损伤机理研究
# 基于经验模态分解的孔道压浆质量冲击回波法分析
# 隔涡板对分离式双箱梁涡振性能的影响研究
# An error occurred
# 预应力锚索框架梁加固拱桥台后边坡的稳定性研究
# 基于本征正交分解和动态模态分解的分离式双箱梁涡振特性分析
# 桥墩病害攀爬检测环形视觉扫描作业机器人系统
# An error occurred
# 冲击作用下钢筋混凝土梁损伤特征与剩余承载性能研究
# 考虑焊接残余应力的钢桁桥整体节点疲劳性能研究
# 基于系留式飞爬机器人的桥梁底面裂缝检测平台研究
# An error occurred when close window
# 爆炸荷载作用下CFRP-钢复合结构数值模拟研究
# 曲线连续梁桥动力响应分析及支座脱空病害识别方法研究
# 耐候钢-混凝土组合加劲梁悬索桥极限承载力退化及预防性养护研究
# 预应力UHPC-NC组合梁设计理论及优化设计方法研究
# 基于深度学习的桥梁裂缝检测算法的研究
# 基于变分模态分解的简支梁结构裂缝损伤识别方法研究
# 移动荷载作用下基于统计分析的斜拉桥拉索损伤识别研究
# GFRP组合桁腹梁桥力学性能研究
# 基于BIM和三维激光扫描的桥梁钢筋施工监控方法研究
# 考虑来流特性的小宽高比H型吊杆风振特性研究
# 高温后钢-ECC组合梁竖向抗剪承载力分析
# 碳纤维索锚固系统蠕变性能及预测模型研究
# 大跨径石拱桥抗震性能分析及FRP加固研究
# 城市桥梁高强螺栓技术状况评定与维护技术研究
# 敞开式TBM底部清渣系统设计研究
# An error occurred
# 基于联合强度的黄土隧道围岩弹塑性分析解析解
# 基于滑坡区不同条件下隧道衬砌的竖向承载特性模型试验及评价
# 上覆黄土的深埋红层隧道施工诱发建筑物开裂机理研究
# 时速400公里高铁隧道微气压波特性及缓解措施研究
# 岩溶地层溶洞对隧道衬砌的影响研究
# 0 2499
# 0 243
# year month has pdfs:7500
# 砂卵石地层盾构掘进效能研究
# 超大断面小净距隧道中夹岩柱力学特性及施工技术研究
# 公轨共建明挖隧道坑中坑围护结构受力变形特性研究
# 隧道盾构穿越施工对邻近既有隧道变形影响研究
# TBM刀盘驱动传动系统动力学建模及其动态性能优化研究
# An error occurred
# 基于深度学习的隧道内异物检测研究与应用
# 基于迁移流形的盾构机主驱动轴承故障诊断方法研究
# 极软弱围岩隧道支护结构开裂机理及防治技术研究
# An error occurred
# 双层盾构公路隧道火灾烟气蔓延及控制研究
# 城市隧道智能运维阶段机电设备失效风险评估研究
# 基于深度学习的隧道衬砌混凝土工况研究
# X隧道工程质量管理改善研究
# 隧道衬砌裂缝漏水砂诱发的地层塌陷试验研究及数值模拟
# 高速列车通过隧道时气动特性的研究
# 火源位置对隧道竖井烟囱效应极限高度影响数值模拟研究
# 软弱地层条件下大断面铁路隧道施工围岩变形风险评估
# 寒区隧道洞口处边坡温度场及稳定性分析
# 最不利隧道长度下列车运行压力波气动载荷特性分析
# 服役期铁路隧道病害监测报警和专家诊断系统
# 隧道衬砌破损诱发砂砾石层塌陷试验及数值模拟研究
# An error occurred
# An error occurred when close window
# 装配式框架隧道环向卯榫接头受力性能研究
# 复合悬浮隧道抑振体系的水动力特性研究
# 海底隧道盾构法施工安全风险评价研究
# An error occurred
# 软岩隧道大断面施工掌子面稳定性及超前支护参数优化研究
# 循环冻融作用下缓倾角层状围岩隧道变形破坏机制研究
# 基于贝叶斯理论的山岭隧道施工坍塌风险评估及预警研究
# An error occurred
# 盾构掘进对浅基础建筑物的扰动及影响分区研究——以上海典型软土区为例
# 隧道喷射混凝土溶蚀特性研究
# 基于机器学习的山岭隧道施工坍塌风险评估研究
# FRP筋刚性桁架增强下新型三管悬浮隧道抑振性能研究
# 基于Vague集模糊决策模型的隧道工程风险管理方法
# 旋转对称机械固有特性研究
# 基于岩机耦合的TBM施工地质识别算法研究
# 复杂场地盾构隧道纵向抗震分析的一种简化方法
# 基于初始损伤的喷射混凝土抗碳化性能研究
# 大断面主隧道与车行横通道交叉处模拟优化分析
# 考虑初始损伤的喷射混凝土受复合盐侵蚀性能研究
# 隧道衬砌用喷射混凝土干缩与徐变性能
# 基于综合超前地质预报技术的隧道模型构建及力学特征研究
# An error occurred
# 基于Mask R-CNN的公路隧道裂缝检测研究
# 0 2538
# 0 243
# year month has pdfs:7500
# 装配式框架隧道环向卯榫接头受力性能研究
# 复合悬浮隧道抑振体系的水动力特性研究
# 海底隧道盾构法施工安全风险评价研究
# 软岩隧道大断面施工掌子面稳定性及超前支护参数优化研究
# 循环冻融作用下缓倾角层状围岩隧道变形破坏机制研究
# 基于贝叶斯理论的山岭隧道施工坍塌风险评估及预警研究
# 盾构掘进对浅基础建筑物的扰动及影响分区研究——以上海典型软土区为例
# An error occurred
# 隧道喷射混凝土溶蚀特性研究
# 基于机器学习的山岭隧道施工坍塌风险评估研究
# An error occurred
# FRP筋刚性桁架增强下新型三管悬浮隧道抑振性能研究
# 基于Vague集模糊决策模型的隧道工程风险管理方法
# An error occurred
# 旋转对称机械固有特性研究
# 基于岩机耦合的TBM施工地质识别算法研究
# An error occurred
# 复杂场地盾构隧道纵向抗震分析的一种简化方法
# 基于初始损伤的喷射混凝土抗碳化性能研究
# An error occurred
# 大断面主隧道与车行横通道交叉处模拟优化分析
# 考虑初始损伤的喷射混凝土受复合盐侵蚀性能研究
# 隧道衬砌用喷射混凝土干缩与徐变性能
# 基于综合超前地质预报技术的隧道模型构建及力学特征研究
# 基于Mask R-CNN的公路隧道裂缝检测研究
# An error occurred when close window
# 卸载波作用下既有隧道的界面动态响应
# TBM穿越断层破碎带的施工风险评估及控制对策
# 考虑围岩参数空间变异性的隧道衬砌结构动力响应规律研究
# 隧道衬砌结构多病害检测与智能识别
# 蠕滑错动下穿越双断层隧道结构力学响应特征与新型支护结构体系研究
# 跨断层海底隧道盾构管片接头力学特性及地震响应研究
# 改良橡胶混凝土隧道韧性层及其减震性能研究
# 非一致地震作用下的跨断层海底隧道地震响应分析
# An error occurred
# 钻爆开挖下片岩隧道松动圈演变规律研究
# 高速铁路隧道裂损衬砌在气动荷载作用下的动力响应分析
# 敞开式TBM施工地质风险评估及控制的研究
# 长大隧道火灾烟气蔓延特性及人员疏散安全性分析
# 往复注浆泵综合试验台的设计与实现
# 基于UWB的隧道内人员定位系统设计研究
# 膨胀岩隧道变形特征及对策研究
# 彝良隧道洞口段浅埋偏压错台小净距隧道围岩压力与施工力学效应研究
# 裂缝缺陷下电缆隧道承载特性评价技术研究
# 隧道洞口“零刷坡”顶进法进洞关键技术研究
# 铁路隧道复合式衬砌极限状态设计方法研究
# 地震作用下跨断层隧道结构动力响应规律与新型抗减震措施研究
# An error occurred
# 0 2559
# 0 243
# year month has pdfs:7500
# 高地应力TBM隧道变形特征及控制技术研究
# 强降雨条件下岩溶隧道衬砌结构力学响应特征研究
# 层状软岩隧道大变形分级方法深化研究
# 新建高铁隧道近距上跨既有高铁隧道力学响应分析研究
# 海陆交互相典型地层渣土改良及盾构掘进参数研究
# 隧道衬砌厚度不足缺陷力学行为与改性ECC加固性能研究
# 岩体及掘进参数对TBM刀盘荷载的影响规律研究
# 隧道衬砌波纹钢板加固的注浆密实度对衬砌力学性能影响的研究
# 复杂艰险地区铁路隧道施工安全韧性评估及提升策略研究
# An error occurred
# 山区隧道洞口周边施工场地布局多目标优化研究
# 岩溶隧道涌水后长期积水围岩力学性能与稳定性研究
# 中梁山隧道安全施工技术研究
# An error occurred
# TBM集群掘进性能分析与预测
# An error occurred
# 盾构机关键液压元件故障仿真分析与状态检测系统设计
# 掘进机盘形滚刀带载跑合试验台的研制
# An error occurred
# 双螺旋隧道驾驶负荷研究
# An error occurred
# 基于驾驶行为和视觉特性的螺旋隧道反光环作用效果评估
# 基于驾驶人特性的螺旋隧道驾驶行为风险研究
# 隧道照明环境变化对驾驶疲劳的调节作用研究
# An error occurred
# 隧道有轨运输障碍物检测与预警方法研究
# An error occurred when close window
# An error occurred when close window
# 电缆隧道裂损机理与分级方法研究
# An error occurred
# 蠕滑断层错动作用下铰接—柔性层韧性支护结构及其主要参数优化研究
# 地下洞室分岔部位通风局部阻力及火灾烟气流动特性研究
# 层状岩宏观性能及围岩稳定性研究
# 彝良隧道穿越黑老林断层破碎带围岩稳定性分析和治理措施研究
# 炳辉隧道卢房沟断层破碎带突涌水成因及治理措施研究
# 在役浅埋偏压隧道降雨条件下衬砌结构力学特性研究
# 软岩隧道围岩遇水劣化结构变形规律及对策研究
# 盾构掘进过程刀盘振动作用下富水粉细砂层液化潜势及控制技术研究
# An error occurred
# 新近系富水弱胶结砂岩隧道稳定性特征研究
# 铁路隧道衬砌结构抗震性能指标及可靠度研究
# 朔黄铁路隧道衬砌承载性能及安全性评价
# 正交穿越滑体的既有隧道围岩压力分布特征研究
# 彝良隧道岩溶段围岩稳定性分析与防突岩体厚度研究
# 盾构机主驱动减速机状态检测与故障诊断研究
# An error occurred
# 隧道衬砌切割机械臂结构设计与动力学分析
# 接头变形与应力松弛共同作用下GINA止水带使用寿命预测
# 盾构隧道施工对邻近电缆隧道的扰动影响及安全距离研究
# 盾构机驱动系统主轴承齿轮的疲劳寿命预测研究
# TBM滚刀磨耗规律与预测预警方法研究
# An error occurred when close window
# An error occurred when close window
# 0 2596
# 0 243
# year month has pdfs:7500
# 盾构机滚刀刀圈材料的热处理优化
# 隧道基底锚杆钻机设计及动力学分析
# TBM连续皮带机托辊巡检机器人系统设计与实现
# 隧道锚杆台车工作臂轨迹规划及优化研究
# 盾构机行星齿轮减速器的均载特性分析与优化
# 基于新意法的隧道掌子面变形机理及控制研究
# 地域文化视角下特长隧道景观营造研究——以秦岭终南山公路隧道为例
# 寒冷地区地下隧道洞口段热环境特性及消防水管防冻保温研究
# 公路隧道排水管路结晶堵塞影响因素及防治对策研究
# 基于车辆检测识别的公路隧道通风系统优化研究
# 基于博弈与深层网络的隧道衬砌结构病害自动检测方法研究
# 隧道工程智能监测云信息系统的研发与应用
# 面向智能网联的行人检测方法与系统设计
# 交叉分辨率可见光红外跨模态车辆重识别研究
# V2V场景下的几何信道建模及统计特性研究
# An error occurred
# 基于深度强化学习的干线交通混合式优化算法研究
# 基于VIT网络的车辆重识别算法研究
# 城市道路场景下双分支实时语义分割算法研究
# 基于深度学习的道路场景语义分割技术研究
# 新能源汽车充电站选择算法研究
# An error occurred when close window
# An error occurred when close window
# 城市环境下基于链路状态感知的车载路由协议研究
# 城镇环境VANET广播技术研究与硬件平台实现
# 针对车联网自私行为和篡改攻击的安全机制研究
# 基于相关滤波的车辆跟踪方法研究
# 智能立体停车场调度算法研究
# An error occurred
# 基于深度学习的交通标志检测与识别算法研究
# 动态路网中的路径持续规划问题研究
# 有限样本下的行程到达时间预测方法研究
# 基于图神经网络的交通流预测技术的研究
# 基于时空图注意力网络的交通流速预测研究
# 基于不确定路况建模的最快路径搜索算法
# 面向时延优化的车辆边缘计算任务卸载算法研究
# 基于最优上下车点的网约车司乘匹配算法研究
# 基于相关向量机的电动汽车保有量预测研究
# 避险车道末端减速消能设施受失控车辆碰撞的影响研究
# 避险车道上人-车-路模型与失控车辆三维离散元模型的研究与应用
# 车辆冲击下的避险车道末端柔性防坠网设计与累计防护性能研究
# 城市道路交通拥堵及评价研究——以北京市西三旗社区街道为例
# 基于模糊推理的车辆跟驰行为控制策略模型研究
# 非合作车联网中基于博弈模型的节点激励机制研究
# 0 2636
# 0 243
# year month has pdfs:7500
# 城市环境下基于链路状态感知的车载路由协议研究
# 城镇环境VANET广播技术研究与硬件平台实现
# 针对车联网自私行为和篡改攻击的安全机制研究
# 基于相关滤波的车辆跟踪方法研究
# 智能立体停车场调度算法研究
# 基于深度学习的交通标志检测与识别算法研究
# 动态路网中的路径持续规划问题研究
# 有限样本下的行程到达时间预测方法研究
# 基于图神经网络的交通流预测技术的研究
# 基于时空图注意力网络的交通流速预测研究
# 基于不确定路况建模的最快路径搜索算法
# An error occurred
# 面向时延优化的车辆边缘计算任务卸载算法研究
# 基于最优上下车点的网约车司乘匹配算法研究
# 基于相关向量机的电动汽车保有量预测研究
# 避险车道末端减速消能设施受失控车辆碰撞的影响研究
# 避险车道上人-车-路模型与失控车辆三维离散元模型的研究与应用
# An error occurred
# 车辆冲击下的避险车道末端柔性防坠网设计与累计防护性能研究
# 城市道路交通拥堵及评价研究——以北京市西三旗社区街道为例
# 基于模糊推理的车辆跟驰行为控制策略模型研究
# 非合作车联网中基于博弈模型的节点激励机制研究
# An error occurred when close window
# 车联网中认知频谱分配机制研究
# 应用于V2G技术的精简矩阵变换器控制策略研究
# 基于车联网的货车队列拓扑结构对空气动力学特性及燃油经济性的影响研究
# An error occurred
# 考虑车队压缩的道路信号协调优化模型研究
# An error occurred
# 基于油耗的重型货车车速与信号配时协同优化模型研究
# An error occurred
# 基于车路协同技术的道路交通信号灯自适应控制方法研究
# 基于域自适应技术的车辆视角雾天场景语义分割方法研究
# An error occurred
# 路-电耦合系统调度和充电策略协同鲁棒优化研究
# 基于光机电检测的橙子分选技术研究及便携式仪器开发
# 基于模型检测的车联网认证协议形式化分析与验证
# 基于智能非合作博弈的城市路网出租车共享研究
# 基于车载激光雷达的道路场景点云分类研究
# 基于RBF神经网络的垂直循环立体车库动力系统平稳控制研究
# An error occurred
# 基于历史轨迹与实时数据的交通信号动态协调控制方法研究
# An error occurred
# 基于电警数据的车辆通勤特征分析及关键出行路径挖掘
# 电动二轮车与机动车碰撞事故严重程度影响因素分析
# 基于认知行为与负荷的高速公路枢纽互通立交出口指路标志设置研究
# An error occurred
# 网络预约背景下出租车市场四方演化博弈研究
# 跟驰行驶中情感演变下的驾驶行为转移规律研究
# An error occurred
# 共享单车早高峰潮汐时空特征分析及调度方法研究
# An error occurred when close window
# 0 2659
# 0 243
# year month has pdfs:7500
# 新型车载称重系统的设计与开发
# 高速公路交通事故严重程度影响因素分析与预测
# 不完备信息环境下的道路交通状态判别与预测方法研究
# 考虑电动汽车能量转移特性的电网多目标双层优化调度
# 基于深度学习的车辆标志目标检测方法研究
# 新能源汽车电-氢能源站容量配置与运行研究
# 基于巡游出租车订单数据的出行时空规律和需求预测研究
# 城市交叉口进口道交通事故辨识与应急管控方法
# 基于不完备信息的快速道路交通事件检测与持续时间预测
# An error occurred
# 车联网下移动边缘计算任务卸载和迁移策略研究
# 顶置式悬移充电桩系统设计及有源滤波研究
# 顾及地形特征的特种车辆路径规划与行驶状态识别方法研究
# 基于高分辨率影像农村公路信息提取方法研究
# 基于时空关联特性的交通流预测方法研究
# 基于时空关联的路网数据分析与交通发展态势预测
# 基于改进YOLO的车辆及行人识别算法研究
# 彩色沥青混合料在交叉口慢行交通优化设计中的应用研究
# An error occurred
# 暴雨内涝多情景下城市道路脆弱性研究——以武汉市中心城区为例
# 基于移动边缘计算的车联网任务卸载策略研究
# 基于强化学习的家用电动汽车智慧充电时空策略研究
# An error occurred when close window
# 桂林市历史城区慢行交通系统优化研究
# 草原公路长距离行车驾驶疲劳调节方式研究
# 基于心电与脑电评价的草原公路驾驶疲劳恢复研究
# 草原公路交叉口设施组合认知负荷量化研究
# 基于深度学习的交通流时空建模与预测研究
# 基于烟花算法的混合车辆调度系统
# 基于区块链的车联网匿名身份认证机制的研究与实现
# 城市交通目标检测与流量预测研究
# 基于蜂窝信令数据的交通特性研究与应用
# 车联网场景下面向驾驶安全的情绪识别研究
# 车联网中基于无人机辅助通信的网络部署优化设计
# 基于子区动态划分和状态评估的区域交通协调优化控制研究
# 蜂窝车联网场景中的协同感知技术研究
# 面向智慧交通的城市道路行驶时间预测模型研究及实现
# 面向道路网络的车辆下一个位置预测问题研究
# W市县乡道路智能交通系统集成项目进度管理研究
# 基于车联网协作数据交换的IDNC传输方案研究
# 基于果蝇全流程感知机制的视隐态车内场景轻量化行为识别方法研究
# 基于数据驱动的电动汽车实时充电研究
# 车联网中群组车辆的信任评估与条件隐私保护认证方法研究
# 0 2698
# 0 243
# year month has pdfs:7500
# 桂林市历史城区慢行交通系统优化研究
# 草原公路长距离行车驾驶疲劳调节方式研究
# 基于心电与脑电评价的草原公路驾驶疲劳恢复研究
# 草原公路交叉口设施组合认知负荷量化研究
# An error occurred
# 基于深度学习的交通流时空建模与预测研究
# 基于烟花算法的混合车辆调度系统
# 基于区块链的车联网匿名身份认证机制的研究与实现
# 城市交通目标检测与流量预测研究
# 基于蜂窝信令数据的交通特性研究与应用
# 车联网场景下面向驾驶安全的情绪识别研究
# 车联网中基于无人机辅助通信的网络部署优化设计
# 基于子区动态划分和状态评估的区域交通协调优化控制研究
# 蜂窝车联网场景中的协同感知技术研究
# 面向智慧交通的城市道路行驶时间预测模型研究及实现
# 面向道路网络的车辆下一个位置预测问题研究
# W市县乡道路智能交通系统集成项目进度管理研究
# 基于车联网协作数据交换的IDNC传输方案研究
# 基于果蝇全流程感知机制的视隐态车内场景轻量化行为识别方法研究
# 基于数据驱动的电动汽车实时充电研究
# 车联网中群组车辆的信任评估与条件隐私保护认证方法研究
# An error occurred when close window
# An error occurred when close window
# 电车网络中基于热力图的空闲移动充电站调度算法研究与实现
# 面向车联网的位置隐私相关技术研究
# An error occurred
# 基于区块链的车联网认证方案
# 基于空间映射的城市车辆历史轨迹学习型索引研究
# 基于混合学习框架的空载出租车个性化路径推荐算法研究
# 电动汽车充电负荷预测及充电站选址定容研究
# An error occurred
# 考虑光伏发电的电动汽车充电站规划决策技术研究
# 集群电动汽车与电网安全智能交互技术研究
# 电动汽车充电设施故障智能诊断策略研究
# 考虑数据缺失的充电设施安全预警方法研究
# 基于数据驱动的电动汽车集群负荷预测及优化调度
# 考虑聚合响应的电动汽车参与电网有功控制研究
# 信息网络因素影响下的电动汽车分布式充电调度方法研究
# 基于贝叶斯网络的车载容迟网络路由优化机制研究
# 车联网边缘云雾网络业务调度优化研究
# 车辆雾网络中的计算卸载优化算法设计
# 车辆边缘计算任务卸载策略研究
# 车联网中基于信道状态信息的轻量化场景识别算法研究
# An error occurred
# 车联网中基于深度学习的资源调度与资源分配算法研究
# 智能超表面辅助车联网通信系统性能研究
# 0 2719
# 0 243
# year month has pdfs:7500
# 智能反射面辅助的车辆通信网络传输方案研究与设计
# 基于短时交通流预测的动态路径诱导系统研究
# 基于路线选择模式的城市交通拥堵时空传播模式研究
# 面向车联网的网络切片资源管理方法研究
# 面向复杂道路场景的目标检测算法研究
# 城市公共交通项目风险管理成熟度与项目成功关系研究
# 基于通感一体化技术的多基站车联网系统与车辆预警系统设计
# 基于深度学习的非机动车及骑行人属性识别技术研究
# 基于汽车全景环视系统的停车位检测方法
# 基于雷视融合的车辆检测技术研究与实现
# 复杂环境下基于深度学习的交通标志牌识别算法研究
# 基于图神经网络的车流量预测研究
# 基于区块链的车联网众包激励机制的研究
# 基于区块链的车联网众包性能评价
# 车联网环境下基于深度强化学习的车辆跟驰纵横向联合控制研究
# 基于数字孪生的货物运送损伤分析系统研究
# 考虑驾驶风格和坡度的车辆纵向控制策略研究
# 基于无人机航拍的交通检测及流量统计算法研究
# 城市道路交通信号协调与应急优先控制研究
# 基于SEM-Logit模型的居民公共交通出行选择行为研究
# An error occurred when close window
# An error occurred when close window
# 纯电动定制公交线路设计
# 基于注意力机制下的LSTM短时交通流量预测研究
# 智能网联环境下车辆强制换道的交通流稳定性研究
# 基于级联失效的城市交通网络拥堵扩散与控制策略研究
# 基于PLS-SEM及贝叶斯网络的大学生网约车忠诚度研究
# An error occurred
# 基于出租车数据的定制公交路径规划研究
# 基于CNL模型的网约车用户出行行为的研究——以大连市大学生为例
# 基于流量预测的大连新机场跨海桥交叉口信号配时设计
# 基于交通流预测的道路干线信号协调控制研究
# 基于时间控制站点的城郊公交和常规公交时刻表协调优化研究
# 基于多源数据融合的公交驾驶行为识别与危害程度评价
# 考虑道路阻抗的低碳冷链物流配送问题研究
# 基于出行需求的城郊定制公交线网优化
# 考虑通行能力折减的潮汐车道优化设置方法
# 基于TPB-HBM理论的大学生休闲出行行为研究
# 城市居民区限时停车泊位布局与时段优化研究
# 左转待行区交叉口的信号配时优化研究
# 基于停车场利用率的城市商圈停车场动态收费机制研究
# 基于数据挖掘的交通事故预警方法研究
# 基于出租汽车服务评价的大学生主观幸福感影响因素研究
# 0 2757
# 0 243
# year month has pdfs:7500
# 电车网络中基于热力图的空闲移动充电站调度算法研究与实现
# 面向车联网的位置隐私相关技术研究
# 基于区块链的车联网认证方案
# 基于空间映射的城市车辆历史轨迹学习型索引研究
# 基于混合学习框架的空载出租车个性化路径推荐算法研究
# 电动汽车充电负荷预测及充电站选址定容研究
# An error occurred
# 考虑光伏发电的电动汽车充电站规划决策技术研究
# 集群电动汽车与电网安全智能交互技术研究
# 电动汽车充电设施故障智能诊断策略研究
# 考虑数据缺失的充电设施安全预警方法研究
# 基于数据驱动的电动汽车集群负荷预测及优化调度
# 考虑聚合响应的电动汽车参与电网有功控制研究
# 信息网络因素影响下的电动汽车分布式充电调度方法研究
# 基于贝叶斯网络的车载容迟网络路由优化机制研究
# 车联网边缘云雾网络业务调度优化研究
# 车辆雾网络中的计算卸载优化算法设计
# 车辆边缘计算任务卸载策略研究
# 车联网中基于信道状态信息的轻量化场景识别算法研究
# 车联网中基于深度学习的资源调度与资源分配算法研究
# 智能超表面辅助车联网通信系统性能研究
# An error occurred when close window
# An error occurred when close window
# 重大突发事件下考虑需求紧迫度的应急车辆路径优化研究
# 恶劣环境下道路图像增强算法研究与应用
# 网约车用户出行方式选择行为分析及改善方案评价
# 基于多源数据融合的定制公交线路设计研究
# 网约车服务质量评价方法的研究与应用
# 考虑自动驾驶的城市混行交通流特性研究
# 基于物联网的智能交通测距系统的设计与实现
# 基于低质图像增强方法的交通灯控制设计
# 基于深度学习的车辆轨迹预测算法研究
# 基于多种模型组合的短时交通流预测
# 考虑道路通行状态的应急物资配送路径研究
# 智能车库中车位分配与AGV调度策略研究
# 桥式凹板运输装备结构设计与分析
# 城市复合线路换乘公交时刻表调度优化设计
# 考虑异质性的大学生出行方式选择行为研究
# 城市区域交通信号协调控制研究
# 基于预信号交叉口的信号配时优化研究
# 公交客流OD反推及其敏感性分析
# 逆向可变车道交叉口信号配时优化研究
# 基于服务质量的大学生网约车满意度及主观幸福感研究
# An error occurred when close window
# 0 2797
# 0 243
# year month has pdfs:7500
# 信号交叉口的直行待行区设置及运行特性研究
# 基于区域分割理论的单向交通组织研究与应用
# 基于家庭收入的网约车用户出行方式选择行为研究
# 基于级联失效的城市交通拥堵扩散研究
# 考虑成本最小化的公交发车间隔优化方法研究
# 城市快速路交织区交通冲突机理研究
# 基于5G场景下新能源定制公交线路规划研究
# 寒冷地区城市道路交通事故成因分析及严重程度预测
# An error occurred
# 道路交通事故热点时空分析研究
# 基于自适应布谷鸟算法的城市区间车调度优化
# 基于车路协同控制的无信号交叉口CAVs冲突分析
# An error occurred
# 考虑运行区间共线的多线路公交协调调度优化研究
# 基于组合模型的短时交通流预测研究
# An error occurred
# 基于深度卷积神经网络的航拍图像车辆目标检测算法研究
# 基于改进YOLOv5的航拍图像车辆检测
# 基于累积前景理论的通勤换乘决策研究
# 重载公路信号交叉口通行能力与配时优化研究
# An error occurred
# 基于图神经网络的相邻尺度道路数据匹配研究
# 多角度车型识别算法及应用研究
# 面向复杂场景的车辆检测与跟踪算法研究
# An error occurred when close window
# An error occurred when close window
# 信号交叉口的直行待行区设置及运行特性研究
# 基于机器视觉的道路交通标线检测方法研究
# 基于CFD的某畜禽运输车车厢内气流场和温度场的模拟研究
# 多车辆固定时间协同编队控制算法研究
# 基于V2G的CLLC谐振变换器及其控制策略研究
# 基于Bi-LSTM负荷预测的光储充电站优化配置与控制研究
# 基于Android的远端安全员监控系统研究
# 基于深度学习的车辆减速情况识别算法研究与实现
# 电动汽车充电桩谐波检测方法研究
# 生鲜冷链物流配送选址—路径多目标优化问题研究
# 疏港公路交通状态评价研究——以天津港疏港公路为例
# 人机混驾条件下高速公路交织区通行能力研究
# 高速公路不断交施工区交通流特性与交通组织优化
# 混合交通流条件下车辆换道模型构建及交通流特性分析
# 基于用户出行特征分类的高速公路差异化收费策略研究
# 交通信息条件下基于期望后悔的路径选择行为研究
# 高速公路合流区网联自动驾驶车辆换道决策模型构建
# 基于个体异质性的大型活动交通生成预测研究
# 高速公路新型服务区司乘引导模型构建与应用
# 车联网环境下复杂异质交通流稳定性与通行能力研究
# An error occurred when close window
# 0 2837
# 0 243
# year month has pdfs:7500
# 基于BIM的矮塔斜拉转体桥施工监测技术研究
# 基于区域分割理论的单向交通组织研究与应用
# 基于家庭收入的网约车用户出行方式选择行为研究
# 基于级联失效的城市交通拥堵扩散研究
# 考虑成本最小化的公交发车间隔优化方法研究
# An error occurred
# 城市快速路交织区交通冲突机理研究
# 基于5G场景下新能源定制公交线路规划研究
# 寒冷地区城市道路交通事故成因分析及严重程度预测
# 道路交通事故热点时空分析研究
# An error occurred
# 基于自适应布谷鸟算法的城市区间车调度优化
# 基于车路协同控制的无信号交叉口CAVs冲突分析
# 考虑运行区间共线的多线路公交协调调度优化研究
# 基于组合模型的短时交通流预测研究
# 基于深度卷积神经网络的航拍图像车辆目标检测算法研究
# An error occurred
# 基于改进YOLOv5的航拍图像车辆检测
# 基于累积前景理论的通勤换乘决策研究
# An error occurred
# 重载公路信号交叉口通行能力与配时优化研究
# An error occurred
# 基于图神经网络的相邻尺度道路数据匹配研究
# An error occurred
# 多角度车型识别算法及应用研究
# An error occurred
# 面向复杂场景的车辆检测与跟踪算法研究
# An error occurred when close window
# 基于深度学习的车辆换道决策识别与轨迹预测
# Sag路段的格子交通流动力学建模及仿真研究
# 老龄化社会背景下的慢行交通适老化评价研究——以西安市碑林区为例
# 基于主动谐波抑制的直流充电桩整流模块研究与开发
# 基于多源数据的公交乘客路径选择行为影响效应研究
# 某智慧城市电动汽车充电站布局优化与定容研究
# 车库智能巡检机器人路径规划研究与应用
# 智慧城市下物流配送中心选址及配送路径优化研究
# 基于深度学习的车辆检测算法研究与应用
# 车联网下的移动边缘计算任务卸载和服务缓存方法研究
# 待行区信号交叉口通行能力及服务水平研究
# 中小城市公交线网效率评价与布局优化研究
# 基于博弈论的智能网联汽车高速公路事故路段换道研究
# 基于机器学习的地铁站区域共享单车需求预测研究
# 考虑乘客时间成本的城市公交时刻表优化研究
# 新型城镇化背景下的绿色道路交通基础设施评价与优化研究
# 基于大数据的高速公路收费站交通流量预测研究
# An error occurred
# 基于浮动车数据的交通状态判别与预测方法研究
# 城市公共交通出行结构及常规公交时刻表优化方法研究
# 居住区对外共享停车研究
# An error occurred when close window
# 0 2858
# 0 243
# year month has pdfs:7500
# 信号交叉口的直行待行区设置及运行特性研究
# 基于机器视觉的道路交通标线检测方法研究
# 基于CFD的某畜禽运输车车厢内气流场和温度场的模拟研究
# An error occurred
# 多车辆固定时间协同编队控制算法研究
# An error occurred
# 基于V2G的CLLC谐振变换器及其控制策略研究
# 基于Bi-LSTM负荷预测的光储充电站优化配置与控制研究
# 基于Android的远端安全员监控系统研究
# 基于深度学习的车辆减速情况识别算法研究与实现
# 电动汽车充电桩谐波检测方法研究
# 生鲜冷链物流配送选址—路径多目标优化问题研究
# 疏港公路交通状态评价研究——以天津港疏港公路为例
# 人机混驾条件下高速公路交织区通行能力研究
# 高速公路不断交施工区交通流特性与交通组织优化
# 混合交通流条件下车辆换道模型构建及交通流特性分析
# An error occurred
# 基于用户出行特征分类的高速公路差异化收费策略研究
# 交通信息条件下基于期望后悔的路径选择行为研究
# An error occurred
# 高速公路合流区网联自动驾驶车辆换道决策模型构建
# 基于个体异质性的大型活动交通生成预测研究
# 高速公路新型服务区司乘引导模型构建与应用
# 车联网环境下复杂异质交通流稳定性与通行能力研究
# An error occurred when close window
# An error occurred when close window
# 基于大数据的车联网运营平台建设关键技术研究与实现
# An error occurred
# 基于Probit模型的交通方式分担仿真预测方法研究
# 基于优化人工神经网络的交通OD反推方法研究
# 面向交通规划的节点阻抗合理取值方法分析
# 超大城市道路货运交通碳排放测算与碳达峰发展策略研究——以北京市、深圳市为例
# 智能网联环境下混合交通流特性分析及能耗研究
# 东非地区海外交通工程风险分析与应对研究——以肯尼亚A公路项目为例
# 复杂交通监控视频中车辆检测跟踪研究及应用
# An error occurred
# 基于自适应滑模控制的车辆编队算法研究
# 面向城市道路场景的实时语义分割算法研究
# 基于驾驶人注意力预测的显著性目标估计方法研究
# 基于深度学习的车辆重识别方法研究
# 电动汽车分布式一致性最优充电控制研究
# 基于视觉的交通场景行人运动感知算法研究
# 基于动态分时电价的云边协同电动汽车有序充电方法研究
# V2G模式下考虑新能源接入的电动汽车充放电调度策略研究
# 新能源汽车一体化充能站的低碳经济优化调度研究
# 智能网联环境下燃料电池混合动力汽车生态驾驶策略研究
# 考虑充电中断与不确定需求的电动汽车充电站选址研究
# 基于可见光通信的V2V路由算法研究
# 0 2898
# 0 243
# year month has pdfs:7500
# 融合RF和VLC技术的异构车联网资源分配算法研究
# 小区背景下基于动态电价的电动汽车V2G调度研究
# 恶劣天气场景下计及源荷不确定性的电力-交通网协调优化调度
# 多场景下居民区配电网承载高比例电动汽车的适应性研究
# 考虑电动汽车用户可信度和有限理性的可调度潜力评估
# 考虑需求响应及可靠性的电力-交通网协同优化运行研究
# 低碳视角下同时取送货的车辆路径问题研究
# 基于轻量级神经网络的前方车辆行人检测算法
# An error occurred
# 融合导航与众包上报数据的城市快速路交通事件检测研究
# 基于出行链的骑行换乘公共交通研究
# 信号控制交叉口内部机动车交通流模型研究
# 基于变点检测的交通状态辨识及预测研究
# 降雨天气下的城市公交客流预测及调度优化
# 智能楼宇内电动汽车充放电多目标优化调度研究
# 面向车辆边缘计算的任务卸载与资源分配策略研究
# 基于深度学习的公交客流OD矩阵获取方法及应用
# 改进遗传算法求解车辆路径问题研究
# 停放车辆辅助边缘计算的动态卸载策略研究
# 快速路入口匝道数据驱动控制方法研究
# An error occurred
# 基于数据驱动的安全控制研究及车辆队列应用
# An error occurred
# An error occurred when close window
# An error occurred when close window
# 含风电和电动汽车的配电网优化调度
# An error occurred
# 车路协同背景下基于编队和动态优先级的混合路口通行策略研究
# 基于区块链的车辆边缘计算资源分配和多组件卸载研究
# 面向数据离散化的交通预测研究
# 基于视觉定位的电动汽车自动充电装置路径规划研究
# 面向节能驾驶的智能网联车辆决策规划控制研究
# 考虑配电网运行安全的出行电动汽车充电引导策略研究
# 基于支持向量机/支持矩阵机的EEG信号分类方法
# 基于车辆轨迹数据的高速公路交通状态监测研究
# 面向道路场景的高质量多模态风格迁移方法研究
# 面向办公建筑的电动汽车充电设施配置与运行调度研究
# An error occurred
# 基于多方博弈的商业区能源供需系统优化调度研究
# 基于信息论的驾驶人感知-行为模式研究
# 毫米波车辆网络中波束选择和功率分配联合优化策略研究
# 基于深度学习的智能交通车辆检测方法研究
# 智能网联汽车车库内激光雷达定位技术
# 基于领域适应的有雾场景下目标检测算法研究
# 结合风险价值的多危险品运输路径规划问题研究
# 混合交通流中人类和机器驾驶员的驾驶礼仪研究
# 考虑无人机站的车辆路径规划问题研究
# 0 2937
# 0 243
# year month has pdfs:7500
# 含风电和电动汽车的配电网优化调度
# 车路协同背景下基于编队和动态优先级的混合路口通行策略研究
# 基于区块链的车辆边缘计算资源分配和多组件卸载研究
# 面向数据离散化的交通预测研究
# 基于视觉定位的电动汽车自动充电装置路径规划研究
# 面向节能驾驶的智能网联车辆决策规划控制研究
# 考虑配电网运行安全的出行电动汽车充电引导策略研究
# 基于支持向量机/支持矩阵机的EEG信号分类方法
# 基于车辆轨迹数据的高速公路交通状态监测研究
# 面向道路场景的高质量多模态风格迁移方法研究
# An error occurred
# 面向办公建筑的电动汽车充电设施配置与运行调度研究
# 基于多方博弈的商业区能源供需系统优化调度研究
# 基于信息论的驾驶人感知-行为模式研究
# 毫米波车辆网络中波束选择和功率分配联合优化策略研究
# 基于深度学习的智能交通车辆检测方法研究
# An error occurred
# 智能网联汽车车库内激光雷达定位技术
# 基于领域适应的有雾场景下目标检测算法研究
# 结合风险价值的多危险品运输路径规划问题研究
# 混合交通流中人类和机器驾驶员的驾驶礼仪研究
# 考虑无人机站的车辆路径规划问题研究
# An error occurred when close window
# An error occurred when close window
# 基于队列跟驰稳定性的协同式自适应巡航策略研究
# A公司汽车安全带性能检测价值流分析及精益检测实施研究
# 巴基斯坦拉合尔卫星城与主城间绿色交通控制延误的低技术智能节点解决方案（基于PTV VISSIM软件的节点预信令应用）
# 一种基于深度学习方法的车牌识别系统
# 环井式立体停车库的集成设计及其关键技术研究
# 基于双目视觉智能车辆的目标识别与测距系统研究
# 带时间窗多行程车辆路径优化的两阶段混合启发式算法研究及应用
# An error occurred
# 女性驾驶员正面碰撞工况下的约束系统研究
# 时变网络下带模糊时间窗的绿色车辆路径优化研究
# An error occurred
# 基于DQN-MLP的认知车联网动态频谱接入问题的研究
# 基于多阶数据张量的网约车OD需求预测方法研究
# 基于图神经网络的车辆出行路径推荐方法研究
# 基于多用户强化学习的多信道认知车联网动态频谱接入问题研究
# An error occurred
# 基于卷积神经网络的雨雾天交通标志识别方法研究
# An error occurred
# 基于功率分配的电动汽车有序充电策略研究
# 冷链物流“最后一公里”配送的多主体博弈及对策研究
# An error occurred
# 多目标鲸群优化及其在随机需求车辆路径规划问题中的应用
# S公司车联网平台运维项目知识图谱构建及问答系统研发
# 基于骑行特征的共享电单车运营优化研究
# 考虑无差别化阈值和参考依赖的出行者路径选择
# An error occurred
# An error occurred when close window
# An error occurred when close window
# 0 2958
# 0 243
# year month has pdfs:7500
# 基于多源数据的城市街道可骑行性评价与分级优化策略
# 带时间窗的同时取送货车辆路径和三维装箱联合优化研究
# 基于交叉口机动车运行轨迹数据的异常识别研究
# 考虑多前车影响的CACC车辆跟驰模型及混行交通流特征研究
# 基于DETR网络的交通场景多目标检测跟踪技术研究
# 车-人冲突场景下高速行驶智能网联汽车运动速度优化
# 基于瓶颈理论的多方式出行均衡行为分析
# 基于机器学习的短时交通流量补全与预测研究
# 疏导型定制旅游公交线路优化研究
# 机非混行环境下自动驾驶对城市交叉口通行能力的影响研究
# 基于交通视频的车辆实时流量统计算法研究
# 基于交通事故高发预警的城市道路警力配置与巡逻方法研究
# 考虑机动车抵近影响的无灯控人行横道行人过街特性研究与建模
# 基于隐马尔可夫模型的出租车轨迹预测方法研究
# An error occurred
# 关中平原城市群陆路交通网络空间结构分析及优化研究
# 考虑碳排放的灵活充电策略物流车辆路径优化研究
# 网联车个性化跟驰诱导系统构建与实车测试
# 基于机器学习的城市常规公交串车预测研究
# An error occurred
# 基于贝叶斯网络的高速公路蓝牌货车交通事故风险及对策研究
# 考虑攻击等级的高速公路网络脆弱性研究
# An error occurred when close window
# 旅客短行程下的高铁与高速公路乘用车出行方式选择偏好研究
# 基于深度强化学习的智能网联车辆换道轨迹规划方法研究
# An error occurred
# 高速公路互通式立交出口危险识别与管控技术研究
# 新能源汽车政策下居民出行意向及出行方式选择研究
# A航运企业管理信息化问题研究
# 天津港口与京津冀经济互动发展的研究
# 新冠疫情对中国出口集装箱航运影响研究——以东南亚航线为例
# 山东港口YT港集团发展战略研究
# 航运成本与最不发达国家经济发展的关系
# An error occurred
# 基于Bryson模型的曹妃甸港口发展中地方政府协同治理研究
# 港口物流与城市产业互动关系研究
# 基于AHP分析法的大连港港口竞争力评价
# PX航运公司票务资产证券化研究
# KL国际货代公司单证操作流程改进研究
# XY游船公司发展战略研究
# An error occurred
# 中泰生鲜冷链物流海运作业流程优化研究
# 基于AHP-Shapley值法的航运联盟利益分配模型及实证研究
# 基于DEA-AHP模型的中国重要港口物流绩效评价
# 港口物流服务质量评价研究——以大连港为例
# 辽宁港口股份有限公司港口物流发展战略研究
# An error occurred
# An error occurred when close window
# 0 2998
# 0 243
# year month has pdfs:7500
# 港产城融合程度评价研究
# “一带一路”境外经贸合作区建设对东道国港口吞吐量影响研究
# 整体性治理视角下沿海港口工程质量政府监管的优化路径研究——以广东省Z市为例
# 基于混合扫描模型的北部湾港口转型升级政策优化研究——以钦州港为例
# 港口物流对京津冀区域经济的促进效应研究——基于空间杜宾模型
# 港口国企合并重组改革动因及效应研究——以大连港合并营口港为例
# 明清山东运河济运泉源与区域社会研究
# 作业成本法在镇江港务集团轮驳公司的应用研究
# 基于系统动力学的南京港港口竞争力研究
# 长江干线电动船舶换电站布局规划研究
# 基于系统动力学的可持续海运供应链协调研究
# 基于平衡计分卡的秦港XG公司部门绩效考核体系研究
# An error occurred
# T国际邮轮母港服务质量提升研究
# 外部监管对港口企业承担环境责任行为影响研究——以秦皇岛市QG公司为例
# An error occurred
# A公司天津分公司客户满意度测评与改进策略研究
# HG港口有限公司内控体系改善研究
# J公司超大灵便型散货船航次营运风险管理优化研究
# 考虑公平偏好和损失规避的港口服务供应链联合契约协调策略研究
# 港口弹性评价指标体系构建研究
# 国际海事服务产业链构建与中国自由贸易试验区创新发展
# An error occurred when close window
# H省海事局“互联网+政务服务”优化研究
# 河北港口集团海洋旅游业务发展战略研究
# 环渤海港口高质量发展水平测度与提升路径研究
# An error occurred
# 疏浚工程项目标准化管理综合评价研究
# 基于电阻层析技术的疏浚管道中含率测量
# 面向绞吸挖泥船的电阻层析测速技术研究
# 明清时期大运河河工物料研究——以运河江苏段为中心
# 宋代大运河淮扬段整治工程研究
# 数据驱动的耙吸挖泥船施工过程多目标优化研究
# 基于数据驱动的绞吸挖泥船作业过程优化控制方法研究
# An error occurred
# 基于深度学习的耙吸船装舱产量预测及控制策略优化反演研究
# 一种船闸自动系泊装置设计
# An error occurred
# 风浪流耦合作用下的系泊船舶与码头动力学分析
# 干散货码头船舶岸电的应用与研究
# 弧墙—浮式防波堤水动力性能研究
# An error occurred
# 考虑物流过程的自动化码头—微电网系统规划与调度优化研究
# 基于碳交易的港口岸电综合效益分析
# O型三翻翻车机有限元分析及钢结构优化
# 装配式浮式码头结构设计与安全性评估研究
# 含有多刚体系统的新型浮式防波堤水动力性能研究
# An error occurred when close window
# 0 3038
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 3038
# 0 243
# year month has pdfs:7500
# 物体坠落诱发的港口共振数值研究
# 装配式浮式码头总体设计及水动力性能分析
# 基于业主视角对码头工程H建设期风险管理评价
# 船舶撞击下高桩码头的动力响应及基桩疲劳损伤分析
# An error occurred
# 双圆桶八隔舱桶型基础新型码头稳定性分析
# 集装箱跨运车侧翻判据及防倾覆控制研究
# An error occurred
# 考虑突发侧风影响环境的集装箱跨运车防倾覆控制
# 滚装船配载及装卸作业优化研究
# 集装箱码头泊位岸桥联合优化调度算法研究
# An error occurred
# 基于多传感器信息融合的港口AGV路径规划及导航算法研究
# 港口群落系统货种运营效率评价与结构优化
# 基于GAN的船舶水尺数字修复与识别算法研究
# An error occurred
# 秦皇岛港物流效率评价研究
# 考虑时间敏感货物运输需求的班轮航线组合设计
# ...
# 两种坡缕石基复合材料的调湿性能研究
# 基于多元负荷预测的楼宇综合能源系统优化调度研究
# 基于特殊电容传感器的浅层埋线探测系统研究
# 高温高湿地区间接/直接蒸发式新风空调系统性能研究
# 直膨式辐射空调系统传热机理研究
# 秦巴山地建筑自然通风设计研究
# 太阳能烟囱通风技术与结构优选研究
# 基于热电热泵的全热交换器性能测试实验系统关键技术研究
# 基于长短期记忆神经网络的空调温度预测仿真研究
# 上海国家电网办公楼柔性负荷的楼宇需求响应研究
# 高原睡眠局部空间对流式热氧环境协同营造末端优化设计研究
# 土壤-空气换热器混风段结构优化及对日光温室环境调控影响
# 基于温度分档优化的多联机空调需求响应调控策略研究
# 基于事件触发机制的变风量空调系统预测控制方法研究
# 西北养殖型村镇太阳能与沼气联合供暖系统热力性能分析及优化设计研究
# An error occurred
# 间歇射流送风策略下人员热舒适及环境分布特征研究
# 基于模型预测的太阳能供暖系统日前运行调控方法研究
# 复叠式空气源热泵承压生活热水系统运行经济性分析
# 某机场多源协同供暖系统多目标节能低碳运行优化研究
# 不同湿度环境下人体呼吸气道干燥感受研究
# 青藏高原室内工作点位供氧、供湿及湿氧协同输送关键参数研究
# An error occurred
# 基于行为模式的户式空气源热泵地板辐射供暖系统的节能研究
# 西安办公建筑冬季工况下个人热舒适数据驱动模型研究
# 波纹表面降膜除湿传热传质研究
# 基于负荷预测的中央空调冷冻站系统节能控制研究
# 口腔诊室气溶胶扩散机理及通风控制作用效果研究
# 通风空调供水管路系统中U型和Z型弯头的减阻优化研究
# An error occurred
# An error occurred when close window
# 0 4758
# 0 243
# year month has pdfs:7500
# 温度突变对人体热反应的影响研究
# 基于净收益最大化的太阳能集热系统变流量运行调控策略研究
# 基于群智能的某机场航站楼中央空调冷冻水系统节能优化研究
# An error occurred
# 全面通风结合局部送风对隔离病房污染物控制和热环境的影响研究
# 通风空调管道风阀沟槽减阻及阻力预测
# 进藏人群对高原干燥环境的生理适应机制及湿环境参数需求研究
# An error occurred
# 穿孔挡风板在壁挂式空调中的应用研究
# 方柱贴附通风水平扩散区气流碰撞机理及流动特征研究
# An error occurred
# 夏热冬冷地区自耦合热泵空调系统性能研究
# An error occurred
# 考虑城市热岛的夏季空调设计日修正方法及应用研究
# 多源联网式供冷系统输配能耗及评价研究
# 基于室内双扩散型污染物通风控制的气流组织模式研究
# 地道风系统换热性能影响因素分析与设计优化研究
# 局部辐射供暖非均匀热环境特征及人体热状态实测研究
# 养老院典型卧室空气环境与新风量及气流组织设计优化研究
# 复合蓄热水箱热特性及其对高原太阳能供暖系统性能的影响研究
# 局部热风供暖非均匀热环境特征及背景辐射场的影响研究
# 风机盘管系统分布式模型预测控制研究
# 基于负荷预测的医院空调冷冻水系统优化研究
# 相变微胶囊悬浮液在地板辐射供暖中的流动换热特性
# An error occurred when close window
# 相邻影响条件下的通风空调管道系统粒子沉积特性研究
# 寒冷地区建筑供冷室内临界温度研究
# 高原建筑室内富氧热气流扩散特性及氧热环境协同营造方法研究
# 高效环保的高温热泵系统节流特性及补气策略研究
# An error occurred
# 户式空气源热泵双末端系统在陕南地区住宅的应用研究
# 多柱面贴附通风模式下气流汇聚机理及分布特征研究
# 面向需求响应的空调系统削减用电高峰的优化控制策略
# 某高校大礼堂的空调系统负荷预测与节能优化
# 关中农村家庭用能模式分类及柔性负荷优化调度研究
# 基于竞争风险模型的电梯寿命的研究
# 基于多传感器数据融合的智慧建筑空间占用检测技术研究
# 基于蜂眼视觉仿生隐私保护机制的居家视频监控智能应用研究
# An error occurred
# 面向智慧建筑的空间占用检测算法研究
# 智能家居设备识别与防御技术研究
# 面向域内与域间安全的智能家居访问控制建模与验证研究
# 智能家居设备网络流量混淆技术研究
# 基于神经网络的无接触电梯控制系统的应用研究
# 基于嵌入式人脸识别的门禁设计
# 垂直电梯导轨多参数检测机器人的设计与研究
# 基于无线传感器网络的多仓库监控系统研制
# 0 4797
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 4797
# 0 243
# year month has pdfs:7500
# 碱矿渣泡沬保温材料的制备及性能优化
# 基于环境数据的建筑室内空间人员占用水平预测技术研究
# 木结构建筑室内温湿度预测模型研究
# 数据驱动的冷水机组多故障检测与诊断方法及应用研究
# 复合型区域供热系统荷-储耦合结构优化
# 外融冰式冰蓄冷系统融冰过程中对流换热实验与数值模拟研究
# 基于LightGBM的冷水机组故障检测与诊断方法研究
# 偏差电量考核机制下空调群控制策略研究
# 基于可燃物存在的商场中庭排烟研究
# 基于嵌入式的智能供暖控制平台设计与实现
# 环境风对高层办公建筑楼梯间自然防烟影响的数值模拟研究
# 暖通空调系统的时间序列优化控制
# 夏季风冷式PVT空调系统性能及影响因素研究
# 太阳能新风系统辨识及控制算法研究
# 基于混合数据驱动模型的空调负荷预测方法研究
# 西安市高校体育馆自然通风优化设计研究
# 民居建筑光热光伏供能系统运行特性分析及匹配优化研究
# 太阳能与空气源热泵联合按需分时供暖柔性控制方法研究
# 基于深度学习的中央空调负荷预测与优化控制研究
# 碰撞射流结合无风道个性化送风改善供冷季室内热环境的研究
# An error occurred when close window
# An error occurred when close window
# 长距离综合管廊电缆舱局部通风方法及换热效果研究
# 深部地下空间安全岛的空气环境设计及控制研究
# 灌浆修补对含缺陷套筒连接力学性能影响研究
# 砂廊支护设计与FLAC3D数值模拟
# 基坑开挖引起下方纵向斜穿地铁隧道的隆起变形分析
# 大体积钢筋混凝土结构抗裂监测与分析
# 基于温度监测的大体积混凝土温控设计有限元反演分析
# 基于神经嵌套遗传算法的大体积混凝土监测优化研究
# 装配式框架梁企口连接区域受力性能研究
# 预制装配式框架梁柱暗牛腿角钢连接区域受力性能研究
# W项目工程质量管理提升研究
# 节段预制拼装护栏UHPC接缝抗剪性能研究
# 大型建设项目监理方风险管理能力评价研究
# EPC模式下总承包方风险识别与评价研究
# 基于深度学习的混凝土裂缝图像语义分割方法
# 岩溶地基处理关键技术与应用研究
# 园林绿化工程项目建设进度管理研究——以花溪公园为例
# 基于贝叶斯网络的全过程咨询模式下的工程项目风险评估研究
# 基于PDCA的建筑工程施工项目质量评价及控制对策研究——以FSD学院学生公寓扩建工程为例
# 深厚淤泥质土层复杂环境下大面积基坑支护研究
# 0 4818
# 0 243
# year month has pdfs:7500
# PHC螺旋管桩施工工艺及竖向抗拔承载特性研究
# 装配式建筑项目施工质量综合评价研究
# 装配式建筑项目供应链绩效综合评价及提升策略研究
# An error occurred
# 大体积混凝土施工期温度预测控制研究
# 考虑公众自媒体监督的工程质量监管演化博弈分析
# 基于解耦视角的A公司产品研发项目进度管理优化研究
# An error occurred
# 基于阻尼振动法的灌浆套筒饱满度识别研究
# 基于智能通信平台的建筑健康监测研究与实现
# 基于物联网的智能回弹仪系统的设计与实现
# 基于数字孪生的装配式建筑施工过程动态调度研究
# 外粘钢加固既有厂房结构的材料强度与变形机理研究
# An error occurred
# 岩溶区灌注桩砼超灌问题力学分析及其控制研究
# 承重墙托换技术在既有建筑物中的应用与研究
# 螺栓连接装配式梁锚栓承载力研究
# H监理公司监理服务质量提升对策研究
# An error occurred
# 基于清晰感知机制的岩土钻孔视频拼接方法研究
# 基于神经网络算法的钢支撑智能伺服控制系统研究
# 基于深度学习的深基坑施工隐患智能识别研究
# 现代农业产业园基础设施工程管理模式选择研究
# 大体积混凝土筏板基础裂缝机理及控制方法研究
# An error occurred when close window
# HY污水厂改扩建项目进度管理优化研究
# 基于改进粒子群算法的工程项目多目标优化研究
# 建筑外保温饰面层瓷砖脱落风险分析及管控研究
# QD公司WBY项目施工阶段质量控制策略管理
# An error occurred
# 气温骤降对大体积混凝土温度场的影响研究
# 基于关键链技术的ALBB项目进度管理研究
# 绿色宜居村镇文旅项目工程承包模式选择研究
# 基于Borda序值与模糊三维矩阵集成的A建筑项目风险管理研究
# 建筑机器人自组网拓扑控制与路由优化研究
# An error occurred
# 装配式弦支钢-砼组合楼盖叠合板及其连接构件力学性能研究
# 基坑组合式冻结支护的温度场和应力场演化特性研究
# 组合式冻结法在基坑支护工程中的应用研究
# 室内装修场景下机器人自主导航策略研究
# 基于物联网技术的装配式建筑施工一体化管理技术研究
# 基于建筑信息模型的G建筑项目质量管理研究
# SG风电导管架项目建造过程质量管理研究
# HY园林项目施工进度管理研究
# XW乡镇医院建设项目甲方进度管理优化研究
# An error occurred
# K市职教中心教学楼扩建项目进度管理研究
# 青岛万科C地产项目施工建设风险管理研究
# An error occurred when close window
# 0 4858
# 0 243
# year month has pdfs:7500
# Z液压胶管建设项目安全风险管理研究
# EPC模式下国有企业某建设项目的风险管理研究
# 住宅小区建设项目工程质量管理评价体系构建研究——以LS住宅小区建设项目为例
# L市D片区棚改项目风险管理研究
# 基于关键链技术的J公司A项目进度管理研究
# LX市政基础设施EPC项目风险管理研究
# H物联网企业基地建设项目经理胜任力模型构建及应用研究
# Z公司二期扩建项目安全风险管理研究
# 胶州市X村污水管道施工项目质量管理提升研究
# An error occurred
# L区“平安城市”项目质量管理研究
# H小学教学楼建设项目施工质量管理研究
# A配电网建设项目施工风险管理研究
# YZ220千伏输变电工程项目风险管理研究
# SA热电智慧供热调度中心项目进度管理研究
# LW智慧园区改造项目进度管理研究
# An error occurred
# 不确定环境下装配式预制构件混流生产调度优化研究
# 整体钢平台顶升模架体系的施工预警方法研究
# 沟通与信任与团队冲突的相互作用及其对建设项目成功的影响研究
# 工程车辆智能化清洗与检测的关键技术研究
# An error occurred
# 柱塞泵压力脉动对液压挖掘机振动特性的影响机理研究
# An error occurred when close window
# 电传动工程车辆开关磁阻电机运行特性研究
# 基于可调压式恒压蓄能器的挖掘机动臂势能回收控制研究
# 挖掘机工作装置轨迹规划及控制研究
# 反铲挖掘机铲掘阻力研究及铲掘轨迹设计
# An error occurred
# 基于高空吊篮喷涂机器人的建筑物外墙智能识别和SLAM算法研究
# An error occurred
# 基于模糊控制的工程车自动变速控制器设计与优化研究
# An error occurred
# 混凝土泵车关键液压系统建模与仿真分析
# 车载一体化配料装置输送机转臂结构优化与设计研究
# An error occurred
# 市政工程造价数据库构架设计研究
# 基于联邦滤波的多传感器地下管道定位方法
# 基于LoRa的低功耗智能井盖监控系统设计
# 地下综合管廊火灾烟流特性及燃气泄漏扩散影响研究
# 直埋管线综合系统的韧性与脆弱性评价及对比研究
# 城市小型综合管廊运维期安全性评估
# An error occurred
# 承插式混凝土管道接头力学特性研究与工程应用
# PE管与原位固化内衬复合结构的外压承载性能研究
# An error occurred
# 泵站管道系统振动的有限元分析及软件二次开发
# 供水管网仿真预测方法研究
# 城市供水管网可视化管理系统研究与实现
# 多阀防护压力供水系统水锤研究
# An error occurred when close window
# An error occurred when close window
# 0 4898
# 0 0
# list index out of range
# 0 4898
# 0 0
# list index out of range
# 0 4898
# 0 0
# list index out of range
# 0 4898
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 4898
# 0 243
# year month has pdfs:7500
# 空气阀防护长距离泵输水系统水锤研究
# 分布式光纤温度测量系统研究及其在供水管道渗漏监测中的应用
# 预氧化缓解赣江原水有机物对纳滤膜污染的研究
# 管材与微生物群落结构对供水管道生物膜形成和耐氯性的影响研究
# 一体式铁盐絮体—超滤净水工艺中试研究
# 预氧化—粉末活性炭强化微涡流絮凝工艺处理含藻水的试验研究
# 普通快滤池反冲洗方式及其参数的中试研究
# 基于改进模糊PID预估算法的混凝投药控制系统研究与设计
# 基于神经网络的用水量预测及供水管网漏损检测研究
# UV/Fenton体系强化混凝去除铜绿微囊藻及藻毒素实验研究
# An error occurred
# 供水系统中镀锌钢管腐蚀与缓蚀的机制研究
# 某供水泵站风险分析及管控研究
# 城市供水系统风险评价研究
# An error occurred
# S项目室外排水设计方案评价与选择
# 适用于纯水超纯水的智能一体式EDI模块的研制
# 基于深度学习的漏水信号检测研究
# 城镇供水系统环境中霉菌暴露的污染风险及机制
# 混凝控垢剂开发及其同步除浊控垢效能研究
# 微纳米气泡共混凝用于强化混凝效能及缓解超滤膜污染的研究
# 介质加载循环结团造粒流化床处理高藻水中试试验研究
# An error occurred when close window
# 氟磷酸钙结晶特性及结晶造粒流化床除氟研究
# 集蓄坝与岸滤组合取水技术对山区村镇浅水河流的适用性研究
# 滞留与菌源有机物诱导管道饮用水水质变化的微生态机制研究
# 流速变化与水质扰动耦合影响下的给水管网铁释放研究
# 地表水源水质季节性变化条件下常规处理工艺优化研究
# 煮沸饮用水同步削减镉、砷污染物的效能与机制研究
# An error occurred
# 基于层次分析法的村镇饮用水水源地安全评价方法研究及应用
# 常熟城市内涝常态化治理研究
# An error occurred
# 绿色屋顶生物炭改性基质径流截留特性研究
# 基于海绵城市建设的合流制溢流控制研究
# 基于众包模式的城市内涝监测方法研究与应用
# 基于SWMM和FVCOM耦合模型的城市内涝模拟研究
# 取消化粪池对排水系统的影响研究——以重庆为例
# 暴雨雨型对城市洪水中人车失稳风险变化影响研究
# 郑州市洪涝灾害风险分析与评价
# An error occurred
# 鹰潭市老城区内涝灾害风险评估
# 海绵城市建设立法研究
# 碱性条件下污水管道沉积物凝胶结构解溶及粘附抗性提升研究
# 不同管材污水管道的生物膜生长规律及种群代谢特性
# 碱性草木灰投加抑制污水管道有害气体生成的效能与机制
# 0 4938
# 0 243
# year month has pdfs:7500
# 基于多重公平维度的城市洪涝灾害应急资源调度研究
# Z新建居住区海绵化设计方案选择与优化研究
# An error occurred
# 合流制管道溢流调蓄池的污染调控特性与机制研究
# 城市雨水排水系统弹性分析及提升措施研究
# 沣西新城创新港中学海绵设施景观设计研究
# 基于海绵城市理念的白马河公园碳汇量化与设计研究
# 西安市居住区雨水景观的感知评价及优化设计研究
# 污水管道中甲烷与硫化物生物代谢的水力调控机制研究
# An error occurred
# 易积水场地海绵设施规模优化及环境效益预评价
# 污水管道涂层材料制备及其抗微生物腐蚀试验研究
# 生物质锅炉供热管理系统的设计、分析及评价
# 基于次声波的供热管道泄漏监测方法研究及应用
# 基于次声波法的供热管道泄漏检测方法研究及应用
# An error occurred
# 集中供热系统室内温度分布式模型预测控制
# 基于卷积神经网络的小样本管道缺陷智能识别研究
# 基于声发射信号的埋地燃气管道第三方破坏检测研究
# An error occurred
# 基于燃气管网多尺度参数化建模方法研究
# 基于GA-LSTM与迁移学习的短期天然气负荷预测及调峰策略研究
# An error occurred
# 基于维纳过程的城市燃气管道剩余寿命预测模型研究
# 水液滴在热流场中运动特性的数值研究
# An error occurred when close window
# 砖木结构古建筑火灾风险分析与数值模拟研究——以庙宇类建筑为例
# 高架仓库火灾韧性评估及提升对策研究
# 背风涡旋效应下并列式建筑群外立面溢流火焰演化行为
# An error occurred
# 基于参数随机性的商业综合体火灾疏散风险评估研究
# 商业综合体火灾风险评价研究——以D商业综合体为例
# An error occurred
# 文旅融合视域下的公共设施设计研究——以鄂城钢铁厂景区为例
# 基于产城融合下的鄂州工业文旅小镇公共设施设计研究
# 城市综合体火灾风险安全评价与管理
# 黄泛平原典型古镇洪涝韧性空间模式研究
# 体育场馆应急疏散路径脆弱性分析及恢复策略
# 基于TOD超大超深基坑工程稳定性分析
# 超大深基坑地下连续墙支护结构变形分析
# 淤泥质软土下双护筒桩基负摩阻力特性研究
# 循环荷载下饱和黏土的超固结特性研究
# 含根膨胀土持水与渗透特性试验研究
# 根系对膨胀土裂隙发育演化规律的影响研究
# 复杂工作条件下荷载箱适应性研究
# An error occurred
# 基于广西三类主要地层扩大头钢筋笼抗浮锚杆承载特性研究
# 基于预熔理论的冻土水热力耦合模型研究
# 黄土边坡滑动模型试验及抗滑桩破坏模式分析
# An error occurred when close window
# An error occurred when close window
# 0 4978
# 0 243
# year month has pdfs:7500
# 砖木结构古建筑火灾风险分析与数值模拟研究——以庙宇类建筑为例
# 高架仓库火灾韧性评估及提升对策研究
# 背风涡旋效应下并列式建筑群外立面溢流火焰演化行为
# 基于参数随机性的商业综合体火灾疏散风险评估研究
# 商业综合体火灾风险评价研究——以D商业综合体为例
# 文旅融合视域下的公共设施设计研究——以鄂城钢铁厂景区为例
# 基于产城融合下的鄂州工业文旅小镇公共设施设计研究
# 城市综合体火灾风险安全评价与管理
# 黄泛平原典型古镇洪涝韧性空间模式研究
# 体育场馆应急疏散路径脆弱性分析及恢复策略
# 基于TOD超大超深基坑工程稳定性分析
# 超大深基坑地下连续墙支护结构变形分析
# 淤泥质软土下双护筒桩基负摩阻力特性研究
# 循环荷载下饱和黏土的超固结特性研究
# 含根膨胀土持水与渗透特性试验研究
# 根系对膨胀土裂隙发育演化规律的影响研究
# 复杂工作条件下荷载箱适应性研究
# 基于广西三类主要地层扩大头钢筋笼抗浮锚杆承载特性研究
# 基于预熔理论的冻土水热力耦合模型研究
# 黄土边坡滑动模型试验及抗滑桩破坏模式分析
# An error occurred when close window
# 黄土的结构性演变规律与强度变形特性的研究
# 真三轴应力条件下黄土增湿变形及其结构性演化规律研究
# 不同坡比下黄土边坡降雨入渗规律室内模型试验研究
# 粉质粘土的固化改良及其加筋力学特性研究
# An error occurred
# 新型注浆螺旋桩的承载性能理论及试验研究
# 长短桩围护结构在土岩复合地层基坑中的应用研究
# An error occurred
# 劲性复合管桩支护结构力学特性研究
# 基于光弹实验的主动桩水平拱效应研究
# 基于高阶剪切变形板理论的地下连续墙侧向变形研究
# 氯盐侵蚀环境下悬臂式挡土墙力学性能研究
# 基于内聚力模型的悬臂式抗滑桩承载性能研究
# 氯离子侵蚀条件下预应力锚索粘结性能研究
# An error occurred
# 磁性浆液运动机理与钻注一体磁锚修复技术研究
# 朱然墓遗址结构性黏土变形和强度特性试验研究
# An error occurred
# 基于孔径分布的朱然墓遗址土饱和-非饱和渗透性预测
# 物理信息神经网络模型的边界条件处理研究
# 微生物诱导（MICP）磷石膏矿化的固砂性能及调控研究
# 新型调理剂对滨海盐渍土的改良效果及机理研究
# 土工合成材料加固钙质砂静力特性研究
# An error occurred
# 考虑板桩形状效应的双排钢板桩结构水平承载特性及简化算法
# 0 4999
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 4999
# 0 0
# list index out of range
# 0 4999
# 0 0
# list index out of range
# 0 4999
# 0 243
# year month has pdfs:7500
# 砂卵石土体的渗透性研究
# 砂土地基中裙式吸力桶基础稳定性及其优化设计
# 基于修正应变软化模型的黏土中T型探头贯入特性分析
# 复杂条件下边坡三维建模及稳定性数值分析研究
# 掺矿粉与粉煤灰的水泥土抗压及渗透性能研究
# 苎麻纤维加筋土的强度特性研究
# 盐溶液环境下砂土热学及电学特征研究
# 基于核磁共振技术的膨胀土膨胀特性分析
# 桂林龙胜千枚岩残积土的一维压缩试验研究
# 击实组构影响的非饱和红黏土变形与刚度特性
# An error occurred
# 高岭土固结过程孔隙水分布形态及渗透性研究
# 干湿循环作用下红黏土裂隙发育规律及强度劣化机理研究
# 微生物诱导碳酸钙沉积固化红色松散砒砂岩机理研究
# 冻融循环下纤维煤矸石复合改良土力学性能及数值分析
# 预埋带锚板预应力螺纹钢筋抗拔性能研究
# 基于大数据和神经网络的桩基承载力及沉降预测
# 岩溶区桩基空孔对周围建筑地基固结蠕变特性影响的研究
# 上覆压力对湛江组结构性黏土触变性的影响研究
# 考虑湛江组结构性黏土触变性的单桩沉降时效性计算方法
# 地下水位波动对覆盖型岩溶塌陷影响的模型试验研究
# An error occurred when close window
# 长江边马钢原料堆场基土固结沉降变形规律研究
# 基于CT图像的砾石土微观结构分析及模拟重构
# An error occurred
# 生物炭改良膨胀土的工程特性及边坡浅表层稳定性研究
# 基于南宁盆地泥岩地层螺纹挤土灌注桩适应性研究
# An error occurred
# 牡蛎壳粉改良膨胀土的工程特性及裂隙特征研究
# 既有竖向荷载下带承台单桩水平承载机理的宏细观研究
# 干湿循环下工业甘蔗渣—低碱生态水泥改良膨胀土土水特性及边坡稳定性研究
# 野牛草根系对边坡土体抗剪强度的影响
# 生物聚合物改良膨胀土的试验研究
# 玻璃纤维网在生土面层中的锚固和搭接性能研究
# An error occurred
# 玻璃纤维网增强生土面层抗拉性能的试验研究
# 焊接锚垫板锚固区裂纹扩展与破坏规律
# An error occurred
# 对拉式加筋土挡墙筋材特性试验与结构行为数值模拟研究
# 静动荷载作用下土工织物加筋土挡墙力学行为研究
# 超软土-桩界面强度及变形特性试验研究
# 岩溶区桩基下伏椭圆形溶洞稳定性研究
# 考虑蠕变随机性的黄土高贴坡变形预测方法研究
# 水平斜交荷载-竖向荷载共同作用下斜桩承载变形性状研究
# 大豆脲酶诱导碳酸钙沉淀对砂岩细观结构及力学特性影响的试验研究
# 木质素磺酸钙改性湿陷性黄土的力学性质与微观机理研究
# 0 5037
# 0 243
# year month has pdfs:7500
# 长江边马钢原料堆场基土固结沉降变形规律研究
# 基于CT图像的砾石土微观结构分析及模拟重构
# 生物炭改良膨胀土的工程特性及边坡浅表层稳定性研究
# 基于南宁盆地泥岩地层螺纹挤土灌注桩适应性研究
# 牡蛎壳粉改良膨胀土的工程特性及裂隙特征研究
# 既有竖向荷载下带承台单桩水平承载机理的宏细观研究
# 干湿循环下工业甘蔗渣—低碱生态水泥改良膨胀土土水特性及边坡稳定性研究
# 野牛草根系对边坡土体抗剪强度的影响
# 生物聚合物改良膨胀土的试验研究
# 玻璃纤维网在生土面层中的锚固和搭接性能研究
# 玻璃纤维网增强生土面层抗拉性能的试验研究
# 焊接锚垫板锚固区裂纹扩展与破坏规律
# 对拉式加筋土挡墙筋材特性试验与结构行为数值模拟研究
# 静动荷载作用下土工织物加筋土挡墙力学行为研究
# An error occurred
# 超软土-桩界面强度及变形特性试验研究
# 岩溶区桩基下伏椭圆形溶洞稳定性研究
# 考虑蠕变随机性的黄土高贴坡变形预测方法研究
# 水平斜交荷载-竖向荷载共同作用下斜桩承载变形性状研究
# 大豆脲酶诱导碳酸钙沉淀对砂岩细观结构及力学特性影响的试验研究
# 木质素磺酸钙改性湿陷性黄土的力学性质与微观机理研究
# An error occurred when close window
# 喷射秸秆加筋黄土强度及稳定性研究
# 黄土地层水泥砂浆锚杆锚固界面力学性质及承载力研究
# 冻融循环条件下垃圾渗滤液污染黄土冻结温度试验研究
# 湿陷性黄土地基高能级增湿强夯试验研究
# An error occurred
# 火力发电厂汽轮机基础结构形式优化与动力响应分析
# 黄土场地静压钢管桩承载力时间效应研究
# 倾斜桩支护黄土基坑性状模型试验及数值分析
# 基于垃圾渗滤液环境条件下木质素磺酸钙改良黄土的工程特性试验研究
# An error occurred
# 交通荷载作用下饱和原状黄土动力特性试验及数值模拟研究
# 自动化绿篱造型修剪机的设计与研究
# 基于“双评价”的广西凭祥市城镇开发边界划定
# 基于图像-点云处理技术园林绿篱对中算法研究
# 基于微博数据感知的南宁市城市意象研究
# 乡镇国土空间规划编制现状、困境与对策——以苏州市Z镇为例
# 苏州市G区城市园林绿化数字化管理问题及对策研究
# 太仓市国土空间规划编制与实施管理问题研究
# 基于EOD理念的唐山市街道临时性景观设计研究
# 基于生态适应性理念的空心村整治规划策略研究——以陕西省洋县为例
# An error occurred
# 广州社区商业建筑骑楼空间设计策略研究
# 集体记忆下传统村落空间环境活化设计研究——以镇江华山村为例
# 0 5059
# 0 0
# list index out of range
# 0 5059
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5059
# 0 0
# list index out of range
# 0 5059
# 0 243
# year month has pdfs:7500
# 基于多源数据的上海黄浦江滨水公共空间活力测度研究
# 特色小镇项目建设与运行管理问题研究——以桓台县创智梦想小镇为例
# 公共设施健全度视角下城市宜居性空间诊断及提升策略
# 全矢量旅游人文地图符号库的设计与实现
# An error occurred
# 基于季相色彩的居住区植物配置模式研究——以福州市城市居住区为例
# 屏南县传统村落空间肌理参数化解析及风貌营造研究
# “土掌房”村落景观空间的活化研究——以云南红河州城子古村为例
# 福建南靖土楼历史文化名村景观资源评价及优化策略研究
# An error occurred
# 老年友好视角下福州市公园绿地布局公平性研究
# An error occurred
# 大数据视域下城市滨水公园健康功能提升研究——以闽江公园北园为例
# 基于鸟类多样性提升的福州市社区公园景观营造策略研究
# 基于灰色关联分析的地质公园地质类环境教育评价研究
# 福州市长乐区绿色空间格局演变对生境质量影响及优化预测研究
# 福州上下杭历史文化街区街巷景观空间特征及其保护更新研究
# 响应线上线下大型线性体育活动的街道景观韧性研究
# 城市街道景观步行适宜性研究
# 山水城市休闲步道系统评价及设计策略研究——以福州为例
# 浦城县匡山国家森林公园康养基地规划
# 福州市内河沿岸串珠公园管理问题及对策研究
# 基于农旅融合的乡村景观设计研究——以长阳县佑溪村为例
# An error occurred when close window
# An error occurred when close window
# 基于多源数据的上海黄浦江滨水公共空间活力测度研究
# 基于CA-Markov模型的三峡库区城镇空间演变及预测研究——以湖北段为例
# 重庆市TOD综合体地下开放式中介空间舒适性优化研究
# 文化基因视角下的重庆校园历史建筑再利用研究
# A物流园区选址风险识别与防范措施研究
# 国土空间规划背景下村庄规划设计研究——以南江村为例方案优选
# 1950-1990年代赣州古城空间形态演变研究
# 江西省传统村落康养活化研究——以金溪县全坊村为例
# 《西游记》主题卡通形象公共艺术作品在儿童娱乐空间中的应用
# An error occurred
# 瑞金市武阳村长征第一桥文化公园设计
# 南京市特色小镇发展对策研究
# An error occurred
# 医院植物景观调查评价与提升策略研究——以江苏省十二所三甲医院为例
# “足征市隐，深意画图”：基于园记文本挖掘的明清江南园林审美特征研究
# An error occurred
# 江苏乡村旅游区布局特征与高星级典型案例建设成效评价研究
# 基于区域差异的主题创意农园空间分布特征与综合评价研究——以江苏省实证调研项目为例
# 淮安市乡村人居环境评价研究
# 基于游憩机会谱理论的南京市绿博园景观优化设计策略研究
# 环境行为学视角下城市街道景观更新营造——以南京市南秀村路为例
# 景观公正背景下的城市绅士化研究——以合肥市环城公园周边区域为例
# 传播学视角下的红楼文化景观研究——以南京为例
# An error occurred when close window
# 0 5097
# 0 243
# year month has pdfs:7500
# 基于非物质文化遗产传承的城市公园景观设计研究——以汉川霍城公园为例
# 基于CA-Markov模型的三峡库区城镇空间演变及预测研究——以湖北段为例
# 重庆市TOD综合体地下开放式中介空间舒适性优化研究
# 文化基因视角下的重庆校园历史建筑再利用研究
# A物流园区选址风险识别与防范措施研究
# 国土空间规划背景下村庄规划设计研究——以南江村为例方案优选
# 1950-1990年代赣州古城空间形态演变研究
# 江西省传统村落康养活化研究——以金溪县全坊村为例
# 《西游记》主题卡通形象公共艺术作品在儿童娱乐空间中的应用
# 瑞金市武阳村长征第一桥文化公园设计
# 南京市特色小镇发展对策研究
# 医院植物景观调查评价与提升策略研究——以江苏省十二所三甲医院为例
# “足征市隐，深意画图”：基于园记文本挖掘的明清江南园林审美特征研究
# 江苏乡村旅游区布局特征与高星级典型案例建设成效评价研究
# 基于区域差异的主题创意农园空间分布特征与综合评价研究——以江苏省实证调研项目为例
# 淮安市乡村人居环境评价研究
# An error occurred
# 基于游憩机会谱理论的南京市绿博园景观优化设计策略研究
# 环境行为学视角下城市街道景观更新营造——以南京市南秀村路为例
# 景观公正背景下的城市绅士化研究——以合肥市环城公园周边区域为例
# 传播学视角下的红楼文化景观研究——以南京为例
# An error occurred when close window
# 基于非物质文化遗产传承的城市公园景观设计研究——以汉川霍城公园为例
# 基于CA-Markov模型的三峡库区城镇空间演变及预测研究——以湖北段为例
# An error occurred
# 重庆市TOD综合体地下开放式中介空间舒适性优化研究
# An error occurred
# 文化基因视角下的重庆校园历史建筑再利用研究
# A物流园区选址风险识别与防范措施研究
# An error occurred
# 国土空间规划背景下村庄规划设计研究——以南江村为例方案优选
# 1950-1990年代赣州古城空间形态演变研究
# 江西省传统村落康养活化研究——以金溪县全坊村为例
# 《西游记》主题卡通形象公共艺术作品在儿童娱乐空间中的应用
# 瑞金市武阳村长征第一桥文化公园设计
# 南京市特色小镇发展对策研究
# 医院植物景观调查评价与提升策略研究——以江苏省十二所三甲医院为例
# “足征市隐，深意画图”：基于园记文本挖掘的明清江南园林审美特征研究
# 江苏乡村旅游区布局特征与高星级典型案例建设成效评价研究
# An error occurred
# 基于区域差异的主题创意农园空间分布特征与综合评价研究——以江苏省实证调研项目为例
# 淮安市乡村人居环境评价研究
# An error occurred
# 基于游憩机会谱理论的南京市绿博园景观优化设计策略研究
# 环境行为学视角下城市街道景观更新营造——以南京市南秀村路为例
# 景观公正背景下的城市绅士化研究——以合肥市环城公园周边区域为例
# An error occurred
# 传播学视角下的红楼文化景观研究——以南京为例
# An error occurred when close window
# 0 5118
# 0 243
# year month has pdfs:7500
# 乡村振兴背景下咸阳市天阁村文化基因优化设计策略研究
# 环境感知视角下的工业遗存居住街区景观提升设计研究——以西安纺织城四棉居住街区为例
# 触媒理论下生态工业园厂区环境设计研究——以北京通州有机垃圾处理中心环境设计为例
# 汉长安城遗址周边村落街巷空间活态研究——以东方红村为例
# 基于耗散结构理论的帝陵遗址景观有机性保护研究——以汉杜陵为例
# 存量背景下老旧社区景观更新策略研究——以西安市安东街老旧社区为例
# An error occurred
# 智慧养老模式下社区景观适老化设计研究——以白银市银光路社区为例
# 西安下马陵传统街区外卖空间系统微更新研究
# 美育背景下儿童活动空间设计研究——以西安地区为例
# 基于文化生态学视域下的凤州古城回汉共融人居环境更新设计研究
# 漓江流域传统村落建筑景观装饰艺术转译及模式语言研究
# 桂林城市综合公园使用后评价（POE）研究
# 桂林山水园林营建历程及机理研究
# 地方依恋视角下龙脊梯田居民农业文化遗产保护行为态度影响研究
# 五皇山国家地质公园野生植物资源调查与园林应用评价
# 空间生产理论视角下肇兴侗寨旅游空间生产研究
# 弹性理念在滨海乡村景观设计中的应用研究——以白马岙村为例
# 杭州市中心城区“三生空间”时空演化特征及优化策略研究
# 杭州都市圈空间经济联系网络结构演化特征及优化策略研究
# 城市公园视听觉景观耦合协调解析与设计研究——以杭州市白马湖公园为例
# An error occurred when close window
# 空间正义视角下的城市滨水景观规划设计研究
# 基于场景理论的社区公园交往空间设计研究
# An error occurred
# 基于社区生活圈健身供给的消极空间活化策略
# 基于透明性理论的街头游园设计研究
# “主动式健康”导向下大学校园户外空间设计研究
# 基于空间生产理论的杭州运河绿道公园活化设计——以青莎公园为例
# An error occurred
# 基于织补理论的老街意象重塑设计研究——以绍兴府直街为例
# 基于PLUS模型的阿拉善左旗土地利用景观格局变化研究
# 呼和浩特市银都福邸居住小区园林景观规划设计
# An error occurred
# 青岛市城市绿地园林植物建植模式选择与评价
# 乌兰察布市兴和县和华苑居住小区景观规划设计
# 呼和浩特市哈拉沁生态公园景观规划设计
# 阿荣旗牧人寨生态旅游区景观规划设计
# 土默特左旗上达赖敖包生态旅游区景观规划设计
# 基于生态修复理念的康巴什区阿布亥沟补洞沟口段河道景观规划设计
# 基于共建共治共享理论下的老旧小区景观改造后评价——以杭州市为例
# 呼和浩特市东干丈村景观规划设计
# 呼和浩特市民案村景观提升规划设计
# 内蒙古电力科学研究院立体绿化设计研究
# 基于乡村振兴战略背景下河南省南阳市罗营村乡村景观改造设计
# 0 5157
# 0 243
# year month has pdfs:7500
# 空间正义视角下的城市滨水景观规划设计研究
# 基于场景理论的社区公园交往空间设计研究
# An error occurred
# 基于社区生活圈健身供给的消极空间活化策略
# 基于透明性理论的街头游园设计研究
# “主动式健康”导向下大学校园户外空间设计研究
# 基于空间生产理论的杭州运河绿道公园活化设计——以青莎公园为例
# 基于织补理论的老街意象重塑设计研究——以绍兴府直街为例
# An error occurred
# 基于PLUS模型的阿拉善左旗土地利用景观格局变化研究
# 呼和浩特市银都福邸居住小区园林景观规划设计
# 青岛市城市绿地园林植物建植模式选择与评价
# 乌兰察布市兴和县和华苑居住小区景观规划设计
# An error occurred
# 呼和浩特市哈拉沁生态公园景观规划设计
# 阿荣旗牧人寨生态旅游区景观规划设计
# 土默特左旗上达赖敖包生态旅游区景观规划设计
# 基于生态修复理念的康巴什区阿布亥沟补洞沟口段河道景观规划设计
# An error occurred
# 基于共建共治共享理论下的老旧小区景观改造后评价——以杭州市为例
# An error occurred
# 呼和浩特市东干丈村景观规划设计
# 呼和浩特市民案村景观提升规划设计
# An error occurred
# 内蒙古电力科学研究院立体绿化设计研究
# 基于乡村振兴战略背景下河南省南阳市罗营村乡村景观改造设计
# 城市公园互动型景观更新改造设计——以青岛祥茂河公园为例
# 烟台市牟平区滟澜海岸滨海公园景观规划设计
# 张家口市赐儿山森林公园景观规划设计
# 基于“丝绸之路”文化的西安植物园文化主题园景观提升设计
# 新疆沙雅县农业产业观光园规划与景观设计
# 基于人本尺度的城市干道街景空间品质优化设计——以秦皇岛市金山大街与紫荆路交汇片区为例
# An error occurred
# 牧旅产业融合背景下正蓝旗五一八分场休闲观光牧场景观规划设计
# 阿拉善定远营古城旅游区景观环境调查研究
# 呼和浩特市科林公园景观规划设计
# 通辽市莫力庙沙湖旅游区景观规划设计
# 呼和浩特市明珠丽景小区东区景观规划设计
# 基于有机更新理论的呼和浩特市新华公园改造设计
# An error occurred
# 呼和浩特市创客公园景观规划设计
# 内蒙古自治区文化景观遗产价值评价体系构建研究
# 内蒙古包头市儿童公园景观改造设计
# 朝阳市儿童公园景观规划设计
# 基于康复理念的呼和浩特市第一医院景观改造设计
# 基于城市滨河景观生态理念对呼和浩特市扎达盖河滨河公园改造设计
# 呼和浩特市大台什居住区园林景观改造设计
# 呼和浩特市纺织公园景观规划设计
# An error occurred when close window
# 0 5178
# 0 243
# year month has pdfs:7500
