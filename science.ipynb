# %%
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time
import winsound
import calendar
import datetime
import time
import re
import os

# %%
name = "m_science.txt"
with open(name, "r") as f:
    line = f.read().strip() 
    downloaded = int(line)
    cur_downloaded = 0

# %%
def startdownload(download_dir, url, name):
    global cur_downloaded, downloaded
    with open(name, "r") as f:
        line = f.read().strip() 
        downloaded = int(line)
        cur_downloaded = 0
    print(cur_downloaded, downloaded)
    # download_dir = r"D:\zhiwangpdf\0715"
    edge_options = Options()
    prefs = {
        "download.default_directory": download_dir,
        "profile.default_content_settings.popups": 0,
        "directory_upgrade": True
    }
    User_Agent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'
    edge_options.add_argument(f"user-agent={User_Agent}")
    edge_options.add_experimental_option("prefs", prefs)
    # edge_options.add_argument("--headless")  # 在后台运行浏览器

    # 设置Edge驱动路径
    webdriver_service = Service(r"E:\bingdownload\edgedriver_win64\msedgedriver.exe")
    # url = "https://cdfd.cnki.net/dejournals/#/cdfd/science"
    driver = webdriver.Edge(service=webdriver_service, options=edge_options)
    driver.get(url)
    time.sleep(2)
    
    #查找开始下载的year_month
    month_elmets = driver.find_elements(By.XPATH, '//div[@class="conneritembottomr"]/ul/li/a')
    i, j  = 0, len(month_elmets)
    print(i, j)
    while i < j:
        month_elmets[i].click()
        time.sleep(5)
        try:
            nums = driver.find_element(By.XPATH, '//div[@class="contentsbottomrb"]/div/span').text
            nums_list = re.findall(r"\d+", nums)
            nums = int("".join(nums_list))
            print(f"year month has pdfs:{nums}")
        except Exception as e:
            print(f"year month has pdfs:{nums}")
            print(e)
            nums = 0
        if nums == 0:
            driver.quit()
            driver = None
            break
        i += 1
        if cur_downloaded + nums <= downloaded:
            cur_downloaded += nums
            driver.back()
            time.sleep(5)
        else:
            break
        month_elmets = driver.find_elements(By.XPATH, '//div[@class="conneritembottomr"]/ul/li/a')
    return driver

def download_onepage(driver, name):
    # print(button[1].get_attribute("disabled"))
    cnt = 0
    flag = download_pdfs(driver, name)
    cnt += flag
    button = driver.find_elements(By.XPATH, '//div[@class="contentsbottomrb"]//button')
    while button[1].get_attribute("disabled") == None:
        button[1].click()
        # time.sleep(4)
        flag = download_pdfs(driver, name)
        cnt += flag
        if cnt == 2:
            driver.quit()
            return None
        button = driver.find_elements(By.XPATH, '//div[@class="contentsbottomrb"]//button')
    # flag = download_pdfs(driver, name)
    driver.quit()
    return None

def download_pdfs(driver, name):
    global downloaded, cur_downloaded 
    pdfs = driver.find_elements(By.XPATH, "//tbody/tr[@class='el-table__row']/td[1]/div[@class='cell']/a")
    main_window = driver.current_window_handle
    if cur_downloaded + len(pdfs) <= downloaded:
        cur_downloaded += len(pdfs)
        time.sleep(1)
        return False
    else:
        time.sleep(4)
        pdfs = driver.find_elements(By.XPATH, "//tbody/tr[@class='el-table__row']/td[1]/div[@class='cell']/a")
    i = 1
    window_set = set([main_window])
    for pdf in pdfs:
        try:
            print(pdf.text)
            pdf.click()
            time.sleep(2)
        except Exception as e:
            print("pdf html error.")
        windows = driver.window_handles
        # 切换到新窗口
        for window in windows:
            if window not in window_set:
                driver.switch_to.window(window)
                window_set.add(window)
                break
        try:
            dl_pdf = driver.find_element(By.XPATH, "//div[@id='DownLoadParts']/div/ul/li[3]/a")
            dl_pdf.click()
            time.sleep(2)
            #添加新产生的页面
            windows = driver.window_handles
            for window in windows:
                if window not in window_set:
                    window_set.add(window)
        except Exception as e:
            print(f"An error occurred")
        # time.sleep(2)
        driver.switch_to.window(main_window)
        i += 1
    cur_downloaded += len(pdfs)
    windows = driver.window_handles
    # 切换到新窗口
    time.sleep(20)
    for window in windows:
        try:
            if window != main_window:
                driver.switch_to.window(window)
                driver.close()
                time.sleep(0.5)
        except Exception as e:
            print(f"An error occurred when close window")
    driver.switch_to.window(main_window)
    with open(name, "w") as f:
        f.write(f"{cur_downloaded}")
    return True

# %%
while True:
    url = "https://cdfd.cnki.net/dejournals/#/cmfd/science"
    download_dir = r"G:\zhiwangpdf\0716"
    try:
        driver = startdownload(download_dir, url, name)
        download_onepage(driver, name)
    except Exception as e:
        print(e)
# Out:
# 0 1680
# 0 243
# year month has pdfs:4296
# 基于石墨烯的透明可调谐吸波器设计
# 基于大地电磁法的水力压裂裂缝识别
# 基于有限元法的水力裂缝电磁响应正演模拟研究
# 弓网电弧电磁辐射快速仿真计算方法研究
# FDFD改进算法及半空间辐射耦合效应研究
# 瞬态电磁环境下列车电磁场分布特性仿真研究
# 列车速度传感器的弓网电弧辐射电磁干扰分析研究
# 弓网离线电磁骚扰特性影响因素试验及仿真
# 钴基材料的设计及其电磁波吸收性能研究
# 用于细胞刺激的太赫兹光学系统研究
# 低气压容性耦合等离子体放电特性的模拟研究
# 一种新型小电容ESD箝位电路
# 新型半导体材料CrSe2电子结构和光学性质的第一性原理
# 二维金属/半导体垂直异质结的肖特基势垒研究
# 掺杂二维GaN及其异质结光电性质的第一性原理研究
# 半导体复合材料光催化及光阳极性能研究
# 有机变形晶态低维结构的精确构筑及其光子学研究
# 周期调制量子体系的光学特性及其应用研究
# 基于二维材料微纳器件的离子凝胶薄膜应用与协同调控的研究
# 陶瓷/金属复合结构抗侵彻近场动力学仿真方法研究
# An error occurred when close window
# 石墨烯增强碳化硼陶瓷及其力学性能研究
# TMDs/Ti3C2X2（X=S，Se，Cl，Br）异质结电子和力学性能的第一性原理研究
# An error occurred
# 非金属元素掺杂石墨烯异质结对其肖特基调控的理论研究
# 表面修饰对二维氮化镓性质影响的研究
# An error occurred
# 拓扑光子晶体的能带工程和慢光特性研究
# 二维平面异质结器件的电学性质研究
# 三维ZrTe5中磁光效应的理论研究
# 掺杂无机双钙钛矿发光材料的研究
# 纳米尺寸效应调控Haldane链反铁磁体R2BaNiO5（R=Er,Dy）磁性及磁热效应的研究
# 人工规范场下玻色—爱因斯坦凝聚的非互易量子输运
# 谐振势中自旋-1自旋轨道耦合玻色-爱因斯坦凝聚体的基态与集体激发特性
# 非均匀规范场下玻色-爱因斯坦凝聚体的稳定性
# 玻色磁梯中的非线性布洛赫动力学及自旋波激发
# 离散强度和连续BEC中三体相互作用对卡门涡街的影响
# 玻色-爱因斯坦凝聚中耗散诱导产生的环状暗孤子和涡对
# 双组分偶极玻色—爱因斯坦凝聚体中的量子卡门涡街
# Bi3+和Yb3+掺杂Cu-Co基铁氧体的结构及磁性的研究
# Ce3+和Sm3+掺杂Ni-Co基铁氧体的结构和磁性能的研究
# 铜锌锡硫硒薄膜太阳能电池界面修饰及对其光伏性能的影响研究
# 基于元素比调控及缓冲层掺杂的CZTSSe薄膜太阳电池光伏性能研究
# 0 1720
# 0 243
# year month has pdfs:4296
# MoS2薄膜忆阻器的制备及其神经突触仿生研究
# 光晶格中偶极玻色气体奇异量子相的研究
# 单层2H-MoSe2光电探测的第一性原理研究
# 几种新型二维材料电子结构调控及相关器件设计理论研究
# 掺杂和空位缺陷对单层2H-MoTe2电子结构和光电效应的影响
# 应变调控磁性拓扑结构的自旋动力学行为研究
# 基于多铁异质结的应变调控斯格明子动力学研究
# 氮化铁基软磁复合材料的制备及性能研究
# Eu2InTe5单晶生长及物性研究
# 二维范德华异质结电子性质与磁电耦合特性的局域极化场调控
# 基于声学人工微结构的新型拓扑材料研究
# 过渡金属原子吸附二维SnSe2薄膜性能研究
# 二维Zr基MXenes材料的电子结构和磁性
# 二维材料谷极化及其调控机制
# 过渡金属三卤化物单层的电子结构和磁各向异性
# 基于二维无机非铅钙钛矿的范德瓦尔斯异质结的理论设计及光电性能研究
# 石墨烯基底对Cu纳米颗粒熔化和凝固行为的影响
# An error occurred
# MoSi2N4/二维金属异质结的第一性原理研究
# DNA hairpin结构微力学稳定性的模拟研究
# 乙烯及异戊二烯产生Criegee的关键机制研究
# 掺氮硼团簇的结构与光谱特性的理论研究
# 第一性原理对A2BX6型钙钛矿静水压力下光电性质的研究
# 大气中醛转化成有机硝酸酯的微观机制研究
# 第一性原理研究A2B4+X6和A2B+B3+X6型卤化物钙钛矿的晶体结构和光电性质
# 磁光效应下双层拓扑共振回路的传输和光栅耦合模分析
# 金属-单层GaS异质结界面特性的第一性原理研究
# 石墨烯/碳化硅复合材料结构特性的模拟研究
# An error occurred
# Janus Ga2XY（X,Y=S,Se,Te;X≠Y）及其异质结的第一性原理研究
# MoSe2及其异质结的第一性原理研究
# 二维WSe2电子结构及光学性质的第一性原理研究
# An error occurred
# 二维Mg2Si半导体及其异质结的第一性原理研究
# 空位缺陷对Janus MoSSe及其异质结构性质影响的第一性原理研究
# 电场与掺杂调控孪生石墨烯的电子、光学与吸附性质
# An error occurred
# 多层Baxter-Wu模型的相变和临界行为
# 非厄米系统中的新奇拓扑现象
# An error occurred
# 二维声拓扑材料中的边缘态特性及其应用研究
# An error occurred
# 几种三维碳材料的拓扑性质的研究
# 新型二维Janus材料自旋霍尔效应的理论计算研究
# 二维碳网络的结构预测与反常力学性质的研究
# An error occurred
# 基于二维光子晶体的拓扑边界态传输特性的研究
# 0 1760
# 0 0
# list index out of range
# 0 1760
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 1760
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 1760
# 0 243
# year month has pdfs:4296
# 高阶拓扑相的搭建和相变
# 二维材料光致纯自旋流器件的第一性原理研究
# 真空技术制备ZnGa2O4材料及其光电性能研究
# 全无机钙钛矿Cs3Cu2Br5的真空物理制备及其光电性能研究
# 新型透明导电材料CaS与SrS的第一性原理研究
# 符号回归在A2BX6钙钛矿型材料设计中的应用
# 混合自旋Ising-XXZ模型中量子纠缠与关联的研究
# SiPb,AlBiTe3,Y2GeI2单层材料热电性能的第一性原理研究
# An error occurred
# 全无机钙钛矿量子点CsPbX3在镧系化合物调控下的发光特性研究
# RbSnX3（F,Cl）和Mg2Si/FeGa3掺杂体系热电性能的理论研究
# 高压下钪氮化合物与惰性元素化合物的第一性原理研究
# An error occurred
# 金属离子电池的阳极材料理论设计与性能研究
# 二维MA2Z4型能谷材料的第一性原理研究
# 基于钡铁氧体的忆阻器及其真随机数发生器应用的研究
# 氧化铪基薄膜及其晶体管的设计制备与性能研究
# [Mo3S13]2-团簇基析氢功能材料的结构设计、制备及应用
# 磁场及电流驱动skyrmion string动力学特性研究
# 新型二维钛/碳基电极材料的第一性原理研究
# 高应变苯并二噻吩格的应变积累与电子性质理论研究
# 二维层状异质结材料的磁电特性研究
# An error occurred
# An error occurred when close window
# 基于KAGOME晶格电子平带二维范德华磁性材料强磁耦合作用机理研究
# 在室温条件下基于WTe2/铁磁异质结无场磁化翻转的研究
# 基于Ⅴ族的二维材料的电子结构与性能调控
# An error occurred
# Ti-基材料作为钠硫电池正极材料的第一性原理研究
# 利用机器学习高通量预测单层和转角二维材料的带隙
# 二维共价有机骨架电子结构及其界面性质
# BiVO4水氧化的第一性原理计算研究
# Hf-Nb、Hf-Ta与Hf-Ta-Zr体系扩散行为及力学性能的研究
# 双钙钛矿Cs2NaBiCl6的可控构筑及其发光特性研究
# 基于磁光克尔效应测量材料表面磁特性方法的研究
# An error occurred
# 二族元素铌酸盐材料力致发光及其增强机理研究
# 基于铒和铥的可调谐上转换荧光研究
# 双钙钛矿Cs2AgBiBr6的可控构筑及其发光特性研究
# 稳定红光钙钛矿量子点的构筑及其发光性能研究
# 纳米孪晶对InSb材料热、力学性能影响的分子动力学研究
# An error occurred
# 纳米晶磁性材料高压扭转制备、结构和磁性
# 基于荧光强度比Er3+/Yb3+共掺杂荧光材料的制备及其光纤荧光温度传感性能研究
# 稀土离子掺杂钛酸锶钡基材料的上转换发光温度特性研究
# An error occurred
# 铁基软磁复合材料的扩散法制备与性能研究
# An error occurred
# 基于荧光强度比技术的稀土双掺发光材料温度传感性能研究
# An error occurred
# 0 1800
# 0 243
# year month has pdfs:4296
# MgGa2O4基长余辉材料的制备与性能研究
# 钽酸盐基红色-近红外发光材料的合成与性能调控
# 基于能量传递获取的铌酸盐暖白光荧光粉的发光特性研究
# La2MgGeO6:Yb和La2MgGeO6:Er体系荧光材料制备及近红外发光性能
# 动态解析逆Preisach磁滞模型及其参数辨识算法研究
# Bi3+掺杂荧光粉的发光特性及光学应用研究
# Mn4+：K2XF6（X=Ti，Ge，Si）荧光粉的制备、改性及发光性能研究
# 稀土掺杂的Sr3Y2（BO3）4荧光粉的制备及发光性质的研究
# 稀土掺杂的Ba3Y2（BO3）4体系荧光粉的制备及发光性质研究
# Dy3+/Eu3+掺杂SiO2-PbF2玻璃陶瓷制备及其发光研究
# 白光LED用氧化物荧光粉的制备及发光性能研究
# 两种氧化物荧光粉的制备和发光特性研究
# 掺Al的HfO2铁电薄膜制备及其阻变性能的研究
# 三元混晶薄膜中导波声子极化激元的色散特性
# Kapton薄膜蠕变力学性能研究
# 拉伸-弯曲组合变形下高温超导涂层带材力-电特性研究
# 高压下富氢化合物ErHn的结构稳定性和超导电性的第一性原理研究
# An error occurred
# 复杂电磁场环境下高温超导带材交流损耗特性研究
# 高温超导线圈典型结构损耗特性研究
# An error occurred
# ThFeAsN超导体的同价元素替代效应研究
# An error occurred when close window
# 几种拓扑超导体的层间耦合调控研究
# 有机化合物材料在高压下的物性研究
# 有机材料高压下密度泛函理论研究
# 液体中放电过程电流诊断技术研究
# 非中性等离子体束流在磁镜中的约束性质研究
# 基于多流体模型对磁化等离子体中磁声波的研究
# An error occurred
# 低气压容性耦合Ar等离子体串联共振效应的研究
# 含有Kappa分布电子的空间等离子体中非线性波的研究
# An error occurred
# Au69+-Au65+离子共振电子复合过程的理论研究
# 利用发射光谱法研究背景气体对激光Al等离子体状态的影响
# 石墨烯光学微结构等离子体诱导透明和吸收特性及应用研究
# 基于石墨烯和黑磷微结构的等离子特性及应用研究
# 调频与调幅射频源驱动的容性耦合等离子体模拟研究
# Yb+离子偶极动态极化率、Tune-out波长和Magic波长的理论研究
# B2+、B+的静态偶极极化率和超极化率的理论研究
# 电场对蛋白质及其突变体构象转变影响的分子动力学模拟研究
# 基于FPGA的分子动力学模拟加速系统研究
# 典型范德华复合物量子动力学程序的开发和应用
# An error occurred
# 基于磁镊技术在单分子水平上研究大分子拥挤效应
# C_nHmX（X=O,S,N）及其异构体的分子结构和光谱性质的理论研究
# 0 1840
# 0 0
# list index out of range
# 0 1840
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 1840
# 0 243
# year month has pdfs:4296
# 基于SCAN meta-GGA泛函从头算分子动力学对过冷水性质反常机制的研究
# 邻苯二酚修饰的D-A-D结构二区分子的制备及乳腺癌骨转移瘤治疗应用
# 基于图对比学习的分子性质预测研究
# 类铍离子电子碰撞激发非辐射衰变Auger电子角向性质的理论研究
# 组合圆偏振激光场驱动双原子分子产生光电子涡旋的理论研究
# 氢原子和氟负离子在强激光场中磁量子数分辨光电离的理论研究
# 高电荷态离子K、L壳层电子碰撞激发辐射极化特性的理论研究
# 类氦离子电子碰撞激发过程及其退激辐射极化性质的理论研究
# An error occurred
# 类氢离子Compton轮廓的高精度计算
# 磁性飙卤素Fe（BF4/AlF4）4的理论研究
# An error occurred
# He-like和Be-like内壳层双洞态原子的能级结构和辐射跃迁性质的研究
# 超短激光脉冲作用下原子非绝热隧穿动力学研究
# 基于变迹光栅的片上冷原子操控的研究
# 燃耗计算中核数据不确定性传播与量化方法研究
# 气冷微堆结构材料制造公差对物理计算不确定性影响研究
# An error occurred
# n/γ辐射场蒙卡—点核耦合计算方法研究
# An error occurred
# 广谱系组件程序的验证与确认
# MOC三维全堆芯中子输运方法在临界实验装置中的应用
# OpenMOC程序两级gCMFD加速方法实施及验证
# 任意几何特征线方法及其并行算法研究
# An error occurred when close window
# 电磁泵多场耦合数值模拟方法研究
# 广谱反应堆两步法物理计算框架搭建与分析
# 基于积累因子优化的离散纵标-点核积分耦合方法研究
# 高功率密集颗粒流靶中束靶耦合模拟关键技术研究
# 基于CDFT的类壳模型方法对171,172Yb对关联的研究
# Holographic Description of Elastic Nucleon-Nucleon Scattering at High Energies
# An error occurred
# 双重味四夸克态的质量谱研究
# 隐重味四夸克态的质量研究
# f0（980）介子分布振幅的研究
# An error occurred
# 粒子物理实验装置中的通用读出电子学关键技术研究
# 炼化企业硫化氢探测器优化布置研究
# 基于吡咯并吡咯二酮共轭材料的合成及在生物成像上的应用研究
# An error occurred
# 有机半导体小分子的设计合成及近红外二区光诊疗应用
# 基于深度学习的序列切片图像分割与三维重建技术研究
# 刺激响应型等离子体增强荧光纳米探针用于生物分子的精准成像检测
# 光刺激型信号放大策略用于生物分子的精准成像检测
# An error occurred
# 合成生物学法律治理路径研究
# An error occurred
# 全球植被绿度年际波动性及其演化
# 深海裸变形虫分类学研究与基于转录组的Actin功能分析
# 赫氏颗石藻对海洋酸化和金属铝的生理响应研究
# An error occurred when close window
# 0 1880
# 0 243
# year month has pdfs:4296
# 基于深度学习的水下海洋生物目标检测方法研究
# 基于深度学习的海洋生物识别技术研究
# 北部湾渔获物生态化学计量特征研究
# 基于底栖动物群落结构特征的洪泽湖湖泊生态健康评价
# 基于改进K-阶传播数的工作记忆EEG研究
# 时-频-空多维融合的脑电情绪分类方法
# 上海黄浦江人工骨干河流优势鱼体内微塑料和重金属污染研究
# 基于半中心振荡器的斑马鱼CPG运动神经系统建模与分析
# 基于改进YOLO v7的微藻轻量级检测算法研究与应用
# An error occurred
# 珊瑚礁食物网营养结构的时空变动研究——以涠洲岛珊瑚礁为例
# 西北太平洋公海主要头足类营养生态关系分析
# 东海典型赤潮藻类种间竞争对不同磷源和温度的响应
# 基于深度学习的底栖生物图像识别技术研究
# 湖南省外来入侵物种监测系统研究
# An error occurred
# 长江经济带湖南区域外来入侵物种调查与入侵风险评价
# An error occurred
# 产角鲨烯细胞工厂的构建及其优化
# 单细胞胞吐过程检测的电化学-SERS联用技术
# 唾液酸凝集素Siglec-Fc的哺乳动物细胞表达和活性鉴定
# ribC的持续进化提高黄素单核苷酸的全细胞催化合成
# 多酶级联实现全细胞催化合成硫酸软骨素A
# An error occurred when close window
# An error occurred when close window
# 不同毕赤酵母底盘细胞hEGF表达效率及脂质组差异比较
# HIP-55促进AT1R介导的巨噬细胞功能活化及机制研究
# Stat5a促进Col10a1基因表达和软骨细胞肥大分化的作用及机制研究
# C57BL/6小鼠股骨与颅骨来源成骨细胞差异的研究
# SGK3在小鼠卵母细胞第一次减数分裂恢复中作用的研究
# SGK1在小鼠一细胞期受精卵发育中的作用研究
# 促红细胞生成素对兔骨髓间充质干细胞迁移能力的影响
# SMURF2在T细胞受体早期信号转导中的作用机制研究
# 质子通道Otop1调控分子挖掘及调控机制初步研究
# An error occurred
# 氧化石墨烯纳米片的控冰性能研究及其在细胞低温保存中的应用
# 表面有机复合氧化石墨烯及其在细胞低温保存中的应用研究
# 卷枝毛霉WJ11 ω-3超长链多不饱和脂肪酸细胞工厂的构建
# 表达SV40 LT永生化脐带间充质干细胞系的建立及其外泌体提取
# 无线电控的细胞外囊泡促释技术与疾病治疗
# 跨膜递送细胞色素C诱导细胞凋亡
# 基于人多能干细胞的功能性胰岛β细胞分化方案的研究
# 单细胞质谱定量金纳米棒的细胞摄取
# An error occurred
# 兔肌源性间充质干细胞生物学特性及对肝损伤修复研究
# Trolox调控间充质干细胞生物学特性的作用与机制研究
# 骨髓间充质干细胞对缺血再灌注损伤肠粘膜免疫屏障的影响及其机制研究
# 0 1920
# 0 243
# year month has pdfs:4296
# 缺氧通过铁代谢相关蛋白调控精原干细胞C18-4自我更新的机制研究
# 草酸青霉中新调控基因POX08340的功能鉴定
# ZmPGIP1基因的克隆与功能分析
# 小麦族St、E、V叶绿体基因组谱系关系
# 非同义盒式选择性剪接对其产物翻译调控影响的研究
# 基于Feed-Batch模式优化rh-TPO的细胞培养及蛋白纯化方法的改进
# 红花类黄酮合成关键酶CtC4H1基因的克隆及功能分析
# 双色蜡蘑氮代谢基因LbGS与LbNR在菌根形成发育过程中的功能研究
# 长白山两种金丝桃属植物光合特性及MADS-box差异研究
# 基于流式细胞术对蜘蛛抱蛋属植物的倍性鉴定及其基因组大小测定的研究
# 堇菜属三种植物花发育过程中GA20ox和GA3ox克隆与表达分析
# 秀丽隐杆线虫腺苷受体ador-1基因功能研究
# 龟裂链霉菌M527土霉素隐性生物合成基因簇的靶向激活
# 基于微单倍型的细胞交叉污染检测方法的建立及验证研究
# 过表达LmGST基因促进浮萍超富集重金属镉的应用
# 狐臭柴果胶合成途径中GAUT基因的克隆及功能验证
# 杜仲SRPP启动子的活性分析
# 火龙果DREB1D基因参与逆境应答的分子调控
# An error occurred
# 颠茄AbWRKY2基因的克隆与功能研究
# 地钱MYB17基因的克隆与功能分析
# An error occurred when close window
# 雨生红球藻中与蓝光反应元件互作蛋白的筛选鉴定及表达分析
# 小片段环状DNA增强cGAS-STING信号通路激活的分子机制研究
# 通过转录组分析选择空腹反应下肝脏基因表达分析参考基因
# An error occurred
# 继代培养对楸树胚性愈伤组织分化再生能力的影响
# 基于CRISPR/Cas的m6A编辑系统的初步研究
# An error occurred
# 基于MeRIP-seq的拟南芥新生RNA m6A修饰功能研究
# 茉莉酸信号转录抑制关键组分JAZ与NINJA互作机制研究
# 基于BSA-Seq技术挖掘拟南芥RSV抗性相关基因
# An error occurred
# 铁皮石斛DoMYB5和DoMYB92转录因子的功能研究
# An error occurred
# 紫茎泽兰单线态氧（1O2）标记基因的克隆及1O2信号在毒素TeA杀草过程中的作用
# An error occurred
# 拟南芥H3K36me3突变体光周期依赖性植物表型变化的分子机理初探
# 秀丽线虫长链非编码RNA调控纳米聚苯乙烯和多壁碳纳米管毒效应的分子机制研究
# 拟南芥CRWN3的互作蛋白鉴定和DNA去甲基化相关突变体rll10的筛选与基因定位
# 马铃薯StHsf026基因的克隆及其在热胁迫响应中的功能分析
# An error occurred
# 水稻转录因子OsNAC3靶基因的筛选和耐镉性分析
# 植物叶绿体基因组生物信息分析方法的系统性整合和应用
# 斑马鱼GIGYF2的鉴定和功能研究
# 磷对集胞藻基因组拷贝数的影响研究
# 三种垫状植物青藏高原极端环境适应性的叶绿体基因组与转录组学研究
# 双色多重CRISPR/sgRNA系统的构建及在斑马鱼染色体成像上的初步应用
# 0 1960
# 0 243
# year month has pdfs:4296
# MgGa2O4基长余辉材料的制备与性能研究
# 草酸青霉中新调控基因POX08340的功能鉴定
# ZmPGIP1基因的克隆与功能分析
# 小麦族St、E、V叶绿体基因组谱系关系
# 非同义盒式选择性剪接对其产物翻译调控影响的研究
# 基于Feed-Batch模式优化rh-TPO的细胞培养及蛋白纯化方法的改进
# 红花类黄酮合成关键酶CtC4H1基因的克隆及功能分析
# 双色蜡蘑氮代谢基因LbGS与LbNR在菌根形成发育过程中的功能研究
# 长白山两种金丝桃属植物光合特性及MADS-box差异研究
# 基于流式细胞术对蜘蛛抱蛋属植物的倍性鉴定及其基因组大小测定的研究
# 堇菜属三种植物花发育过程中GA20ox和GA3ox克隆与表达分析
# 秀丽隐杆线虫腺苷受体ador-1基因功能研究
# An error occurred
# 龟裂链霉菌M527土霉素隐性生物合成基因簇的靶向激活
# 基于微单倍型的细胞交叉污染检测方法的建立及验证研究
# An error occurred
# 过表达LmGST基因促进浮萍超富集重金属镉的应用
# 狐臭柴果胶合成途径中GAUT基因的克隆及功能验证
# An error occurred
# 杜仲SRPP启动子的活性分析
# 火龙果DREB1D基因参与逆境应答的分子调控
# 颠茄AbWRKY2基因的克隆与功能研究
# 地钱MYB17基因的克隆与功能分析
# An error occurred when close window
# An error occurred when close window
# 极后区钙敏感受体在调节摄食和胃肠道运动中的作用以及机制研究
# 重金属基因编码荧光探针的构筑、表征及生物成像研究
# 深穿透稀土荧光生物探针的构建及性能研究
# 具有钾离子转运功能的人造折叠体的设计合成
# 榛蘑肽的制备、分离纯化及其抗氧化活性研究
# 抗菌肽LRGG的原核表达与功能验证
# 大孔聚合物肝素亲和层析介质的制备与评价研究
# 基于等温核酸扩增信号放大策略检测核酸酶及DNA糖苷酶活性
# 用于糜蛋白酶和硫化氢检测的有机荧光探针的设计和应用
# 越橘花青素脂质体的制备及其细胞抗氧化作用研究
# 褐飞虱网格蛋白重链和类酵母共生菌烯醇酶互作蛋白的筛选与研究
# 基于银基自组装纳米薄膜SERS光谱的谷胱甘肽检测与应用研究
# 基于共享组件的荧光适体传感器构建
# 牦牛骨源抗炎活性肽分离纯化与作用机制解析
# 基于银纳米簇的ATP荧光适配体传感器研究
# 糖基化通路分析工具GlycoMaple的优化与应用
# 定点突变提高糖基转移酶YojK的热稳定性以高效合成莱鲍迪苷D
# 重组双碱基内肽酶的高效表达及其在大豆蛋白水解中的应用
# 多芳基取代咪唑类有机荧光分子的构筑及其生物应用研究
# 噻虫胺和氨基甲酸乙酯的核酸适配体筛选与应用研究
# 0 2000
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2000
# 0 243
# year month has pdfs:4296
# 极后区钙敏感受体在调节摄食和胃肠道运动中的作用以及机制研究
# 重金属基因编码荧光探针的构筑、表征及生物成像研究
# 深穿透稀土荧光生物探针的构建及性能研究
# 具有钾离子转运功能的人造折叠体的设计合成
# 榛蘑肽的制备、分离纯化及其抗氧化活性研究
# 抗菌肽LRGG的原核表达与功能验证
# 大孔聚合物肝素亲和层析介质的制备与评价研究
# 基于等温核酸扩增信号放大策略检测核酸酶及DNA糖苷酶活性
# 用于糜蛋白酶和硫化氢检测的有机荧光探针的设计和应用
# 越橘花青素脂质体的制备及其细胞抗氧化作用研究
# An error occurred
# 褐飞虱网格蛋白重链和类酵母共生菌烯醇酶互作蛋白的筛选与研究
# 基于银基自组装纳米薄膜SERS光谱的谷胱甘肽检测与应用研究
# 基于共享组件的荧光适体传感器构建
# 牦牛骨源抗炎活性肽分离纯化与作用机制解析
# 基于银纳米簇的ATP荧光适配体传感器研究
# An error occurred
# 糖基化通路分析工具GlycoMaple的优化与应用
# 定点突变提高糖基转移酶YojK的热稳定性以高效合成莱鲍迪苷D
# 重组双碱基内肽酶的高效表达及其在大豆蛋白水解中的应用
# 多芳基取代咪唑类有机荧光分子的构筑及其生物应用研究
# 噻虫胺和氨基甲酸乙酯的核酸适配体筛选与应用研究
# An error occurred when close window
# 疾病相关的蛋白质与金属离子结合位点的研究
# 基于lncRNA序列特征的预测研究
# 基于深度学习的蛋白质信号位点预测
# Novosphingobium sp. GX9中三个GH1家族β-葡萄糖苷酶的功能鉴定
# 多级酶功能智能预测方法研究
# 兼顾分子结构与序列挖掘的酶功能预测
# 生物催化生产熊去氧胆酸及其关键酶分子改造研究
# 基于半理性设计的亮氨酸脱氢酶分子改造及应用
# 人源溶菌酶的分子改造及其高效表达
# NADH氧化酶分子改造及其应用
# 天冬氨酸β-脱羧酶的分子改造及催化机制研究
# 祖先氨肽酶的制备及酶学性质研究
# 基于NanoBit技术的泛素连接酶筛选系统的建立及应用
# 硫酸软骨素酶B的克隆表达、结构表征及结构改造
# 劈裂型10-23脱氧核酶的功能优化及生物传感器应用研究
# meso-DAPDH亚家族间插入/缺失序列的功能研究
# 5-甲基四氢叶酸脱氢酶突变体MetF1m特性与结构的初步研究
# 肉桂酸衍生物与胰脂肪酶的相互作用及其对脂质消化的影响研究
# 蕨麻多糖分子的构效关系研究——以其中重复单元pap-1为例
# 基于单细胞多组学数据的基因调控网络构建算法研究
# 0 2040
# 0 0
# list index out of range
# 0 2040
# 0 243
# year month has pdfs:4296
# 基于单细胞RNA测序数据的基因调控分析方法研究
# 生物分子相互作用智能预测新方法研究
# 基于深度学习的复杂疾病风险与生存预测研究
# An error occurred
# 构建万古霉素修饰的碳纳米点用于VRE生物膜的多重靶向和协同治疗研究
# 基于数据非依赖采集质谱的肽测序方法研究
# 基于深度学习的DNA和RNA结合蛋白预测研究
# 基于深度学习的单细胞多组学数据挖掘研究
# 基于图神经网络的单细胞多组学数据分析研究
# 面向疾病与lncRNA关联的复杂特征学习及预测研究
# 随机网络和基于复制-变异机制的生物分子网络的可压缩性
# 马克斯克鲁维酵母糖转运蛋白Km＿SUT1关键氨基酸位点的鉴定与分析
# 马克斯克鲁维酵母GX-UN120中两个糖转运蛋白基因Km＿SUT13和Km＿SUT14的功能研究
# 草酸青霉G蛋白γ亚基PoxSte18在植物生物质降解酶基因表达中的功能研究
# 双酶共表达菌株的构建及水解淫羊藿苷的研究
# 草酸青霉中支架蛋白PoxSte50在生物质降解酶基因表达中的功能鉴定
# 马克斯克鲁维酵母GX-UN120中四个糖转运蛋白基因的敲除及其对糖利用能力影响的研究
# 副结核分枝杆菌35kDa蛋白基因重组腺病毒的构建及免疫原性研究
# 裂解多糖单加氧酶基因的高效异源表达研究
# 酸性磷酸酶在毕赤酵母中表达及其活性初步研究
# NADH焦磷酸酶的高效表达与分子改造研究
# An error occurred when close window
# 重组酿酒酵母生物合成角鲨烯的研究
# 利用CRISPR-Cas12a基因编辑系统改造拟无枝酸菌高效生产香兰素
# An error occurred
# Candida glycerinogenes基因组文库的构建及应用
# 重组鲎C因子的表达与内毒素检测
# 源自极端嗜酸喜温硫杆菌的硫化物醌氧化还原酶（SQR）性质与结构功能研究
# 低温、碱性β-1,4-内切葡聚糖酶的基因挖掘、异源表达和理性改造
# An error occurred
# 大肠杆菌中高效表达与纯化获得无融合蜂毒肽
# 枯草芽孢杆菌中高效响应N-乙酰神经氨酸生物传感器的构建与应用
# An error occurred
# 新基因型腈水合酶的克隆表达及其成熟机制的初探
# 罗伊氏乳杆菌醛酮还原酶的克隆表达及酶学性质研究
# An error occurred
# β-甘露聚糖酶热稳定性改造及其高效表达
# 代谢工程改造大肠杆菌生产琥珀酸
# An error occurred
# 谷氨酸棒杆菌sRNA的筛选、挖掘及其生理功能鉴定
# 代谢工程改造大肠杆菌高效合成β-烟酰胺单核苷酸
# Cfa DnaE断裂内含肽中非天然外显肽序列与断裂性能的关系研究
# 重组大肠杆菌利用农业副产物发酵产香兰素的研究
# Pantoea dispersa蔗糖异构酶在枯草芽孢杆菌中的表达及异麦芽酮糖制备
# 大肠杆菌血红素合成途径关键酶基因重组对TfuDyP异源表达的影响
# 大肠杆菌血红素代谢途径的改造及DyP酶的异源表达
# 代谢工程改造酿酒酵母合成β-胡萝卜素
# An error occurred
# An error occurred when close window
# 0 2080
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2080
# 0 0
# list index out of range
# 0 2080
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2080
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2080
# 0 243
# year month has pdfs:4296
# 谷氨酸棒杆菌4-羟基异亮氨酸合成的CRISPR-Cpf1辅助编辑和代谢改造
# 代谢工程改造大肠杆菌合成烟酰胺单核苷酸
# 大肠杆菌抗噬菌体基因的挖掘及其抗噬菌体菌株的构建
# 代谢工程改造大肠杆菌高效合成樱花素
# 群体感应动态调控谷氨酸棒杆菌4-羟基异亮氨酸的合成
# 地衣芽孢杆菌异源重组系统的构建及应用
# 褐飞虱离子通道蛋白SLC26A10、NaCh、MCOLN3和TMCO1的基因克隆与功能研究
# 基于CRISPR/Cas12a的蛋白酶活性及RNA检测新方法研究
# 青海血蜱唾液腺重组蛋白Hq012与凝血因子相互作用的研究
# 假单胞菌中调控小RNA系统的建立及其在甲羟戊酸合成中的应用
# An error occurred
# 马克思主义系统观视域下基因编辑技术的研究
# nfU在蓝藻Fe-S簇生物合成中的作用机制研究
# 青岛文昌鱼血清淀粉样蛋白P成分基因的克隆、表达与进化分析
# TBEV森张株E蛋白胞外区原核表达、纯化及单克隆抗体制备
# An error occurred
# 醚菌酯降解菌MJ-1的分离鉴定、代谢途径分析及其水解酶基因的克隆
# 甲烷单加氧酶sMMO合成调控机制及异源表达的研究
# 贻贝粘蛋白在大肠杆菌和枯草杆菌中的重组表达研究
# 通过随机突变提高α-淀粉酶AmyM在枯草杆菌中的表达量
# 宏基因组来源新型酯酶的酶学性质表征及定向进化研究
# 抑制PD-L1的溶瘤腺病毒表达CXCL9、GM-CSF的抗肿瘤研究
# An error occurred when close window
# An error occurred when close window
# 海洋环糊精葡萄糖基转移酶的分子改造及其应用的研究
# 酿酒酵母srp4039基因的克隆与功能研究
# 茶树菇来源非特异性过氧化酶（AaeUPO）的异源表达及固定化研究
# 产PHA嗜盐古菌分裂相关蛋白ftsZ1基因改造及效果研究
# swnK基因ACP结构域敲除对Alternaria oxytropis OW7.8代谢组的影响、swnR和swnH1基因克隆及表达研究
# 二氧化碳固定酶固碳效率及其对地衣芽孢杆菌代谢的影响
# 基于混合模型的生物过程数字孪生构建与应用
# 基于生物信息学对形觉剥夺性近视差异基因的分析和探讨
# 3D拓扑建模下的分子性质计算分析
# 基于深度学习的核小体定占位建模研究
# 基于仿生海豚的水下目标识别技术研究
# 基于深度学习的表型相关非编码突变预测
# 基于CPG的仿生鱼自主游动控制方法研究
# 用于DNA存储的集成电路及纠错算法设计
# 基于深度学习的转录因子识别模型研究
# EpiMOGA：基于多目标遗传算法的高阶上位性检测方法
# An error occurred
# 基于决策树方法的全基因组关联分析
# 基于单细胞转录组数据的细胞类型识别及应用研究
# 基于单细胞测序数据构建基因调控网络的方法研究
# 基于U-Net的医学图像分割算法研究及应用
# 0 2120
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2120
# 0 243
# year month has pdfs:4296
# 基于范数稀疏表示的医学影像重构方法研究
# 基于外部知识与视觉记忆的医学报告生成方法研究
# An error occurred
# 基于联合注意力的改进U网络血管分割算法研究
# 基于深度学习的病理图像分类与语义分割研究
# 基于跨模态特征融合的医学报告生成方法研究
# 超声图像引导的注射穿刺系统
# 面向脑电神经反馈的深度学习算法研究
# 基于序列的同义与无义单核苷酸变异致病性预测模型
# 蛋白质相互作用位点计算建模研究
# 蛋白质翻译后修饰相互作用的预测模型研究
# 面向嵌套结构的生物医学事件抽取
# 基于联合学习的生物医学实体因果关系抽取
# An error occurred
# 组蛋白修饰的计算建模研究
# 基于弱监督的医学影像病灶区域分割算法研究
# 面向MRI医学图像的半监督分割算法的研究和应用
# 基于流固耦合的2D-3D血管影像非刚性配准方法研究
# 显微细胞图像分割的研究
# 基于手臂肌电信号作业动作识别方法研究
# 脑肌电集成采集与增强技术研究
# 基于生物电阻抗谱超快测量的人体成分分析方法研究
# An error occurred
# An error occurred when close window
# 基于范数稀疏表示的医学影像重构方法研究
# 基于人体表面肌电信号的汉语声调识别研究
# 基于多专家标注差异性的医学图像分割模型研究
# 基于改进YOLOv5的公共场景下口罩佩戴检测算法
# 面向口咽期吞咽障碍的吞咽行为研究
# 基于小波变换和深度学习的脑电信号识别算法研究
# 可穿戴式下肢无动力外骨骼设计与优化
# 基于光纤传感器的脉搏监测系统的设计
# 气动肌肉仿生腿的刚度分析及变刚度运动仿真
# 高灵敏快速响应的光纤核酸生物传感器研究
# 被动式胎心音听诊器关键技术的研究
# 基于PPG降噪算法的人体生理参数检测研究
# 人体坐姿智能识别系统研制
# 联合多维动态拓扑与时空多尺度的骨架动作识别研究
# 基于深度学习的口罩佩戴检测算法研究
# 基于毫米波的非接触式情感识别方法研究
# 基于三维卷积的多模态生理信号情绪识别研究
# 基于深度学习的多模态医学影像算法及其应用研究
# 基于元学习理论的医学影像分割算法研究
# 人工智能元学习新理论及其医学影像分析与应用研究
# 0 2160
# 0 243
# year month has pdfs:4296
# 面向伪迹去除和运动想象指令识别的脑电信号处理技术研究
# 基于深度注意力机制的医学图像分割技术研究
# 基于运动想象的EEG信号挖掘与分析方法研究
# An error occurred
# 脑机接口时频信息抽取与识别的虚实结合控制研究
# 基于EEG的情绪识别调控系统研究
# 基于多层石墨烯/二氧化钛纳米结构的脑电电极在机械臂脑机接口控制中的应用
# 基于步行状态感知的柔性外骨骼髋关节助力参数优化方法
# 基于变论域模糊控制的血管介入手术机器人的研究
# An error occurred
# 面向主动式脑机接口的模式增强与识别技术研究
# 基于语义增强与并行网络架构的心脏医疗影像分割研究
# 基于脑电和眼动数据融合的多模态情绪识别研究
# 基于脑电信号水平垂直流动表征的域适应情感分类研究
# 基于脑电信号的情绪识别与主动服务推荐方法研究
# 基于卷积神经网络的骨骼异常图像检测方法
# 医学CT影像边缘检测算法研究及FPGA实现
# An error occurred
# 结合Alphapose与时空图卷积网络的康复动作识别
# 基于视觉诱发双模态生物电的情绪状态识别研究
# 煤矿调度室操作员情绪对工作记忆表现的影响研究
# 煤矿VDT作业者脑疲劳对持续注意力的影响研究
# 基于特征增强的医学影像报告自动生成的研究与应用
# An error occurred when close window
# 基于多局部点特征信息融合的医学图像病灶检测的研究
# 基于多尺度特征分析的肝脏血管分割研究
# 基于谱归一化生成对抗网络的基因表达谱数据增强方法研究
# 基于YOLOv5的医学图像病变区域检测研究与应用
# 基于深度学习的心电信号分类研究
# M公司装窑及干燥作业人机工程改善应用研究
# 基于词义增强的生物医学命名实体识别方法研究
# 多尺度特征金字塔网络在医疗图像分割中的研究
# 基于深度学习的医学图像超分辨技术研究
# 基于深度学习的前节OCTA图像处理与血管量化方法研究
# An error occurred
# 基于改进U-Net网络的2.5D医学图像分割技术研究
# 基于深度残差网络的眼底图像多疾病分类方法研究
# An error occurred
# 血脑屏障穿透肽数据库构建与预测研究
# 基于红外的手部血管识别算法研究
# 基于图神经网络的circRNA-药物敏感性关联预测算法研究
# An error occurred
# 聚乙烯醇基水凝胶骨软骨支架的制备及性能研究
# 基于深度学习的医学图像分割方法研究
# 先验信息约束的医学图像多目标联合分割方法研究
# 基于深度学习网络的息肉图像分割
# 基于生成对抗网络的肌电特征生成及分类性能研究
# 0 2200
# 0 243
# year month has pdfs:4296
# 气动人工肌肉驱动的下肢外骨骼膝关节设计与控制研究
# 基于气动肌肉的仿生腿设计及控制策略研究
# 基于绳驱咽拭子机器人采样的多传感器融合及轨迹规划研究
# 镍钛合金心血管支架光纤激光切割仿真及基础试验研究
# 基于运动想象的脑控下肢康复外骨骼的设计与研究
# 基于聚类与卷积神经网络的医学图像分割技术研究
# 基于深度卷积神经网络的RNA-蛋白质结合位点预测方法研究
# 基于深度学习的脑电情绪识别方法研究
# 基于三维重建技术的计算机辅助手术规划系统设计与实现
# 基于钴基有机金属框架材料的电化学免疫传感器的构建与应用
# An error occurred
# 基于深度学习的运动想象脑电特征分类算法
# 基于脑电、外周生理信号和面部表情的多模态情感识别研究
# An error occurred
# 基于深度学习的心理压力识别算法研究
# 学习情境下基于脑电特征识别的注意力训练方法研究
# 基于运动想象脑电信号的分类研究
# 基于深度学习的运动想象脑电信号分类方法研究
# 基于深度学习的生物医学命名实体识别方法的研究与实现
# 基于改进元启发式算法的医学图像分割方法研究
# 具有双导电网络的皮肤电极的制备及其在生理电信号监测的应用
# 基于进化算法的卷积神经网络图像去噪算法研究
# An error occurred when close window
# 基于微服务的脑电信号可视化平台设计与实现
# 基于表面肌电信号的语音识别研究
# 基于神经网络还原算法的单光子荧光寿命成像技术研究
# 脑电状态智能识别与调节机制的研究与系统构建
# 基于深度学习的P300脑机接口分类算法研究
# 基于高维特征模型的跨被试脑电情感识别方法研究
# 基于EEG的多级疲劳状态识别研究
# An error occurred
# 基于人因工程的复杂系统装备虚实融合装配与运维仿真系统设计与开发
# 基于情感脑电特征处理的身份识别方法研究
# 基于多维传感特性电子皮肤的可穿戴设备及其在人机交互中的应用
# 融合多频阻抗测量功能的射频消融电源设计
# 基于PPG和ECG信号的多频域多特征身份识别方法和系统研究
# An error occurred
# 基于WiFi的人员呼吸感知边界研究
# An error occurred
# 基于毫米波雷达的呼吸检测算法研究
# 基于表面肌电信号的动作识别与人机交互方法研究
# 基于表面肌电信号的人机交互方法研究及其系统设计
# 基于人体局部阻抗的全身体脂率预测方法研究及其系统实现
# 面向人体运动模式识别的压缩感知关键技术研究
# 基于图像先验知识和深度学习的医学图像分割方法研究
# 基于生物电阻抗的肌肉量智能检测技术研究
# 0 2240
# 0 243
# year month has pdfs:4296
# 基于毫米波雷达的生命体征检测与身份认证算法研究
# 面向SAM基因序列的压缩算法及并行化研究
# 基于时空自注意力机制的非接触心率检测研究及实现
# 基于柔性感知的人体运动热舒适检测及健康预警研究
# 面向在线学习场景的生理信号及先验知识情感分类研究
# An error occurred
# 面向医学图像的深度学习辅助诊断方法研究
# 基于深度学习的戴口罩人脸识别研究
# 基于编解码的医学图像分割方法研究
# An error occurred
# 基于深度学习的医学影像识别与分割技术研究
# 基于深度学习的管状结构分割研究与应用
# 基于深度学习的医学影像方法配准研究与应用
# 医疗知识图谱中实体关系抽取技术研究
# An error occurred
# 基于共识窗的CT器官分割方法研究
# 基于表面肌电与加速度信号的手、腕关节连续运动估计方法研究
# 个性化假肢3D打印建模方法研究
# An error occurred
# 基于硫缩酮键连接的双ICG分子构筑的纳米诊疗一体化平台
# 基于ALPHA信息迁移方法的稳态视觉诱发电位脑—机接口研究
# An error occurred
# 基于时空特征融合的情绪识别研究
# 基于多特征融合的心音信号分类
# 基于协同训练域适应算法的运动想象脑电识别
# An error occurred when close window
# 基于MEMS的柔性微针葡萄糖传感器的设计与分析
# 石墨烯基湿度传感器及其在呼吸监测中的应用
# 足底压力与踝关节弯曲传感器设计及步态分析系统研究
# 声波/微纳结构辅助下的荧光计数策略用于外泌体的高灵敏检测
# An error occurred
# 基于深度学习的脑电情感识别
# 基于sEMG信号的手势识别算法研究
# 基于胶囊神经网络的骨骼数据行为识别研究
# EEG Based Emotion Recognition Using Convolution and Domain Adversarial Neural Networks
# An error occurred
# Motor Imagery Eeg Signal Classification Using Ensembled Cnns for Brain Computer Interface
# 基于机器学习的5-甲基胞嘧啶位点预测研究
# 基于氨基酸属性编码的蛋白质多序列比对算法的研究
# 基于修正梯度加权和的医学图像融合及FPGA实现研究
# m7G修饰位点识别及疾病关联预测方法研究
# 基于肝脏血管分割标签的多模态肝脏影像合成
# 面向视杯视盘分割的深度神经网络方法研究
# 基于生成对抗网络的医学图像诊断报告自动生成算法研究
# 用于细胞微环境检测的新型极性/粘度荧光探针的设计合成与应用
# 新型二氧化硫荧光探针的构建及其生物成像应用研究
# 基于DNA纳米结构的传感器用于miRNA的检测及生物成像
# 粘度荧光探针的构建及其在病理模型中的应用——基于TICT机制
# An error occurred when close window
# An error occurred when close window
# 0 2280
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2280
# 0 0
# list index out of range
# 0 2280
# 0 0
# list index out of range
# 0 2280
# 0 243
# year month has pdfs:4296
# 基于时频分析和神经网络的脑电采集分析系统
# 基于深度学习的双光子钙成像中神经元泛化分割方法研究
# 多功能酶智能预测新方法研究
# 基于瘤胃功能微生物构建木质纤维素丁酸—丁醇发酵体系的研究
# 代谢工程改造谷氨酸棒杆菌生产L-缬氨酸
# An error occurred
# 单加氧酶的发掘、改造及在级联反应中应用的研究
# 谷氨酸棒杆菌OYE酶的功能鉴定、半理性设计改造与应用
# 褐藻胶裂解酶的分子改造及其酶学性质分析
# 基于粗酶固定化的高产N-乙酰神经氨酸无细胞体系的构建
# 3'-磷酸腺苷-5'-磷酰硫酸固定化催化体系的构建与优化
# An error occurred
# 基于磁性壳聚糖复合材料对耐高温酶的固定化研究
# L-天冬氨酸α-脱羧酶的挖掘、改造及在催化合成β-丙氨酸中的应用
# An error occurred
# 黑曲霉果胶裂解酶的表达和耐酸性改造
# An error occurred
# 毕赤酵母生长过程中的图像分析技术初步研究
# 多元酶簇微粒的构建及其有序固定化
# 肠膜明串珠菌蔗糖磷酸化酶的表达、分子改造及应用于合成α-熊果苷的研究
# 利用酿酒酵母高效合成月桂烯、罗勒烯和红没药醇
# An error occurred
# 代谢工程改造谷氨酸棒杆菌高效合成组氨酸
# 裂褶菌硒多糖的合成及其结构性质分析
# 阻断大肠杆菌TWF001菌毛合成以提高L—苏氨酸产量
# An error occurred when close window
# 多酶级联催化γ-丁内酯合成1,4-丁二醇
# 重组大肠杆菌合成L-半胱氨酸及其胞内响应型启动子的筛选表征
# 重组大肠杆菌中N-乙酰神经氨酸合成途径的构建与优化
# 代谢工程改造大肠杆菌生产己二酸
# 谷胱甘肽双功能合成酶的半理性改造及全细胞催化合成谷胱甘肽
# 图像识别在裂殖壶藻生长及产油应用中的初步研究
# 代谢工程改造大肠杆菌发酵合成广藿香醇
# 重组地衣芽孢杆菌全细胞转化合成（R）-柠苹酸
# 基于ATP再生的高效制备D-泛酸细胞工厂的构建
# 代谢改造黄柄曲霉高效合成Aspochalasin D及发酵优化
# Fe(Ⅱ)/α-酮戊二酸依赖型双加氧酶挖掘表征及其合成(2S,3R)-3-羟基哌啶酸
# 乙醇酸生物法高效合成研究
# 代谢工程改造热带假丝酵母生产鼠尾草酸
# 氨基酸脱氢酶分子改造及其多酶体系合成D-丝氨酸
# 代谢工程改造枯草芽孢杆菌底盘细胞高效生产乙偶姻
# 异源表达α-葡萄糖苷酶高效合成低聚异麦芽糖
# 柚皮素促进猪肌管生成和成熟作用机理及细胞培养肉应用研究
# An error occurred
# 代谢工程改造大肠杆菌生产软骨素
# An error occurred
# 微生物法生产丙酮酸及其衍生物的过程优化
# 机器学习辅助定向进化提高奇异变形杆菌脂肪酶的甲醇耐受性
# An error occurred
# An error occurred when close window
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2320
# 0 243
# year month has pdfs:4296
# Thermomyces lanuginosus脂肪酶催化特异性检测方法开发与分子改造研究
# 基于紫色杆菌素生物合成途径的L-色氨酸生物传感器的开发及应用
# 代谢改造酿酒酵母细胞工厂高效合成聚酮类化合物
# An error occurred
# 酿酒酵母萜类化合物转运蛋白的预测、鉴定及应用
# 合成ω-氨基脂肪酸的酵母细胞工厂构建
# 麦芽糖淀粉酶LpMA的异源表达及其在烘焙中的应用
# An error occurred
# 氨基甲酸乙酯水解酶分子改造及功能表征
# An error occurred
# 酮糖3-差向异构酶的固定化及生产应用
# Penicillium cyclopium CICC-4022来源右旋糖酐酶的结构解析及调控降解右旋糖酐分子量研究
# An error occurred
# 通过添加蛋白质稳定剂和结构改造提高硫酸软骨素AC酶的热稳定性
# 生物炭负载纳米磁性粒子对鸡粪厌氧发酵的影响研究
# 基于机器学习的酶改造方法研究
# 水凝胶纤维管固定化酶/菌的效果研究
# CHO细胞培养工艺对单克隆抗体电荷异构体的调节
# 纳米酶在外伤性脊髓损伤及其细菌感染伤口治疗中的应用研究
# 基于黑水虻生物转化的蓝藻资源化利用研究
# 微生物电化学反应器中左氧氟沙星的生物强化降解效果及其机制研究
# 基于微生物群体感应的高盐度影响MBR膜污染作用机制及控制研究
# 聚多曲霉菌对重金属镉解毒机制的研究
# 基于海洋群体感应淬灭菌的高盐环境下MBR膜污染控制研究
# An error occurred when close window
# 高标准污水处理厂沿程ARGs、MGEs赋存特征和微生物群落相关性研究
# 黑水虻生物转化蓝藻藻泥的研究
# 外源镧对植物内生菌的影响
# An error occurred
# 同型产乙酸菌Clostridium bovifaecis甲酸脱氢酶缺失型Wood-Ljungdahl途径的固碳机制
# 山梨酸副产物好氧堆肥技术研究
# 用于处理生活污水的好氧反硝化脱氮微生物制剂的研制
# An error occurred
# 富集AOB污泥共代谢降解抗生素过程中的微生物响应和抗性基因归趋
# 异养硝化-好氧反硝化菌的选育及其脱氮特性与途径的研究
# An error occurred
# 光合细菌处理废水过程中单细胞蛋白的合成研究
# 食木锯白蚁（Microcerotermes sp.）肠道共生细菌多样性及其降解木质纤维素的功能特征
# 水生植物与好氧反硝化菌联合脱氮除磷效果的研究
# 黑水虻生物堆肥处理鸡粪物质转化规律及虫粪应用效果评估
# 脱氧雪腐镰刀菌烯醇降解菌的筛选、降解特性研究及其应用
# An error occurred
# 基于甲烷氧化菌的硝酸盐和六价铬还原及作用机理
# 生物炭固定化微生物技术在处理酸性矿山废水中的应用研究
# 锑胁迫下斑马鱼肝脏DNA损伤及作用机理研究
# An error occurred
# 生态安全网络构建研究——以陕西省甘泉县为例
# 苯并[a]芘厌氧降解菌群的富集及其降解效能研究
# 吡噻菌胺优势降解菌的筛选、降解特性及潜在立体选择性研究
# 基于生境质量的武陵山生物多样性保护重点工程区生态安全格局构建
# An error occurred when close window
# 0 2360
# 0 243
# year month has pdfs:4296
# 基于MEMS的柔性微针葡萄糖传感器的设计与分析
# 硅基微囊材料生物强化修复地下水中苯系物
# 微生物在赤泥土壤化进程中的变化及作用研究
# 基于电驱动离子迁移的碳氮耦合微生物电合成研究
# 碳源、电解产氢和盐碱条件对富集HOB的影响
# An error occurred
# 滇西污染农田土壤的淋洗—伴矿景天吸取修复研究
# 毒死蜱和氯氰菊酯对罗非鱼和斑马鱼的急性毒性和联合毒性
# 复合微生物菌剂强化植物萃取重金属的机理及应用研究
# 菌株Pigmentiphaga sp.H8中3-溴-4-羟基苯甲酸的代谢调控机制
# 植物促生菌强化美洲商陆（Phytolacca americana L.）修复重金属污染土壤及对根际微生物群落影响的研究
# 基于生态系统服务的自然资源价值评估和空间权衡关系研究——以江苏省为例
# 土壤中微塑料与菲复合污染的植物和微生物效应
# 桂林市典型生态系统服务功能可持续研究
# 阴山北麓地区生态系统服务功能权衡与协同研究
# 关键气候因子对内蒙古荒漠化的影响研究
# 锡林浩特草原矿区土壤水分时空变异及人工乔木蒸腾规律
# 十大孔兑区生态系统服务功能及其权衡协同关系
# 碳中和情景下中国边缘海地区多环芳烃排放趋势及生态效应
# 噁唑酰草胺对黄鳝生态毒理效应的研究
# 耐盐耐冷异养硝化-好氧反硝化细菌的筛选及强化人工湿地脱氮作用研究
# An error occurred when close window
# 基于日光诱导叶绿素荧光的中国植被总初级生产力估算及其对干旱的响应
# 库布齐沙漠东缘不同类型固沙灌丛下地表凝结水特征
# 我国典型滨海湿地植被根际微生物多样性及功能研究
# 吡啶高效降解微生物的筛选及降解机制研究
# 耐镉砷硫酸盐还原菌的筛选及对土壤镉砷钝化研究
# An error occurred
# 磺胺甲恶唑对砷污染土壤微生物群落特征及抗性基因的影响
# 芦苇菌菌渣联合耐镉微生物修复镉污染土壤的试验研究
# 十二烷基硫酸钠降解微生物筛选及应用研究
# 多菌灵降解菌的筛选及转录组分析
# 青藏高原草甸灌丛化对植物-土壤-酶生态化学计量特征的影响
# 成渝地区双城经济圈植被覆盖度时空变化及其驱动因素研究
# 数字化时代南海生物多样性法律保护研究
# An error occurred
# 基于AHP层次决策分析法构建优化耐盐型多环芳烃高效复合降解菌群的研究
# 琥珀化石数据库搭建及代表性类群演化分析
# 缅甸琥珀中三类节肢动物的化石形态和演化研究
# 竹林植物-土壤系统植硅体组合及有效硅变化特征
# 浙东晚中新世胡桃属果实化石的首次发现及嵊县植物群古植被重建
# 六盘山白垩纪李洼峡组狼鳍鱼化石的埋藏学及古环境分析
# 华南早-中三叠世始鳍龙目新材料的系统分类和演化研究
# 孟氏螺蛳壳体生长层的同位素特征与古温度重建
# 0 2400
# 0 243
# year month has pdfs:4296
# 产α-葡聚糖酶菌株的筛选、酶学特性及其活性改造研究
# 鞘氨醇单胞菌ATCC 31461的三个糖基水解酶的功能鉴定
# 哈氏噬纤维菌的一个属于糖苷水解酶家族9的1,4-β-D-葡聚糖葡萄糖水解酶的鉴定
# 东北林区地下生真菌的分类学研究
# An error occurred
# 吲哚在细菌SOS反应促进接合转移过程中的作用研究
# 维氏气单胞菌TH0426株Fur基因的缺失及其功能的初探
# PI3K/Akt/ERK信号通路在盘基网柄菌细胞趋电性中的作用研究
# 副伯克霍尔德属根瘤菌的比较基因组与系统发育研究
# 面向酿酒酵母检测的电化学免疫传感器的制作
# 植物乳杆菌（R）-CHBE脱氢酶的筛选及性质研究
# 北海涠洲岛可培养细菌多样性及生物活性研究
# 西北地区广义丝膜菌属真菌资源研究
# 红树莓内生细菌的多样性分析及其次级代谢产物抑菌活性评价
# 西藏沙棘根瘤及其内生弗兰克氏菌研究
# 甘肃省蜡伞科真菌物种多样性研究
# An error occurred
# ppGpp合成酶调控淀粉酶产色链霉菌合成丰加霉素的机制研究
# 贵州毕节地区大型真菌遗传亲缘关系分析及白假鬼伞生物学特性研究
# 花溪盾孢囊霉双重培养体系及孢子发育研究
# 贵州乌蒙山区大型真菌多样性研究
# 内生砖红镰刀菌分泌蛋白FlSce1的功能研究
# An error occurred when close window
# An error occurred when close window
# 获得外源共生岛的Rhizobium etli CFN42在毛萼田菁体内定向进化及分子机制的研究
# 嗜水气单胞菌外膜蛋白AhCirA生物学功能的初步研究
# 普城沙雷氏菌ACCC 02146合成灵菌红素相关调控基因的鉴定
# 近平滑假丝酵母ATCC 7330羰基还原酶CpCR的分子改造及其应用研究
# 基于蛋白质组学的红平红球菌XP中硫代谢途径研究
# An error occurred
# 硒还原溶杆菌新种多相分类学鉴定和硒抗性机制研究
# 云南洱源热泉微生物多样性研究及嗜热菌分离鉴定
# 地中海富盐菌细胞分裂相关蛋白FtsZ冗余基因功能的研究
# 微生物在冷表面上的接触传播规律
# 北极新奥尔松融水区潮间带与潮下带沉积物细菌、古菌的多样性研究
# 一种藻类共生细菌Gordonia的鉴定及其胞外多糖的表征
# 海杆菌混合营养型代谢及海洋环境适应性分析
# 南极阿德雷岛企鹅粪土中微生物的群落结构及生态作用研究
# 南极乔治王岛冰锥洞生境微生物的培养探索与新种发现
# 温度和静水压力对Palaeococcus pacificus膜脂化合物的影响
# 马里亚纳海沟深渊沉积物中芽单胞菌的代谢潜力和生态功能研究
# 马里亚纳海沟沉积物中营养细菌和细菌芽孢的丰度和分布研究
# 深渊新属种Anoxybacterium hadale的分离鉴定及其硫代谢特征的研究
# 基于降雨过程的岩溶地下水固碳微生物群落变化研究
# An error occurred
# H1N1亚型犬流感病毒鼠肺适应性机制的初步研究
# 0 2440
# 0 243
# year month has pdfs:4296
# 获得外源共生岛的Rhizobium etli CFN42在毛萼田菁体内定向进化及分子机制的研究
# 嗜水气单胞菌外膜蛋白AhCirA生物学功能的初步研究
# 普城沙雷氏菌ACCC 02146合成灵菌红素相关调控基因的鉴定
# 近平滑假丝酵母ATCC 7330羰基还原酶CpCR的分子改造及其应用研究
# 基于蛋白质组学的红平红球菌XP中硫代谢途径研究
# An error occurred
# 硒还原溶杆菌新种多相分类学鉴定和硒抗性机制研究
# 云南洱源热泉微生物多样性研究及嗜热菌分离鉴定
# 地中海富盐菌细胞分裂相关蛋白FtsZ冗余基因功能的研究
# An error occurred
# 微生物在冷表面上的接触传播规律
# 北极新奥尔松融水区潮间带与潮下带沉积物细菌、古菌的多样性研究
# 一种藻类共生细菌Gordonia的鉴定及其胞外多糖的表征
# 海杆菌混合营养型代谢及海洋环境适应性分析
# 南极阿德雷岛企鹅粪土中微生物的群落结构及生态作用研究
# 南极乔治王岛冰锥洞生境微生物的培养探索与新种发现
# 温度和静水压力对Palaeococcus pacificus膜脂化合物的影响
# 马里亚纳海沟深渊沉积物中芽单胞菌的代谢潜力和生态功能研究
# An error occurred
# 马里亚纳海沟沉积物中营养细菌和细菌芽孢的丰度和分布研究
# 深渊新属种Anoxybacterium hadale的分离鉴定及其硫代谢特征的研究
# An error occurred
# 基于降雨过程的岩溶地下水固碳微生物群落变化研究
# H1N1亚型犬流感病毒鼠肺适应性机制的初步研究
# An error occurred when close window
# 猪源干扰素跨膜诱导蛋白（IFITM）对A型塞内卡病毒复制的影响
# 广西部分地区猫杯状病毒的分离鉴定及其致病性研究
# 猪星状病毒衣壳蛋白单克隆抗体制备及ELISA检测方法建立
# 塞内卡病毒的分离鉴定及其感染性克隆的构建
# 2015-2019年广西部分地区猪繁殖与呼吸综合征病毒的监测及遗传进化分析
# 猪肠病毒G型实时荧光定量PCR检测方法的建立及两株广西地区猪肠病毒G型毒株全基因组序列分析
# 轮状病毒拉曼免疫层析快速检测技术研究
# PCBP2与ISG15相互作用及其影响猪瘟病毒复制的初步探索
# DTMUV重组酶介导的等温扩增检测方法及DTMUV和N-GPV二重PCR检测方法的建立与应用
# 两株DHAV-3毒株全基因组测序及重组酶介导等温扩增DHAV-1和DHAV-3检测方法的建立与应用
# 流感病毒H3N2血凝素HA蛋白MTC和TC的表达纯化与结构表征
# 新冠病毒5'-非翻译区调控寡聚腺苷酸合成酶活力的研究
# 基于纳米孔测序技术的植物病毒快速检测与应用研究
# An error occurred
# 人呼吸道合胞病毒G糖蛋白B细胞表位的筛选及免疫原性的研究
# 人呼吸道合胞病毒F蛋白多肽表位的筛选及免疫原性评价
# EV71病毒感染细胞分泌的sEVs蛋白质组成分析及其功能研究
# 新型星状病毒的病原学鉴定及荧光定量PCR方法的建立
# ABL2调控柯萨奇B3病毒复制的机制研究
# m6A修饰的LONP1抑制CVB3复制的分子机制研究
# 基于数字PCR和扩增子测序技术的虫媒病毒检测方法建立
# An error occurred when close window
# 0 2480
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2480
# 0 0
# list index out of range
# 0 2480
# 0 0
# list index out of range
# 0 2480
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2480
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2480
# 0 0
# list index out of range
# 0 2480
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2480
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2480
# 0 243
# year month has pdfs:4296
# 海马及其生物饵料的宏转录组分析及RNA新病毒的发现
# 基于深度学习的新型冠状病毒功能预测相关问题研究
# HCMV-IE2蛋白抑制NSC的增殖分化造成转基因鼠小头畸形的分子机制研究
# 鸡细胞表面受体Nectin4和SLAMF1促进NDV增殖的机制研究
# An error occurred
# 新型阿卡斑病毒双抗原夹心CLEIA和ELISA抗体检测方法的建立及感染谱的初步调查
# 血清2型登革病毒特异性纳米抗体的构建与功能鉴定研究
# 血清4型禽腺病毒变异株快速鉴别检测方法的研究
# An error occurred
# 犬圆环病毒快速检测方法的建立与广西流行毒株序列分析
# IBDV的分离鉴定和不同致病型病毒的检测方法及其混合感染的研究
# 阿卡斑病毒和蓝舌病毒重组酶等温扩增快速检测方法的建立与初步评价
# PRRSV VLPs的构建与免疫原性研究
# 鸽Ⅰ型副粘病毒的分离鉴定、免疫原性研究及全长cDNA克隆的构建
# 猪重要腹泻病毒多重qRT-PCR鉴别检测方法及PEDV、PDCoV分子流行病学研究
# 近两年广西ALV的分离鉴定及不同P27抗原检测试剂盒的比较研究
# 鸡细小病毒NS1、VP2蛋白的单克隆抗体制备和检测方法的建立
# 猪流行性腹泻病毒GX15株全基因序列分析及感染模型的初步建立
# 猪伪狂犬病病毒的分离和鉴定及其与HMGCR相互作用的研究
# An error occurred
# 基于N蛋白间接ELISA检测猪德尔塔冠状病毒抗体方法的建立
# PCV2荧光定量PCR方法的建立及应用
# 湖南省2021年度H9亚型禽流感流行病学调查及其病毒分离鉴定与基因序列分析
# An error occurred when close window
# 检测PCV2特异性记忆B细胞的ELISpot方法建立及应用
# 猪急性腹泻综合征冠状病毒分离鉴定和四种猪冠状病毒多重荧光定量PCR检测方法建立
# 四种猪繁殖障碍相关病毒的多重荧光定量PCR检测方法的建立及初步应用
# An error occurred
# 基于非洲猪瘟病毒C-type lectin蛋白建立间接ELISA抗体检测方法的研究
# 非洲猪瘟病毒蛋白表达与检测方法建立
# 湖南部分地区PCV2的遗传进化分析及不同基因型毒株体外复制的差异研究
# PRRSV的分离鉴定及其分离株对猪周期黄体细胞分泌孕酮的影响
# 猪圆环病毒2型在猪卵泡中的感染及其对颗粒细胞增殖、凋亡及自噬的影响
# 基于CRISPR-Cas12a系统的PCV2检测方法的建立与应用
# An error occurred
# 猪细小病毒7型的分离及分子流行病学调查
# 热休克蛋白HSP90AB1抑制猪繁殖与呼吸综合征病毒复制作用机制的研究
# An error occurred
# ASFV H240R蛋白间接ELISA方法的建立及其抑制炎症因子的研究
# 猪流行性腹泻病毒经典株和变异株荧光定量RT-PCR双重检测方法的建立及应用
# PEDV结构蛋白S和M在Sf9细胞中的表达、分泌及免疫原性研究
# 猪流行性腹泻病毒的RNA依赖RNA聚合酶的多抗制备及应用
# 猪塞内卡病毒弱毒株的制备及遗传稳定性评价
# SFTSV复制相关宿主因子FUBP3和IFIT5的鉴定与功能分析
# FAF2与SARS-CoV-2 ORF6相互作用并抑制病毒的复制
# An error occurred
# SFTSV假病毒的构建及中和抗体的制备
# EGFR调控汉滩病毒复制的机制研究
# An error occurred when close window
# 0 2520
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2520
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2520
# 0 243
# year month has pdfs:4296
# Tim-3抑制MHC-Ⅱ表达促进病毒感染的分子机制研究
# 靶向甲型流感病毒广谱单克隆抗体的初步研究
# 圣路易斯脑炎病毒RNA解旋酶的晶体结构及其抑制剂的筛选
# An error occurred
# 伊列乌斯病毒解旋酶晶体结构和功能研究以及抗病毒药物筛选
# SARS-CoV-2棘突蛋白融合肽释放的研究
# 马尔堡病毒特异性中和抗体AF-03及其ADCC增强型AF-04的制备及功能评价
# 去泛素化酶USP13通过提高NLRP3蛋白稳定性促进NLRP3炎症小体活化
# 抗CD20/CD3双特异性单域抗体的制备及生物学活性检测
# 鸡肌肉生长抑制素多克隆抗体的制备与应用
# An error occurred
# 基于图深度学习的乳酸菌抗菌肽识别研究
# 具有免疫调节活性乳杆菌的筛选与功能研究
# 2011-2019年广西地区大肠杆菌和沙门氏菌中mcr基因的分布及分子特征分析
# 基于鸭疫里默氏菌MotB蛋白的乳胶凝集和免疫胶体金方法的建立
# 马链球菌马亚种-MDMC0316株的分离鉴定以及rSeM蛋白间接ELISA检测方法的建立
# 呼和浩特地区奶牛临床型乳腺炎金黄色葡萄球菌的分离鉴定、分子分型及耐药性研究
# 捻转血矛线虫伊维菌素耐药相关miRNA筛选及其耐药相关性研究
# 中药单体联合抗菌药物对犊牛源大肠杆菌生物被膜形成的影响及其机制探究
# 内蒙古地区羊源副结核分枝杆菌的分离鉴定及小鼠感染模型的建立
# 绵羊溶血性曼氏杆菌SYS-1株的分离鉴定及小鼠致病性研究
# An error occurred
# 牛源支原体的分离、鉴定及其耐药性研究
# An error occurred when close window
# 绵羊肺炎支原体SY株分离鉴定及HSP70蛋白基因的克隆与分析
# 原核表达猫干扰素ω的纯化及其体外抗FPV活性检测
# An error occurred
# 蜱源性芽孢杆菌的分离鉴定及小鼠致病性研究
# 马源沙门菌的分离鉴定及PCR检测方法的建立
# 猪肺炎支原体RT-qPCR内参的建立及用于亚单位疫苗候选抗原鉴定的研究
# 细胞培养中支原体污染检测方法的建立及应用
# An error occurred
# 猪衣原体多表位融合蛋白的表达和免疫原性研究
# 凝结芽孢杆菌的产孢条件优化及动物试验
# 鸡粪肠球菌长沙株的分离和基因组特征分析及其对檀香醇的敏感性研究
# 猪源肺炎克雷伯氏菌和大肠杆菌双重PCR方法的建立与应用
# 羊源多杀性巴氏杆菌感染条件下MyD88作用机制的初步研究
# 牛鲍曼不动杆菌感染引起的宿主免疫应答机制研究
# 复合精油对弗氏柠檬酸杆菌的体内外抑菌作用研究
# An error occurred
# 地方品种鸡沙门菌的分离鉴定及应用八角肉桂精油防控的研究
# 炭疽杆菌保护性抗原的表达及间接ELISA检测方法的建立与初步应用
# 滑液囊支原体的分离鉴定及其重组酶介导的等温扩增检测方法的建立与应用
# 沙门氏菌噬菌体PSE-D1和PST-H1的特性分析与应用研究
# 噬菌体PST＿H2与抗菌药联合应用的研究
# 食性转换中大熊猫肠道菌群演替规律及基于宏基因组Binning的细菌功能研究
# An error occurred
# 嗜酸乳杆菌β-葡萄糖苷酶及其与抗坏血酸互作特性研究
# An error occurred when close window
# 0 2560
# 0 0
# list index out of range
# 0 2560
# 0 243
# year month has pdfs:4296
# 水稻种植下富硒土壤微生物群落结构及水稻对硒的吸收
# 益生性粪肠球菌的筛选及其抑菌物质的初步探究
# 魔芋葡甘露聚糖益生作用和益生元稳定性分析及对乳酸菌的促进作用研究
# 微生物法制备高纯度低聚果糖菌株的筛选、纯化条件优化及放大工艺的研究
# 十字花科黑腐病菌RpfF调控HrpX和HrpG表达的机理研究
# 黄单胞菌重要蛋白XC1160和XC1553的结构生物学研究
# 十字花科黑腐病菌Ⅲ型效应物XopXccR1的致病机理研究
# 十字花科黑腐病菌纤维素酶致病机理的研究
# 不同产地蜂胶对特异青霉菌（Penicillium notatum）的抑菌作用及其机理研究
# 干旱和冷冻对荒漠土壤微生物群落和功能的影响及遗留效应研究
# 长期轮作土壤溶磷潜力及其与土壤微生物的联系
# 巴氏灭菌嗜黏蛋白阿克曼氏菌对糖尿病合并阿尔茨海默症的改善作用
# An error occurred
# 黑土地典型县域耕地土壤细菌多样性分布特征与空间预测
# 产细菌素乳酸菌的筛选及其益生性能评价
# 高效合成酪醇及羟基酪醇的大肠杆菌细胞工厂构建
# 功能乳酸菌的筛选及其在低盐固态酱油发酵中的应用
# 改造谷氨酸棒杆菌高效生产γ-氨基丁酸的研究
# An error occurred
# 耐盐乳酸菌的益生特性及其在食品发酵中的应用
# 来源于极端嗜酸喜温硫杆菌ArsR/SmtB家族铜敏感型转录因子分子机制研究
# 代谢工程改造谷氨酸棒杆菌生产L-缬氨酸
# An error occurred when close window
# An error occurred when close window
# 代谢工程改造酿酒酵母合成柠檬烯及紫苏酸
# 合成胍基乙酸的重组枯草芽孢杆菌的构建
# An error occurred
# 乳酸片球菌组成型梯度强度PUTR文库的构建、表征和应用
# 膳食唾液酸调节益生菌生长和孕妇肠道菌群的研究
# 发酵乳杆菌CCFM1139缓解牙周炎的临床效果评价及机制探究
# 有机酸联合等离子体活化水对金黄色葡萄球菌的抑制机理及应用研究
# 调控宿主透明质酸含量的后生元筛选及其功效物质解析
# 乳酸菌硒的生物学功能评价及富硒工艺研究
# 肥胖人群肠道菌群生物标志物的挖掘及调控
# 肠道微生物色氨酸代谢特征数据库的构建及应用
# 转化鞣花单宁产尿石素的菌株筛选及抗衰老功效研究
# 大肠杆菌麦角硫因合成体系的构建与优化
# An error occurred
# 保加利亚乳杆菌NQ2508的高密度培养与冷冻干燥保护研究
# 产甘油假丝酵母盐胁迫抗逆基因筛选及应用
# An error occurred
# 高效合成菌体蛋白的酿酒酵母菌株选育
# An error occurred
# 人体肠道中长双歧杆菌占据属内丰度优势的机制解析及筛选方法开发
# An error occurred
# 定向增殖普拉梭菌的膳食因子的筛选及作用机制研究
# 产不同细菌素的格氏乳杆菌对小鼠肠道微生态影响的研究
# An error occurred
# 耐高渗青春双歧杆菌和两歧双歧杆菌的筛选及生产工艺研究
# An error occurred
# 植物乳杆菌发酵对苦杏仁蛋白致敏原性的影响
# An error occurred when close window
# 0 2600
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2600
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2600
# 0 0
# list index out of range
# 0 2600
# 0 0
# list index out of range
# 0 2600
# 0 243
# year month has pdfs:4296
# 动物双歧杆菌乳亚种干预便秘的作用途径研究
# 植物乳杆菌微胶囊的制备及其性能研究
# 贵州不同寄主的锈病病原菌多样性研究
# 贵州红托竹荪绿霉病与土壤微生物群落的关联分析及防控药剂筛选
# 天麻根际土壤微生物多样性分析及其化学成分研究
# 一种臭常山内生真菌的分类及其次级代谢产物的研究
# 生态茶园植物残体在土壤中分解的微生物群落动态
# 降血糖功能乳酸菌的筛选\降糖机理及应用研究
# An error occurred
# 山苍子精油@聚天冬氨酸/壳聚糖纳米粒子对金黄色葡萄球菌生物膜的抑制作用及其应用研究
# 芡实壳多酚对单增李斯特菌的抑制作用及双层抗菌薄膜的制备与应用
# He-Ne激光和脉冲强光诱变选育高产酸醋酸菌及其机制研究
# 植物乳杆菌dy-1发酵促进大麦结合态酚释放的酶学机制研究
# 产气荚膜梭菌噬菌体裂解酶的制备及其抗菌效应研究
# 酱卤肉制品中产气荚膜梭菌的控制研究
# 负载肉桂醛纳米颗粒复合水凝胶在肉制品中对鼠伤寒沙门氏菌的抑制作用
# 基于互作转录组筛选Aspergillus westerdijkiae效应蛋白及其功能分析
# 基于片上散射光子计数复合光谱聚类识别的流式病害孢子检测方法
# 大肠杆菌Nissle 1917鞭毛蛋白的结构特征及其对Caco-2细胞刺激作用初探
# 传统豆豉粑产川芎嗪菌株优选及其发酵特性研究
# 干酪乳杆菌H1发酵番茄酸汤有机酸代谢及特征风味研究
# An error occurred when close window
# 基于基因组学和转录组学的热纤梭菌降解纤维二糖研究
# 板栗冷藏过程中腐败菌剖析及其致腐表征研究
# 植物乳杆菌的筛选及其发酵糟辣椒特性研究
# 喀斯特土壤AM真菌多样性与土壤性质和植物功能性状的关联性
# 中国兜兰属宽瓣亚属植物根际土壤微生物多样性
# 米槁根际土壤可培养促生真菌的筛选及其拮抗作用研究
# 梵净山亚高山灌丛群落丛枝菌根真菌多样性研究
# 间作三叶草和花生对茶园土壤微生物种群的影响
# 长期生草对红壤坡地枇杷园根际微生态的影响
# 市售三文鱼中单增李斯特菌分离鉴定及热失活数值模拟
# An error occurred
# TMC7复合菌系中厌氧菌的分离及其木质纤维素协同降解机制
# An error occurred
# 一株单宁降解菌的分离鉴定、发酵条件优化及代谢途径分析
# Rhodococcus sp.L1降解多菌灵的分子机制研究
# 4-羟基百菌清厌氧微生物还原脱氯功能菌群结构及宏基因组分析
# 功能性乳酸菌的筛选及发酵菌剂的配制及应用
# 脱氧雪腐镰刀菌烯醇降解菌的筛选及其降解机制的研究
# An error occurred
# 地衣芽孢杆菌Ⅰ型L-天冬酰胺酶在枯草芽孢杆菌中的分泌表达及分泌途径研究
# 利用CRISPR/Cas9技术挖掘新型Plipastatin及其产量优化研究
# An error occurred
# 基于费氏弧菌群体感应系统与T7表达系统的迭代基因电路开关的构建及应用
# An error occurred
# 红树林土壤抗菌活性菌株的筛选及其次级代谢产物的研究
# 0 2640
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2640
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2640
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2640
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2640
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2640
# 0 243
# year month has pdfs:4296
# 噬菌体对沙门氏菌生物菌膜的清除效果研究
# 两株链霉菌及宏基因组文库来源的天然产物的发现
# An error occurred
# sRNA SaaS对沙门氏菌粘附特性的影响效应
# 不同毒力单增李斯特菌对小鼠肠道上皮的损伤和宿主防御的影响研究
# 鼠伤寒沙门氏菌生物被膜形成的机制及控制研究
# 红树林链霉菌抗菌次级代谢产物的研究
# An error occurred
# 水果内生源乳酸菌的筛选及其发酵蓝莓汁功能特性研究
# 瑞士乳杆菌LZ-R-5胞外多糖生物合成途径解析及其关键基因YveK功能研究
# 滨海湿地盐地碱蓬根际解磷细菌群落结构特征及生态效应
# 块菌伴生微生物多样性研究
# 阴沟肠杆菌DJ在盐碱胁迫下促生机制的研究
# 不同碳源对嗜热链球菌N1-7冷冻干燥存活率的影响
# 产抗菌肽乳酸菌筛选与乳酸菌互作预测研究及平台构建
# An error occurred
# 真空冷冻干燥对保加利亚乳杆菌M-58细胞活性和贮藏稳定性的影响研究
# 双歧杆菌微胶囊的工艺优化及性能评价
# 降解亚硝酸盐乳酸菌的筛选及其在发酵羊肉香肠中的应用
# 青春双歧杆菌微胶囊的制备及特性研究
# An error occurred
# 抗弓形虫感染乳酸菌的筛选及鉴定
# 复合益生菌中单菌株的生物量定量方法研究
# An error occurred
# 乳酸菌对发酵香肠凝胶特性及风味的影响
# An error occurred when close window
# 噬菌体对沙门氏菌生物菌膜的清除效果研究
# 基于信号分子AI-2的发酵乳杆菌对发酵羊肉香肠品质特性的影响研究
# An error occurred
# 复合发酵剂特性及菌粉制备工艺研究
# An error occurred
# 瑞士乳杆菌H11最适营养需求解析及培养条件优化
# 培养体系中氧化还原电位对干酪乳酪杆菌Zhang生物量的影响
# 保加利亚乳杆菌M-58在发酵豆乳中的应用研究
# 乳酸菌抗氧化特性及其对发酵香肠色泽的影响
# 瑞士乳杆菌H11在发酵豆乳中的特性研究及其产品开发
# An error occurred
# 嗜酸乳杆菌LA-06培养基优化及高密度发酵工艺研究
# 预冻工艺对瑞士乳杆菌H11冻干菌体存活性的影响
# An error occurred
# 产抑制弓形虫活性物质乳酸菌的筛选及鉴定
# An error occurred
# 副干酪乳酪杆菌PC646抗冷冻保护剂的筛选及优化
# 保加利亚乳杆菌T-50和嗜热链球菌S10复配发酵剂应用研究
# 发酵牛乳和豆乳作为载体对益生菌耐受胃肠液的影响研究
# An error occurred
# 嗜热链球菌S10培养基优化及培养温度对菌体生物量和活性的影响
# 食醋中乳酸菌的分离鉴定及其发酵特性研究
# 巴基斯坦自然发酵乳中乳酸菌的分离鉴定及优势菌基因组学研究
# An error occurred
# 嗜热链球菌IMAU20246胞外多糖的表型特征及其生物合成机制的研究
# 燕麦与箭筈豌豆混播下燕麦性状表型和土壤养分及微生物群落结构的研究
# 绿肥配施氮肥对岩溶土壤微生物群落及水稻产量的影响
# An error occurred when close window
# 0 2680
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2680
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2680
# 0 0
# list index out of range
# 0 2680
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2680
# 0 243
# year month has pdfs:4296
# 禾谷镰刀菌引起的新病害鉴定及其Fg2518基因功能研究
# 红曲霉菌株的筛选及其对红曲霉奶酪中代谢产物的影响
# 微波场非热效应对生孢梭菌的灭活机理研究
# 基因工程菌株Xanthomonas campestris ΔrpfBΔxanK发酵工艺优化及与其野生型菌株转录组学分析
# 不同毒力基因型副溶血性弧菌混合生物被膜的研究
# 肺炎克雷伯菌裂解性噬菌体特性分析及在食品上的应用
# An error occurred
# 双层微胶囊包埋益生菌及体内外效果评价
# 产果胶酶菌株的筛选、酶学性质的研究及应用
# 主要环境因子影响的单增李斯特菌异质性研究
# 低温对单增李斯特菌和大肠杆菌O157:H7致病特性及酸性电解水耐受性的影响
# An error occurred
# 发酵鱼露中优势菌群与质量的相关性及生物胺的控制
# 万古霉素修饰碳纳米管对金黄色葡萄球菌分离与富集的研究
# 沙门氏菌噬菌体的分离与表征及在食品基质中的应用研究
# 不同胁迫条件下产志贺毒素大肠杆菌的生长适应机制研究
# 片球菌素高产菌株C23221的诱变与发酵动力学研究
# 产河鲀毒素细菌的分离鉴定及弧菌群体感应元件LuxR对细菌河鲀毒素产量的影响
# 南极菲尔德斯半岛特征微环境土壤氮循环细菌多样性比较研究
# An error occurred
# 光活性疏水壳聚糖（GA/OA-g-CS）薄膜的制备及其光动力抗菌及清除生物被膜研究
# 构建多层结构载体提升嗜酸乳杆菌JYLA-191抗逆性研究
# 碘化钾对没食子酸辛酯介导的光动力抗菌和清除生物被膜的增效机制研究
# An error occurred
# An error occurred when close window
# 基于全基因组与转录组研究假单胞菌低温环境下生物被膜形成与致腐特征
# 海藻酸钠—果胶—乳清分离蛋白复合物构建及对植物乳杆菌和EGCG的共包埋研究
# 婴儿双歧杆菌及其与EGCG联用对结直肠癌细胞的体外胁迫研究
# 植物乳杆菌Z-1胞外多糖的理化特性及及生物活性研究
# 主流甜味剂对常见食品微生物生物被膜形成影响的筛查研究
# 鼠李糖乳杆菌微胶囊结肠靶向递送系统的构建及其对小鼠肠道菌群影响的研究
# 植物乳杆菌对发酵香肠蛋白质分解的影响
# 蒙古国Hurunge中细菌多样性、益生特性及全基因组研究
# 丁酸梭菌对绵羊蛋白质代谢及肉品质的影响
# Lentilactobacillus rapi subsp. dabitei subsp. nov.的鉴定和应用特性研究
# 渗透胁迫下甲基化转移酶突变体及其野生型的多组学分析
# 植物乳植杆菌群体遗传学及功能基因组学研究
# 应用培养和非培养法探究不同分娩方式婴儿肠道乳酸菌菌群结构
# An error occurred
# 鼠李糖乳酪杆菌Probio-M9太空诱变分离株的表型及基因组研究
# 副干酪乳酪杆菌ALAC-4抗真菌肽的抑菌机理及其应用特性研究
# An error occurred
# 干酪乳酪杆菌Zhang活的非可培养态的诱导及蛋白组学研究
# 内蒙古呼伦贝尔草原生境乳酸菌分离鉴定及微生物多样性研究
# DNA甲基化对副干酪乳酪杆菌Zhang乙醇胁迫响应机制的影响
# 温度对副干酪乳酪杆菌高密度培养过程中生长特性的影响机制
# 干酪乳酪杆菌Zhang非可培养态的诱导及其转录组研究
# 0 2720
# 0 0
# list index out of range
# 0 2720
# 0 243
# year month has pdfs:4296
# 降尿酸乳酸菌的筛选及其潜在机制研究
# 具有潜在益生特性的乳酸菌对非电解微酸性次氯酸的耐受特性及机制的研究
# 乳酸盐与渗透胁迫对干酪乳酪杆菌Zhang的损伤机理及保护措施研究
# An error occurred
# 植物乳植杆菌IMAU30043胞外多糖的抗氧化活性及生物信息学研究
# 交互胁迫对植物乳植杆菌LIP-1冷冻干燥存活率及室温贮藏稳定性的影响
# 银杏内生菌介导纳米银的生物合成及抑菌活性研究
# 菌藻共培养体系的建立及其除氮特性研究
# 弃耕红壤稻田磷素转化特征及其微生物响应过程
# 黑水虻肠道油脂降解菌X8的分离、鉴定与初步应用
# 库布齐沙漠藓类结皮与其他不同演替阶段结皮及下层土壤微生物群落结构特征比较
# An error occurred
# 蚕砂中产1-脱氧野尻霉素菌株PD04的筛选、鉴定及特性研究
# 微课在中职《植物生产与环境》课程中的开发与应用研究——以“植物生产与土壤培肥”为例
# 丹参组河南鼠尾草与美丽鼠尾草的物种分化研究
# 基于图形和图像的植物叶片建模研究
# An error occurred
# 理化因子调控三角褐指藻PUFA合成的初步研究
# 基于多视角图像的植物三维表型获取及自动解析技术研究
# 1949年以前中国西南地区苔藓植物采集研究史
# 1949年以前华南地区苔藓植物采集与研究史
# An error occurred
# 结构稳定型核酸探针的构建及其在植物分子检测中应用
# 拟南芥FtsH和cpSRP54维持类囊体蛋白稳态的研究
# An error occurred when close window
# 拟南芥自噬与多囊泡体途径的功能互作
# 基于荧光光谱和拉曼光谱技术的花粉分类鉴别研究
# 无籽刺梨花粉败育及果实发育的细胞学基础
# 多壁碳纳米管和氢化镁调控侧根发生的分子机制
# 植物花形态科学摄影技术体系探索——以赛罕乌拉自然保护区常见植物为例
# 四翅滨藜对铜的生理响应及TRV介导的VIGS体系的构建
# 外源褪黑素诱导黄瓜幼苗镉胁迫耐受性的研究
# An error occurred
# 堇菜属三种植物中B类MADS-box基因对光周期响应的比较研究
# 光照对蓬莱宫和火龙果细胞形成草酸钙晶体的影响
# 构树和桑树幼苗的无机氮利用对模拟喀斯特逆境的响应
# 基于CMOS相机的植物叶绿素荧光成像系统开发与应用
# An error occurred
# 谷胱甘肽和过氧化氢参与氢气诱导侧根发生的机理研究
# 拟南芥磷脂酶D调控AMT1;1和应答高铵胁迫的分子机理
# An error occurred
# 莱茵衣藻铜转运蛋白CrCTR2功能及其对光合产氢的影响
# BPC1/BPC2-GALS1在拟南芥响应盐胁迫中的机理研究
# 黄海沿岸松林外生菌根真菌资源调查及外生菌根真菌提高黑松耐盐性机制研究
# 乙烯对拟南芥砷耐性的影响及其机制探究
# An error occurred
# 拟南芥蛋白激酶C受体（RACK1）调控生长素信号机理的初步研究
# 外源ABA对柳枝稷镉毒性的缓解效应及生理机制探究
# 侧根诱导化合物LRI1的功能鉴定和机制解析
# An error occurred when close window
# 0 2760
# 0 243
# year month has pdfs:4296
# 角倍蚜冬寄主苔藓繁殖利用技术研究及新寄主的发现
# 红壤侵蚀退化地生态恢复先锋植物芒萁对不同环境逆境胁迫的响应机理
# 拟南芥YDA-MKK4/MKK5-MPK3/MPK6级联调控角质层形成
# An error occurred
# 臭椿酮调节植物生长发育的作用研究
# 一种全区间热脉冲液流测量方法
# An error occurred
# 干旱区野生旱生植物种子萌发特性及引发技术研究
# 沙葱种子丸粒化技术优化及其耐旱、耐盐碱效果分析
# An error occurred
# 硒浸种对地梢瓜种子萌发及生理生化基础的影响
# 植物灯用玻璃基LED的设计、性能及应用
# 镉胁迫下烟草细胞骨架与粘弹性的动态监测与研究
# 山黧豆酰基转移酶BAHD3催化β-ODAP合成的活性分析
# 拟南芥胼胝质合成酶PMR4调控植物衰老的功能和作用机理
# 基于荧光开启型的新型罗丹明探针的设计、合成及在检测植物信号分子方面的应用
# 拟南芥铁转运蛋白AtCBSDUF5的功能研究
# An error occurred
# 基于光学特性参数的绿萝叶片叶绿素含量分布估测研究
# 地梢瓜硒蛋白提取工艺优化及体外抗氧化能力分析
# An error occurred
# 五种蜘蛛抱蛋属植物（天门冬科）的传粉生物学探究
# 基于卷积神经网络的野外入侵植物识别分类的研究
# 我国东南不同生境下黄山松、马尾松树轮早晚材宽度对气候的响应
# 阿根廷NDVI时空变化及其对气候和人类活动的响应
# An error occurred when close window
# 松辽流域植被变化及其驱动因子
# 植被-土壤综合视角的元谋干热河谷上限研究
# 亚高寒草甸植物合成群落结构与生产力的关系
# 青藏高原高寒草甸非随机物种丧失对节肢动物多样性的影响
# 青藏高原高寒草甸常见优势种吸收根性状种间变异研究
# 狼毒大戟雌花运动的适应性意义及机理研究
# 祁连山植被变化及其对气候因子和人类活动的响应研究
# An error occurred
# 祁连山不同植被类型区土壤理化性质及影响因素研究
# 三北地区植被恢复对土壤有机碳和水分的影响——基于Meta分析
# 不同降水条件下沙鞭种群空间格局及对流沙治理的启示
# 2001-2018年蒙古高原植被变化及其对气候变化的响应
# 2001-2017年氮沉降对中国植被影响的时空变化研究
# An error occurred
# 甘南高寒草甸植物群落不同取样尺度下物种共存机制研究
# 祁连山植被NPP时空演变及驱动因子分析
# 阿拉善沙漠五种植物根系生态特征研究
# 基于日光诱导叶绿素荧光的植物对气候变化响应模型及其预测研究
# 唐白河流域植被覆盖时空演变及驱动因素研究
# 西天山植物群落多样性沿海拔梯度的变化特征
# 大别山五针松叶、细根功能性状和细根动态的研究
# 贵州竹类植物区系及空间分布规律研究
# An error occurred when close window
# 0 2800
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2800
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2800
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2800
# 0 243
# year month has pdfs:4296
# 松辽流域植被变化及其驱动因子
# 喀斯特适生植物种间相互作用对形态可塑性的影响
# 喀斯特木本植物群落功能多样性及稳定性随生境异质性的变化
# An error occurred
# 黔中喀斯特区岩生苔藓不同时期植物功能性状与岩面生境互作
# 黔中喀斯特区碳酸岩不同演替时期岩生地衣群落对环境的响应
# 喀斯特异质性生境枯落物分解对土壤有机碳组分和植硅体碳的影响
# 中国兜兰属宽瓣亚属植物生境特征及保护分析
# An error occurred
# 喀斯特土壤养分资源对木本植物群落CSR策略的影响
# 不同护坡草种根系分布特征及根土复合体力学性质研究
# 毛乌素沙地气候变化及其对植被NDVI的影响
# 毛乌素沙地植被物候动态及其对气候变化的响应
# 1990-2019年榆神府矿区不同地貌植被覆盖度和景观格局演化研究
# An error occurred
# 宁东北部植被生态变化及其影响因素分析
# An error occurred
# 基于序列二次规划的气候与植被生长状况的相关性研究
# 黔北典型丹霞地貌种子植物多样性及其空间分异
# An error occurred
# 贵阳市不同海拔梯度石生苔藓植物群落特征及生态功能研究
# 极狭域特有植物辐花苣苔濒危原因及离体培育技术研究
# 土壤微生物在植物多样性影响群落可入侵性中的作用研究
# 不同多样性组合土壤对两种外来入侵植物生长的影响及其背景依赖性研究
# An error occurred
# 黄河三角洲滨海湿地退耕还湿区域的土壤、植物及种子库的演变过程分析
# An error occurred when close window
# 氮添加、增温和降雨改变对黄土高原半干旱草地植物群落多样性及生产力的影响
# 福建原生被子植物区系特征及其性别系统多样性研究
# 基于遥感的中国城镇化引起植被物候变化的空间异质性特征研究
# 疏花水柏枝残存种群有性繁殖的空间异质性
# 黄河三角洲湿地互花米草与盐地碱蓬氮素利用特征差异及其微生物学机制
# 大兴安岭森林分布区植被物候对主要环境因子的响应
# 黄河三角洲典型潮沟形态特征对潮滩植被和土壤空间分布的影响
# 锡林郭勒国家级自然保护区植物多样性的研究
# 基于遥感的恩格贝生态示范区植被长势动态监测研究
# 基于郊狼算法和BP神经网络的叶绿素a浓度的反演方法研究
# 光伏电站风沙运动特征及植被恢复对土壤的影响
# 固沙先锋植物沙打旺根系固土抗蚀力学特性的研究
# 基于高光谱遥感的六种典型荒漠植物冠层含水率反演研究
# 查干淖尔干盐湖周边植被分布及地表侵蚀特征
# 大兴安岭植被覆盖时空变化特征及其驱动机制分析
# 模拟氮、硫沉降对水生植物生长和生理生态的影响
# 青藏高原高寒植被物候时空变化特征及其对植被水分利用效率的影响研究
# GNSS-IR与多源数据融合的植被含水量和土壤湿度同步反演研究
# 基于微流控显微荧光的浮游藻类细胞计数技术研究
# 兴凯湖冰封期浮游植物群落结构时空特征及驱动因子研究
# 0 2840
# 0 243
# year month has pdfs:4296
# 嫩江流域湿地植物群落和功能性状对管理模式的响应研究
# 水动力与植被对南汇边滩沉积过程作用的观测及数值模拟
# 基于景观偏好的滨河草本植物组群应用策略研究——以浏阳河河岸带草本植物组群调查为例
# 西鄂尔多斯四合木荒漠的种类组成与种群分布格局研究
# 东阿拉善荒漠绵刺群落的种类组成与种群分布格局研究
# 内蒙古奈曼旗黄花塔拉苏木民族植物学研究
# 珍稀荒漠植物裸果木适应干旱生境的生理及分子机制研究
# An error occurred
# 蒙古国杭爱山植被返青期变化及其影响因素分析
# 蒙古高原植被水分利用效率时空变化特征及驱动因素研究
# 季前干旱对蒙古高原植被物候的影响研究
# 伏牛山龙池墁油松径向生长对气候变化的响应
# 桐柏山马尾松树木年轮与气候变化关系研究
# 黄河流域干热变化及对植被影响研究
# 全球气候变化背景下秦巴山地珍稀濒危云杉属植物适生区变化
# 植物叶片C、N、P化学计量特征及影响因素——以中国22个城市为例
# 毛乌素东南缘典型固沙植物根区细菌特征及其对地下水埋深的响应
# 闽江下游湿地土壤、植物硅素空间分布特征及其影响因素
# 东北地区口蘑类真菌的分类及生药资源学研究
# An error occurred
# 贵州省马铃苣苔属与石蝴蝶属植物分类修订
# 贵州省野生凤仙花属（Impatiens L.）植物分类修订
# An error occurred when close window
# 嫩江流域湿地植物群落和功能性状对管理模式的响应研究
# 浙东晚中新世漆树科分类鉴定与古地理迁移以及季风强度对比研究
# An error occurred
# 基于不同结皮藻种的筛选、鉴定与人工蓝藻结皮培育技术的优化
# An error occurred
# 红豆杉种子中抗菌成分的筛选及其应用研究
# 大黄素新功效的发现及机制研究
# 基于改进Mel谱图与特征选择的鲸鱼分类方法研究
# 鲸豚动物社交信号时频特征提取关键技术研究
# 青春期母本存在对小鼠认知能力及海马齿状回神经发生的影响
# 性腺升糖素在斑马鱼摄食和糖代谢中的功能与机制研究
# 酿酒酵母菌对果蝇睡眠的影响研究
# 斑马鱼眼睛早期发育及其CD34和Vimentin表达动态
# 古希腊社会生活中的动物与动物观念——以“五畜”为中心的研究
# 缢蛏Hsp和caspase基因家族分析及干露胁迫下的表达模式和生理响应研究
# 基于深度学习的端到端鸟类鸣声识别方法研究
# 日本医蛭唾液腺细胞分泌机制的研究
# Tnfrsf11a-NF-κB通过活化破骨细胞调控斑马鱼侧线管道形成
# 环境DNA技术在红树林底栖生物多样性研究中的初探
# 吉林省舒兰市青松林区三种鼬科动物生态位差异研究
# 基于生态位模型预测吉林省东部山区原麝及獐潜在分布
# 蝙蝠回声定位声波对甜菜夜蛾的非消耗效应研究
# An error occurred when close window
# 0 2880
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2880
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2880
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2880
# 0 0
# list index out of range
# 0 2880
# 0 0
# list index out of range
# 0 2880
# 0 243
# year month has pdfs:4296
# 浙江清凉峰国家级自然保护区黑麂与小麂潜在栖息地预测及共存机制研究
# 浙江清凉峰国家级自然保护区四种脊椎动物空间分布及活动节律研究
# An error occurred
# 梵净山有蹄类动物的时空共存模式
# 贵州掌突蟾属的物种分布及形态、鸣声变异研究
# An error occurred
# 福州城市公园鸟类群落特征及其栖息地景观营造研究
# HIF通过经典Wnt信号调控斑马鱼侧线神经丘发育
# 长江口南部水域春秋季游泳动物群落结构与环境因子关系的研究
# 南汇东滩堤内湿地水鸟的年际变化与不同食性雁形目鸟类线粒体基因组的适应性进化分析
# 海漂垃圾堆积对九龙江口红树林大型底栖动物群落结构及食源的影响
# 崇明岛河道后生浮游动物群落结构时空变化及水质评价
# An error occurred
# 外来入侵生物福寿螺分子鉴定及其与环境互作效应研究
# 莱州湾东部海域游泳动物群落结构特征及其与环境因子关系研究
# 西伯利亚蝗形态特征和卵的耐寒性研究
# An error occurred
# 陈巴尔虎旗不同生境蝗虫群落多样性及草原主要危害蝗虫毛足棒角蝗体内生化物质变化的研究
# 基于深度学习的东洞庭湖鸟类识别研究
# 广叶螨族与棘爪螨族（蜱螨亚纲：叶螨科）分类修订
# 基于整合分类学方法对中国海竹蛏总科的分类与系统演化研究
# 基于线粒体基因组的中国片角叶蝉亚科系统发育研究
# 转铁蛋白家族基因在褐飞虱生存及生殖中的作用研究
# Hox基因调控二斑叶螨足的生长发育研究
# An error occurred when close window
# An error occurred when close window
# 基于深度学习的蝴蝶种类识别研究
# An error occurred
# 包头市植物园不同植被区昆虫群落多样性分析
# 贵州蜡蚧科分类研究
# 中国叶螨总科分子系统发育研究
# 中国菱纹叶蝉族分类研究
# 雄尾螨科中国区系及其几何形态分类研究
# 改进决策树算法及其蝴蝶分类识别研究
# 花鲈IL-10细胞因子家族基因克隆及表达分析
# 中国苗族的体质类型和人种学特征
# 中国侗族的人类生物学研究
# 中国毛南族的体质特征研究
# 马克思主义生态哲学视域下人与自然生命共同体的构建及实践价值研究
# 基于微透镜积分视场光谱仪的图像重构研究
# 基于小波变换和注意力的卷积网络凌星光变分类研究
# 天文观测用红外焦平面探测器的测试和近红外太阳成像应用研究
# 基于中国丽江日冕仪观测的绿线强度分布研究
# Wolter-Ⅰ型X射线聚焦镜姿态精密调节与测量
# 基于Transformer结构的直接波前重构方法研究
# 基于大数据方法的SKA图像高动态范围重建研究
# 基于深度学习的星系图重建技术研究
# 0 2920
# 0 243
# year month has pdfs:4296
# 天马望远镜背架结构温度效应分析
# 用于Stewart平台的负载时变伺服控制系统研究
# 火流星监测网及火流星监测关键技术研究
# CXPD立方星前端电子学优化研究
# 二维复摆倾斜隔振特性的实验研究
# 基于TESS对大振幅δ Scuti型变星频率和振幅进行统计研究
# 高温高压条件下Fe-N体系电阻率的实验研究
# 修正黑洞时空中物质场的吸收与引力透镜效应
# An error occurred
# 多站融合的深度学习引力波信搜寻方法研究
# 黑洞阴影的理论分析和数值模拟
# 扩展相空间中黑洞霍金辐射和阴影研究
# 超新星和千新新星伽玛暴的观测与统计性质
# 利用黑洞的准正规模检验广义不确定原理
# 恒星蓝回绕的物理机制研究
# 基于LAMOST和TESS巡天数据研究变星物理参数和特殊过程
# 利用机器学习算法研究爆发性天体的统计特性及物理机制
# 耀变体辐射的周期性研究
# 耀变体多波段光变与能谱分析
# 耀变体喷流的高能伽玛射线辐射特性研究
# 平谱射电类星体3C 279光变过程物理性质的研究
# An error occurred when close window
# 费米耀变体多波段辐射机制与物理特性究
# An error occurred
# 蝎虎类星体Mrk 421的宽带能谱光变特性分析
# 近邻分子云的物理性质
# 碎片盘的样本搜集与性质统计研究
# 新伽玛射线赛弗特一型星系的搜寻与其多波段特性研究
# 基于深度学习的星系形态分类研究
# 基于多模态机器学习的天体分类和参数预测研究
# 月背射电天文观测天线的设计
# 基于蒙特卡洛模拟的宽视场望远镜快速射电暴观测机遇研究
# 两类伽玛暴X射线余辉光变特性的比较研究
# 伽玛暴主暴和后暴能谱特性统计研究
# 小尺度磁重联导致中间暗条形成
# 含水冰月壤的钻进力载和生热机理研究
# 月面采样模拟机械臂操作误差分析与补偿
# 基于虚拟现实的火星场景立体匹配算法与评价方法研究
# 基于探测雷达的火星次表层结构探测研究
# 基于光学天文跟踪数据小天体星历确定与参数解算研究
# 许靖华现实主义灾变论思想研究
# 基于离散元与系统动力学耦合的钻探装置动态特性研究
# 采用月壤袋的月面结构建造方案及受力性能研究
# 0 2960
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2960
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2960
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2960
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 2960
# 0 0
# list index out of range
# 0 2960
# 0 243
# year month has pdfs:4296
# 极区月壤旋切式微量定量采样特性研究及其适应性验证
# 不确定性分析角度下局地尺度高山林线交错带上下线垂直分布格局及地理解释
# 乌兰木伦河流域景观生态格局与蒸散发时空变化研究
# 湘江流域景观格局及生境质量研究
# 郑州市三维景观空间格局变化及其碳效应
# 秦巴山地景观格局变化及生态系统碳储量研究
# 基于绿色基础设施评价模型的生态网络研究——以河南省方城县为例
# 黄河下游影响区景观生态安全时空演变及格局优化研究
# 遇龙河流域景观格局优化与美景度提升研究
# 1996年以来黄河清水沟沙嘴地貌演变
# 1964年以来黄河刁口亚三角洲河口地貌演变研究
# 库姆塔格沙漠沙颗粒岩矿特征及其成因
# 库布齐沙漠地表沉积物粒度与地球化学特征的空间分布研究
# 青藏高原南部雅拉香波雪山及邻区更新世以来地貌形态特征分析
# 南海珊瑚礁区有孔虫指数的空间变化及其记录之西沙群岛近2600年的生态环境特征
# 近40a乌珠穆沁伏沙区沙漠化时空演变及其成因分析
# 黄河上游景泰段流域地貌与新生代物源分析
# 1979-2100年中国寒区范围分布与变化及其对气候变化的响应
# 南极宇航员海水文结构及海洋混合研究
# 基于Elmer/Ice的玛丽伯德地冰盖现状及演化模拟
# An error occurred when close window
# An error occurred when close window
# 基于深度学习的南极表面融水识别技术研究
# 山体效应因子对青藏高原潜热和感热通量的影响研究
# 畜禽粪便中铜和磺胺二甲嘧啶污染对稻田土壤温室气体排放及相关微生物基因丰度的影响
# 生物质炭和化学硝化抑制剂对不同农用土壤氧化亚氮排放及相关功能基因丰度的影响
# 铁锰对稻田周丛生物氨氧化能力的影响及其机制研究
# 基于深度迁移的土壤制图研究
# An error occurred
# Zn2+对土壤-石灰岩系统碳汇效应影响研究
# 包头黄河湿地土壤碳氮磷及生态化学计量特征研究
# An error occurred
# 不同管理模式对草地土壤水-碳关系及其植物群落的影响
# 典型草原梯级带土壤温室气体通量特征及其影响因素研究
# 科尔沁沙地沙丘-草甸相间地区土壤呼吸模拟估算
# 氮沉降和增雨背景下蚂蚁巢穴对土壤温室气体排放的影响及其机制
# An error occurred
# 水稻土厌氧氨氧化对不同农田管理的响应
# An error occurred
# 牲畜排泄物返还对季节性冻融高寒草原氮素动态及N2O排放的影响
# 可降解微塑料对土壤及其团聚体温室气体排放的影响
# 微塑料对滨海湿地土壤有机碳矿化和温室气体排放的影响
# 祁连山青海云杉林土壤氨氧化菌群落结构及功能研究
# 水盐胁迫下枯草芽孢杆菌对棉花生长及耐盐性提升机理研究及其模型模拟
# γ-聚谷氨酸对盐碱化土壤水盐运移及棉花生长的影响研究
# 炭基生物富硒技术应用于健康农产品生产示范——以南京市溧水区芝山富硒产业园区为例
# 0 3000
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 3000
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 3000
# 0 243
# year month has pdfs:4296
# 融合叶绿素a荧光与反射光谱的芦竹耐盐性快速评价方法研究
# 外源碳氮添加对杉木人工林土壤有机碳周转和稳定性的影响
# 不同钝化剂对弱酸性土壤-水稻系统中镉、铅钝化效果的研究
# 不同间伐强度杉木人工林凋落物特征研究
# 不同温度下亚热带典型乔木叶凋落物添加对土壤有机碳周转的影响
# 条带式隔层对滨海盐碱土壤水盐肥分布及狗牙根生长的影响
# 黄河三角洲咸水结冰灌溉洗盐机理及数值模拟
# 黄河三角洲盐碱地土壤质量评价与障碍因素分析——以黄三角农高区为例
# 基于GEE的黄河流域盐渍化遥感监测研究
# 不同腐化方式的秸秆促进赤泥成土过程及其调控措施研究
# 模拟增温对大兴安岭兴安落叶松林土壤温室气体通量的影响
# 模拟增温对大青山油松林土壤理化性质及土壤酶活性的影响
# 砒砂岩区不同生态修复植被根际土壤微生态环境特征及土壤质量评价
# 不同改良措施对区域苏打盐碱土及玉米生长影响
# 生物炭基肥对盐碱地改良与葵花生长影响
# 腾格里沙漠东北缘飞播植物群落土壤水分特征研究
# 基于面向对象的土壤盐渍化信息提取及时空变化研究
# 旺业甸华北落叶松人工林土壤与枯落物特征及保水保肥能力评价
# 毛不拉孔兑穿越沙漠段人工植被蒸腾耗水特征及承载力研究
# 西鄂尔多斯地区沙冬青及伴生种群落分布对土壤理化性质的影响
# An error occurred when close window
# 腾格里沙漠东北缘飞播造林区植物群落特征及土壤理化性质研究
# 有机无机肥配施对河套灌区盐碱化农田温室气体排放及高粱生长的影响
# An error occurred
# 咸水冬灌对盐碱地土壤水热盐运移及作物生长规律的影响
# 基于工程措施的盐碱化草地水盐调控机制与技术研究
# An error occurred
# 微生物菌肥对砒砂岩区人工林土壤微生态环境的调控研究
# 神东煤矿塌陷条件下复垦区土壤性质变化及质量评价
# 蚯蚓粪肥、保水剂与水肥互作对风沙土的改良研究
# 达拉特旗典型人工林林下植被特征与土壤理化性质研究
# 内蒙古荒漠草原显热通量特征及影响因素研究
# 短花针茅荒漠草原丛枝菌根真菌群落对降水变化与氮沉降的响应
# An error occurred
# 放牧强度对荒漠草原土壤有机碳组分及其稳定性的影响
# 不同管理措施下内蒙古草原土壤固碳潜力研究
# 温度升高和氮沉降对荒漠草原生态系统碳交换的影响
# An error occurred
# 内蒙古针茅草原土壤微节肢动物群落调查
# 生物质改良剂对沙质土壤改良效果的研究
# 冻融循环作用下纤维改良膨胀土力学性能及数值模拟
# 沙葱、沙芥栽培基质的筛选
# An error occurred
# 耐盐碱促生微生物的筛选、鉴定与应用初探
# An error occurred
# NaCl胁迫下5个种源黑果枸杞一年生苗的生理响应研究
# 模拟增温和减雨对中亚热带常绿阔叶林凋落物分解的影响
# An error occurred when close window
# 0 3040
# 0 0
# list index out of range
# 0 3040
# 0 0
# list index out of range
# 0 3040
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 3040
# 0 243
# year month has pdfs:4296
# 腾格里沙漠东北缘飞播造林区植物群落特征及土壤理化性质研究
# 有机无机肥配施对河套灌区盐碱化农田温室气体排放及高粱生长的影响
# 咸水冬灌对盐碱地土壤水热盐运移及作物生长规律的影响
# 基于工程措施的盐碱化草地水盐调控机制与技术研究
# 微生物菌肥对砒砂岩区人工林土壤微生态环境的调控研究
# 神东煤矿塌陷条件下复垦区土壤性质变化及质量评价
# 蚯蚓粪肥、保水剂与水肥互作对风沙土的改良研究
# 达拉特旗典型人工林林下植被特征与土壤理化性质研究
# 内蒙古荒漠草原显热通量特征及影响因素研究
# 短花针茅荒漠草原丛枝菌根真菌群落对降水变化与氮沉降的响应
# 放牧强度对荒漠草原土壤有机碳组分及其稳定性的影响
# 不同管理措施下内蒙古草原土壤固碳潜力研究
# 温度升高和氮沉降对荒漠草原生态系统碳交换的影响
# 内蒙古针茅草原土壤微节肢动物群落调查
# 生物质改良剂对沙质土壤改良效果的研究
# An error occurred
# 冻融循环作用下纤维改良膨胀土力学性能及数值模拟
# 沙葱、沙芥栽培基质的筛选
# 耐盐碱促生微生物的筛选、鉴定与应用初探
# An error occurred
# NaCl胁迫下5个种源黑果枸杞一年生苗的生理响应研究
# 模拟增温和减雨对中亚热带常绿阔叶林凋落物分解的影响
# 安宁河干旱河谷区云南松林水源涵养功能对林分密度的响应
# 安宁河流域火烧迹地土壤水文特征与抗蚀性研究
# 安宁河流域不同林型土壤团聚体稳定性研究
# 桉树纯林及混交林土壤团聚体碳氮磷组分分布特征
# An error occurred
# 马尾松-格木人工混交林与纯林土壤有机碳的铁铝氧化物固持及矿化特征
# 杉木人工林近自然化改造对土壤团聚体稳定性及磷组分的影响
# 引入固氮树种对桉树人工林土壤团聚体稳定性及其养分的影响
# 固氮树种及种植模式对石漠化区土壤团聚体稳定性的影响及调控机制
# 短轮伐期桉树人工林土壤基质入渗与优先流的定量研究
# 引入阔叶树种混交改造对马尾松人工林土壤P组分及其转化的影响
# 短轮伐期桉树人工林土壤入渗及氮素淋失特征研究
# 湘南莽山土壤性质垂直分异与系统分类
# 湖南岩溶土壤剖面形态发育评价与系统分类研究
# 芦荻生物炭基肥的研制及其阻控水稻土氮磷损失的效应研究
# 地肤对土壤重金属Cd污染的修复效果与机理
# 土壤调理剂对湘南双季稻产量构成与米质及养分利用的影响
# 土壤调理剂对双季稻镉积累的影响及其与叶面阻控剂的协同效应
# 钩吻生物碱在蜂蜜和土壤中的二维液相色谱方法研究
# 基于生物质炭的土壤改良剂对砂质土壤的改良效益研究
# 政府补贴与企业创新——基于地理信息产业的实证研究
# An error occurred when close window
# An error occurred when close window
# 0 3080
# 0 0
# list index out of range
# 0 3080
# 0 0
# list index out of range
# 0 3080
# 0 0
# list index out of range
# 0 3080
# 0 243
# year month has pdfs:4296
# 电力网络多尺度几何语义建模及可视化应用研究
# 漓江流域“三生”功能时空演变特征及分区优化策略
# 基于最佳距离衰减系数的空间同位模式挖掘方法研究
# 基于线性最大熵原理的空间数据内插建模研究
# 基于模式累积的在线路网轨迹压缩方法研究
# 基于时空LightGBM模型的中国碳排放预测
# 基于多层感知机的大场景点云分类方法研究
# 融合高分辨率遥感与开放地理数据的城市功能区识别方法
# 基于手机传感器流数据的路面非平稳地物特征检测方法研究
# 基于POI和轨迹大数据的城市商业与居住空间静态匹配与动态关联研究——以上海市为例
# An error occurred
# 基于POI数据的呼和浩特市中心城区零售业空间分布特征分析
# 浊漳河流域仰韶至商时期遗址分布及其与自然环境关系研究
# 基于时空大数据平台的BIM应用技术研究
# 黄河下游滩区土地利用/覆被变化（1985-2025年）数据集研制及其时空变化特征分析
# 基于空间多尺度统计模型的居民福祉研究——以郑州市为例
# An error occurred
# 基于随机森林和关键地表参数的秦巴山地山体效应定量化研究
# An error occurred
# 基于多源数据的街道空间城市活力感知与影响因素分析
# 黄河流域土地利用变化对地表能量收支平衡的影响
# 基于精细化建模的居民居住碳排放空间模式研究
# 伏牛山地区生态系统生产总值核算与时空格局演化
# An error occurred when close window
# 开封中心城区商业网点时空格局及优化研究
# 基于图卷积神经网络的居民地空间分布模式分析
# 基于多源数据对城市高活力街道的识别研究——以海口市为例
# Z信息集团竞争力提升研究
# 三维探地雷达数据与地理信息系统的融合研究
# 安宁河流域土石围栏空间分异规律及其影响因素研究
# 三维智慧社区基础地理框架快速搭建方法研究
# 地方意义视角下旅游地社区居民空间认知研究
# 基于LADM的三维地籍数据库概念模型构建
# ...
# 湍动磁场的测量和粒子加速
# 梯形空腔内非牛顿流体流动及混溶数值模拟
# An error occurred
# 甲烷/气相助燃剂燃爆特性及其燃爆致裂页岩的机理研究
# 爆炸场景数字建模与数值仿真研究
# An error occurred
# 西宁市黄土物理力学性质指标的统计分析与BP神经网络预测
# 界面反散射问题的机器学习算法研究
# An error occurred
# Einstein-Aether理论中的3维最大对称解
# 带有角点弹性介质散射体的可见性
# An error occurred
# 角点处的弹性无辐射源与传输特征值问题的局部几何结构及其应用
# 基于引力波事件观测的额外维理论中测地线问题研究
# 噪声系统中干涉仪的多参量估值研究
# 基于量子理论的支付协议设计
# An error occurred
# 量子测量中的相关问题研究
# 多体量子系统纠缠的单配性关系
# An error occurred
# 非线性操作下的连续变量纠缠及水下密钥分发的研究
# 基于线性器件的量子纠缠及改善研究
# 基于直方图的量子图像增强算法研究
# An error occurred
# 基于量子计算的哈希函数和布尔函数研究
# 量子图像滤波方法研究
# 表面等离激元中基于流体模型的量子效应研究
# 0 5576
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 带杀M/M/1模型的拟平稳分布及吸引域研究
# 波热耦合问题的优化施瓦兹波形松弛方法
# 声弹耦合传输特征值问题的谱分析
# 带组合外力项的零压气体动力系统的黎曼问题
# 激波诱导百微米液滴变形破碎实验和数值研究
# 混合不确定性下机翼气动性能CFD模拟评估与灵敏度分析方法研究
# 点阵夹芯结构气动弹性能量采集
# V形钝前缘激波干扰非定常特性与波系调控
# 高超音速飞行器气动热计算与热防护数值模拟的研究
# An error occurred
# 低温氮气跨声速膨胀过冷凝结特性研究
# 仿蒲公英飞行器气动外形优化研究
# 直升机声探测数据采集处理系统的设计与实现
# 基于多任务学习的大差异性空气动力学数据建模方法研究
# 低速风洞优化设计及其在航空发动机变形齿流场分析中的应用
# 粗糙壁面条件下振动Rayleigh-Bénard对流的传热及耗散特性研究
# 圆柱绕流流场涡旋影响混凝粘附的机制
# 弱胶结裂隙岩体渗流侵蚀特性研究
# 水流作用下旋转钻柱的流致振动特性研究
# 微细颗粒-气泡在湍流场中的脱附行为及微细矿物分选选择性强化
# 乌式毛细管黏度计自动检定系统研究
# An error occurred when close window
# 基于量子机器学习的分类算法与应用研究
# An error occurred
# 机械谐振器与固态色心的耦合研究
# 反宇称时间对称高阶例外点的电路实现
# 基于量子计算的核管道故障诊断技术研究
# 基于格上困难问题的两类密码方案研究
# 基于量子蒙特卡洛算法的欧式期权定价
# 多域量子密钥分发网络生存性技术研究
# 量子密钥协商协议的参与者攻击研究
# 基于机器学习的量子密钥分发网络系统的参数优化
# 广义三粒子纠缠态的多方EPR导引
# 受控量子安全直接通信的控制力的研究
# 量子系统中信息加扰和恢复研究
# 基于金刚石NV色心的量子编码与量子计算
# 测量设备无关量子密钥分发协议的研究
# 连续变量量子密钥分发高维协商算法研究
# 集成量子密钥分发的光接入网中的同步技术研究
# 内嵌量子密钥服务的物联网边缘侧密钥资源分配策略研究
# 面向数据中心的量子密钥分发策略研究
# 基于贝尔非定域性的量子资源验证方案
# 面向量子信号和经典信号联合规划的空频资源分配技术研究
# An error occurred when close window
# 0 5616
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 四阶部分对称张量M-特征值的包含定理及其应用
# 一类特殊的Yangian实现及其在量子纠缠态跃迁中的应用
# 利用周期性泵浦耗散制备里德堡原子最大纠缠态
# 准周期势的Haldane-Shastry模型的多体局域化性质
# 借助频率调制生成两原子系综量子纠缠态
# 基于周期驱动的手性流算符量子模拟研究
# 弱耦合到腔磁系统中驱动三能级原子的色散读出
# 熵不确定关系及其意义
# An error occurred
# 选择性里德堡泵浦机制中的非绝热和乐量子计算
# 准周期势的一维海森堡模型的多体局域化性质
# An error occurred
# 利用非高斯态改善线性干涉仪的测量精度
# 基于非高斯操作的SU(1,1)干涉仪的量子相位评估
# An error occurred
# 一类具有近共振控制的（N+1）-能级系统的重整化群近似解
# An error occurred
# 基于半监督机器学习的量子关联分类研究
# 辅助驱动盲量子计算协议及其验证性研究
# 用户资源受限的安全多方量子计算专用协议研究
# An error occurred
# 量子信息技术在区块链中的应用研究
# 引力量子性对小质量系统量子态动力学的影响
# PT对称非厄米耦合量子系统非经典效应和输运性质的研究
# 耦合量子点输运体系随机热力学的全计数统计研究
# An error occurred when close window
# 粒子非平衡输运的统计理论研究
# 静电场作用下单相电介质系统的热力学特征
# 级联模型下的量子热力学相关问题研究
# An error occurred
# 基于储备池计算的混沌相位同步预测
# 忆阻混沌系统及其在图像加密中的应用研究
# An error occurred
# 新型四翼混沌系统及其图像加密应用
# An error occurred
# 神经网络在电磁辐射下的混沌同步
# 基于混沌与DNA编码的图像加密算法研究
# 基于离散混沌映射的图像加密算法研究
# 混沌系统的状态观测器同步及其在遮掩通信中的应用研究
# An error occurred
# 基于非线性反馈同步的混沌加密系统设计及FPGA实现
# 基于混沌映射和压缩感知的图像加密的研究
# An error occurred
# 广义同步与混沌遮掩保密通信研究
# 分数阶保守混沌系统的构建及动力学特性分析
# 基于超混沌系统与压缩感知的图像加密算法研究
# 无简并多维超混沌映射的构建及其在密码学中的应用研究
# 混沌映射的构建及其在密码算法中的应用
# An error occurred
# 基于超混沌的高非线性度强S盒的构建及应用研究
# An error occurred
# 随机神经网络的同步控制及其在混沌加解密中的应用
# 利用储备池计算实现双稳态下的动力学重构
# An error occurred when close window
# 0 5656
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5656
# 0 0
# list index out of range
# 0 5656
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 非全同洛伦兹振子的同步和振幅死亡
# 一维双激转子系统中的加速岛与超扩散
# 基于五维耦合同步混沌系统的数据加密技术研究
# 保守混沌的动力学研究及其FPGA实现
# 基于超混沌系统的图像加密算法研究
# 多时间尺度混沌系统的动力学行为分析
# 具有自激和隐藏吸引子的混沌系统动力学研究
# 基于曲率指数的分数阶混沌系统的研究
# 分数阶多稳态忆阻混沌系统的动力学分析与同步研究
# 基于相位梯度结构的声场调控
# 超声波协同臭氧提质冶炼烟气脱硫产品及机理
# 基于主动声学激励的管道堵塞检测方法研究
# 超声波封边关键技术的研究
# 基于声学远场成像的水下目标识别问题研究
# 超声气体射流辅助飞秒激光刻蚀石英机理与工艺研究
# 圆管水听器灵敏度的温度稳定性分析及校准技术研究
# 超声波激光堆积振动装置的研制及实验研究
# 二维声学黑洞板的动力学特性研究
# 面向样本偏斜的次声事件分类算法研究与实现
# 基于机器学习的次声事件检测算法的研究与实现
# An error occurred when close window
# 基于机器学习技术的多源数据融合子系统的设计与实现
# An error occurred
# 基于微弱磁通量变化的声检测传感器研究
# 基于改进型深度学习网络的水声信号分类识别方法
# 结合机器听觉的有源噪声控制算法研究
# 矢量水听器阵高分辨率DOA估计算法研究
# 多元浮标阵无线收发系统及其定位解算算法研究
# 船舶水声辐射信号降噪算法和识别技术研究
# 跨座式单轨动力学性能评价指标及车桥耦合振动影响规律分析
# 基于耦合腔互易法的水听器灵敏度低频校准系统研制
# 水声线列阵灵敏度现场校准方法研究
# 频偏应答式ADCP小流速校准方法研究
# 等离激元纳腔结构增强荧光的研究
# 基于SPAD的高灵敏度大动态范围光功率测量系统研究
# 磁场作用下光控磁流体宏观旋转现象的研究
# 光学微腔物理参数的精细调控技术研究
# 基于手性超构表面的高灵敏度开关与传感应用
# 基于神经网络的手性光学材料设技优化及其光学特性分析
# 手性金螺旋体纳米颗粒与激子在强耦合系统下的手性特性
# 基于深度学习的分数阶涡旋光相位恢复
# 基于超表面结构的表面增强拉曼基底研究
# 0 5696
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5696
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 可实现纳米聚焦热点阵列的超构表面设计
# 双拉盖尔-高斯旋转腔光力学系统中涡旋光束非互易性的研究
# 旋向非均匀涡旋光场的调控及其性质研究
# An error occurred
# 基于矢量光场的光学自旋角动量调控
# 基于球心投影设计的庞加莱球矢量光场
# An error occurred
# 等离激元共振光吸收及其光热转化研究
# 基于光波耦合谐振的超表面传感器设计及响应特性研究
# 基于超表面的光学轨道角动量的产生和调控研究
# 基于高斯波束模式分析的紧缩场馈电系统设计方法研究
# 基于超表面的类电磁诱导透明现象及其应用研究
# 基于高Q共振的非线性倍频超构表面
# 直射散射光谱辐射计改进及其定标方法研究
# 基于近红外DFB激光器的乙炔吸收光谱检测技术研究
# An error occurred
# 基于光谱共聚焦的厚度和表面形貌检测技术研究
# HO2自由基反应动力学腔衰荡光谱测量装置研究
# 基于永磁体的法拉第旋转光谱理论仿真研究
# An error occurred
# 基于WFM-DOAS的二氧化碳遥测技术及应用研究
# 远距离脉冲拉曼光谱预处理技术研究与实现
# 基于MAPbX3钙钛矿可调滤光片的计算重构光谱探测器设计
# An error occurred
# 基于多光谱和GAN的伪全光谱生成方法及果品内部品质预测模型的构建
# An error occurred when close window
# An error occurred when close window
# 铯铅溴旋涂薄膜的椭偏光谱分析研究
# 免校准波长调制光谱技术中智能寻优算法的研究
# 基于深度学习的X射线钨矿图像检测方法研究
# X射线探伤图像的焊缝缺陷自动检测与识别方法研究
# X光安检图像违禁品检测方法研究
# X射线能谱CT及图像重建算法研发
# 基于深度学习的X光扫描图像违禁品检测算法研究
# 基于XRF的土壤重金属元素检测分析方法研究
# 条纹相机中X光分析和联合仿真研究
# Sm3+/Cr3+共掺杂GdAlO3 X射线荧光粉的制备与闪烁特性的研究
# 红外偏光晶体氯化亚汞的生长及格兰棱镜的研制
# 中红外RE:(LuxGd1-x)3Ga5O12(RE=Er3+,Dy3+)激光晶体生长及性能研究
# 不同曲率基材表面上光子晶体的喷涂法制备及其性能研究
# 基于深度学习的标量和矢量光场透过散射介质的散斑图复原研究
# 光子晶体中拓扑界面态传输性质的研究
# 掺金光子晶体水凝胶的制备及刺激响应性研究
# 低角度依赖性1D光子晶体膜的制备与性能研究
# 基于光子纳米链的响应性光子晶体膜的制备及性能研究
# 基于深度学习的可拓展散斑相关成像
# 基于矢量光束的水下主动偏振成像理论及实验研究
# An error occurred when close window
# 0 5736
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 量子点与等离激元在中等耦合区杂化的高偏振光发射
# 锰激活的长余辉钙钛矿晶体的光学性质
# 衍射图像的非均匀特性与去模糊算法研究
# 经过散射介质的光场反演技术及其应用研究
# 基于双光子聚合的激光直写技术在亚波长光栅制备中的应用
# 激光直写衍射光学元件的设计与工艺研究
# 光子晶体中连续域束缚态的数值计算
# 环形色散介质光子晶体的数值计算方法及性质
# 钇钡铜氧超导网状材料中光子局域化增强的数值研究
# 银纳米线的手性传播特性和光子晶体的定向传输研究
# 超高品质氟化物光学晶体微盘腔研制
# 基于硅基光子晶体微腔的多纳米粒子光学捕获研究及其性能分析
# 基于光腔衰荡技术的光学元件表面散射测量
# 波前数字处理的超衍射角分辨望远技术研究
# 基于深度学习的涡旋光湍流相位畸变矫正
# 基于神经网络的目标与粗糙面复合散射快速建模方法
# 强散射介质中基于反射矩阵法的光学相干层析成像技术研究
# 基于液晶器件的偏振成像系统及其应用
# An error occurred
# 光子晶体中连续域束缚态的调控及涡旋的产生
# 基于深度学习偏振图像融合的金属工业件检测
# An error occurred when close window
# 基于偏振成像的水上航行场景图像语义分割方法研究
# 几种有机-无机杂化非线性光学晶体的制备及性能研究
# 高功率光子晶体激光巴条的热特性及可靠性分析
# 高功率光子晶体激光单管热特性及封装测试研究
# 间接耦合光子晶体纳米梁腔系统中模式分裂的调控研究
# 基于大错位方法的锥形光纤微腔应变传感器
# 基于三角形谐振腔的微纳结构器件研究
# 基于超冷铒原子的双波长激光光纤相位噪声抑制
# 基于SPR的液晶填充型微结构光纤折射率及温度传感特性研究
# An error occurred
# 基于Fano共振的全光双稳态研究及可调光纤延迟线设计
# 等离激元高Q共振微结构设计及其光谱特性研究
# 基于微纳光纤布拉格光栅的磁场和全光调谐特性研究
# 低损耗空芯反谐振光纤的设计与研究
# 基于相移光纤光栅的光电振荡器温度特性与稳定方法研究
# An error occurred
# 双合透镜与热扩芯光纤的离轴旋转连接器特性研究
# An error occurred
# 基于迭代的高质量纯相位全息图生成算法
# 光纤宏弯低频振动传感器研究
# 光纤F-P腔非对称光谱的调控及应用
# 化学腐蚀法制作单光纤探针对多微粒的捕获
# 光纤In-Line MZI的模式差异研究及其游标增敏传感应用
# An error occurred
# An error occurred when close window
# 0 5776
# 0 243
# year month has pdfs:4296
# list index out of range
# 0 5776
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5776
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5776
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5776
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 手性耦合环芯光纤中光轨道角动量传输和光偏振态演变的研究
# 基于表面等离子体共振的光子晶体光纤传感器研究
# 光导系统中塑料光纤光泄露定量化研究
# 热光波导开关设计及驱动优化技术研究
# 基于连续光纤激光光腔衰荡的光学元件损耗测量技术
# 基于双模光波导干涉仪的液体折射率传感器研究
# 大功率太赫兹光波导探测器的研究
# 光波导探测器太赫兹匹配技术研究
# 薄膜铌酸锂光波导射频信号接收器研究
# 少模光纤信道的矢量模串扰分析及噪声抑制技术研究
# 负曲率反共振空芯光纤的抗弯曲设计方法研究
# MEMS IMU/里程计融合的管线仪精密定位方法研究
# 光波导探测器微波发射电路研究
# 集成光学可变光延迟技术研究
# 基于硅基高非线性光纤2-3微米平坦型超连续谱的研究
# 基于多模波导的电场测量技术研究
# 光纤陀螺温漂高精度矫正方法研究
# 液晶填充的双芯光子晶体光纤偏振分束器设计
# 新型微结构光纤偏振分束器和传感器的研究
# 基于微纳器件逆设计的仿真加速技术研究
# An error occurred when close window
# 光学超表面光场相位调控及光束操控器件研究
# An error occurred
# 基于深度学习的多模光纤图像传输研究
# 镱铝氟石英光纤结构设计及光学性质研究
# 基于锁模激光器的全光纤高精度时频传递
# 三包层高非线性光子晶体光纤设计及多峰布里渊散射谱特性研究
# 分布式光器件智能设计云平台的研究与实现
# 基于氮化硅的光学相控阵关键器件智能设计
# 面向5G前传网络的可调谐单纤双向光器件设计及优化
# 基于光纤的光子纳米射流器件研究
# 基于各向异性结构的多功能平面器件设计
# 二维过渡金属碳氮化合物非线性光学性质研究
# 神光-ⅡU装置的背向受激布里渊散射角分辨诊断系统研制
# An error occurred
# 第Ⅳ主族元素二维材料的制备及其非线性光学研究
# 回音壁模式微腔的制备及其克尔光频梳的产生机理研究
# 非线性波导中高相干超连续谱产生的研究
# 新型苯并噻唑盐有机非线性光学材料的设计与制备研究
# 修饰开笼富勒烯构造新奇分子的结构和性质理论研究
# 非线性介质中的非互易光力二阶边带
# 基于面元法的计算全息动态计算及显示
# An error occurred
# 基于面元法的计算全息算法及成像质量的研究
# 0 5816
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 基于红外数字全息过烟雾场重建像增强研究
# 高分辨率像面全息图打印方法研究
# 基于深度学习的近眼全息计算算法研究
# 亚毫米精度实用型单光子测距技术研究
# 基于双电光频率梳的测距测速技术研究
# An error occurred
# 基于电光调制的双光梳成像技术应用研究
# 低成本数字全息三维形变场检测系统研究
# 基于条纹投影的高反光物体三维测量方法研究
# 正弦结构光投影测量系统的关键技术研究
# An error occurred
# 不同气氛环境下有机物的激光诱导击穿光谱特性研究
# An error occurred
# 基于精密扭秤技术的纳瓦光压测量实验
# 超快强激光脉冲驱动的原子电离特性研究
# 基于改进ICP算法的光学元件曲面配准方法研究
# An error occurred
# 飞秒激光诱导液线辐射太赫兹波的介质特性研究
# 基于正弦相位调制激光干涉仪的齿轮减速箱故障诊断技术研究
# 基于大扫频范围和目标漂移补偿的激光频率扫描干涉法绝对测距研究
# An error occurred
# 便携式空间频域成像智能一体机开发与应用研究
# 基于二维激光SLAM的AGV导航系统设计
# An error occurred
# 基于结构光的管道内表面缺陷检测技术研究
# 倒车摄像头激光焊接压力优化控制与系统设计
# An error occurred when close window
# An error occurred when close window
# 土壤重金属遥测仪无人载台地面测试系统设计与实现
# An error occurred
# 基于激光扫频干涉非线性校正方法研究
# 基于线激光扫描的基准孔检测与边缘偏差修正方法
# 基于深度学习的光学滤光片表面缺陷检测研究
# 基于激光视觉传感的焊缝自动跟踪方法及系统研究
# 基于激光扫描的焊缝坡口三维建模与特征提取研究
# 脉冲激光沉积TiO2等离子体状态诊断及薄膜特性的研究
# 基于树莓派与LIF技术的矿井水源识别系统设计
# 三维激光扫描技术在钢结构检测中的研究与应用
# 基于三维激光扫描技术的隧道渗漏水检测及裂缝识别
# 基于图像处理的激光熔覆熔池宽度闭环控制研究
# 基于光栅相移的轻离轴数字全息技术研究
# 基于飞秒激光双光子聚合的刺激响应结构色加工与应用
# 激光系统出光特性直接测量装置标定技术研究
# 基于遗传算法的稳态光场优化设计方法研究
# 基于像差补偿网络的光学系统研究
# 弯曲应力对光纤激光损伤阈值的影响研究
# 基于测量驱动的鬼成像方法研究
# 基于投影阵列的三维光场重构算法研究与优化
# 稀疏矩阵乘法的光学实现及应用研究
# An error occurred when close window
# 0 5856
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 基于相干光源的光子辅助射频滤波器研究
# 基于区域块扫描的水下蓝绿激光成像技术研究
# 基于激光扫描的三维表面重建技术研究
# An error occurred
# 面向不完美通用多端口干涉仪的快速可重构研究
# BIG磁光单晶薄膜的抗激光损伤特性研究
# An error occurred
# 基于激光测振的光声缺陷检测技术研究
# An error occurred
# 基于模仿学习的光学图像小样本分类方法研究
# 光学相干层析三维成像和数据分割技术研究
# 利用液晶透镜光轴移动和液晶光楔光束偏转的深度测量研究
# 液晶微透镜阵列成像的研究
# 激光测距机性能检测技术研究
# 基于超快激光的玻璃三维微结构研究
# An error occurred
# 基于倾斜取向ITO薄膜的激光感生横向电压效应研究
# 基于条纹反射的镜面三维面形动态测量方法研究
# FMCW激光测距信号处理技术研究与实现
# An error occurred
# 二维材料表面等离激元光力增强的数值计算研究
# 显微LIBS技术对敦煌壁画颜料层分析的烧蚀损伤研究
# 面向色彩再现的光谱反射率重建算法的研究
# 基于深度学习的高分辨率光声成像研究
# 基于深度学习的扩展双光子成像视场研究
# An error occurred when close window
# An error occurred when close window
# 基于FPGA的半导体光源驱动与调制
# 基于PSpice的双量子阱半导体激光器等效电路的建模与仿真
# 2.79μm中红外固体激光器
# An error occurred
# (Sm3+,Tb3+,Eu3+)-Dy3+共掺铝酸盐玻璃的制备及可见光发光性能研究
# 调Q脉冲串激光的产生及调控技术研究
# 具有超晶格电子阻挡层AlGaN基深紫外LD性能研究
# An error occurred
# 定向发射的硅基GaN微环激光器研究
# 非均匀热源下强化表面冲击射流的散热特性研究
# 激光脉冲辐照固体CH材料的离子组分分离研究
# 部分相干光的非线性传输特性研究
# 基于少层PtS2可饱和吸收的光参量振荡优化特性研究
# An error occurred
# 基于声光调制的纳秒级中红外光学参量振荡输出特性研究
# 高功率高偏振度792nm合束半导体激光器研制
# 准连续激光放大及其频率转换特性研究
# An error occurred
# 钕镁双掺铌酸锂晶体及自光参量振荡应用研究
# 基横模650nm红光半导体激光芯片的研制
# 基于2微米飞秒激光泵浦非线性光纤的中红外级联拉曼孤子自频移研究
# An error occurred
# 光学频率梳产生及应用研究
# 宽带可调谐双波长激光源关键技术研究
# 基于光热偏转技术的Nd：YAG板条缺陷检测研究
# An error occurred when close window
# 0 5896
# 0 243
# year month has pdfs:4296
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5896
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5896
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# ～2 μm全光纤啁啾脉冲放大及光参量振荡技术研究
# 高性能760 nm垂直腔面发射激光器的研究与设计
# 功能化锁模光纤激光频梳和正时技术研究
# 基于液晶移相体制的亚毫秒光束控制方法研究
# 原子陀螺仪气室高精度温控技术研究
# 基于连续光声谱系统的血清溶液中葡萄糖浓度预测关键技术研究
# 基于9字腔和哑铃形腔的锁模光纤激光器研究
# 自注入锁定窄线宽激光器的关键技术研究
# 纳秒掺铥光纤激光器的高效放大及其应用研究
# 高性能光频梳及微波频梳产生技术研究
# 3.5μm掺铒光纤激光器及其脉冲输出特性的基础研究
# 高功率宽带随机光纤激光光源及其传感应用
# 超长拉曼光纤激光器设计与实现
# 基于随机分布反馈的可调谐窄线宽光纤激光器研究
# 散射辅助的光纤型微腔激光研究
# 强激光打靶产生电磁脉冲的机理研究及屏蔽设计
# 基于高熵范德瓦尔斯材料的光纤激光器非线性动力学研究
# 基于高损伤阈值可饱和吸收体激光器的设计
# 相位型激光测距单元设计
# 全保偏波长可调谐飞秒掺镱光纤激光器研究
# An error occurred when close window
# An error occurred when close window
# 1.3μm硅基量子点分布反馈激光器设计研究
# 非线性脉冲动力学及饱和吸收体锁模光纤激光器的特性研究
# An error occurred
# 超构表面的饱和吸收特性研究及其在锁模和调Q光纤激光器中的应用
# 硅基GaAs系激光器材料分子束外延和位错疏导结构研究
# 面发射激光器阵列光注入锁定研究
# 低微分电阻硅基外延Ⅲ-Ⅴ族激光器芯片结构设计与制备
# An error occurred
# 时空锁模光纤激光器动态过程研究
# 被动锁模自相似掺铒氟化物光纤激光器理论研究
# 2μm大功率超快光纤激光器的研究
# 自由曲面光学天线设计及其传输特性研究
# 10A极窄脉冲电流产生模块设计与实现
# 光纤随机激光脉冲机制研究
# 基于压敏光纤微谐振腔的正交偏振双克尔孤子频梳研究
# 超长腔锁模掺铒光纤激光器研究
# 基于深度学习的同轴封装金属底座缺陷检测研究
# 基于量子级联激光器的多气体检测技术研究
# 基于腔内倍频的大功率绿光激光器研究
# 湿法氧化及高功率高效率940 nm垂直腔面发射激光器研究
# 半导体激光芯片封装热应力研究
# 基于表面狭槽结构的主动传感机制研究
# 0 5936
# 0 0
# list index out of range
# 0 5936
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5936
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5936
# 0 243
# year month has pdfs:4296
# list index out of range
# 0 5936
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5936
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5936
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5936
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 高亮度半导体激光合束技术研究
# 大功率激光芯片载流子注入调控
# 基于高浓度掺铒光纤的锁模激光器研究
# 超高斯光场调控超冷原子动力学的研究
# Feshbach共振调控的光晶格束缚玻色-爱因斯坦凝聚体的局域场效应
# 退局域光子增加操作前后光场态的属性研究
# 基于光子/声子阻塞效应制备反聚束量子光/声源
# 量子系统的相干反馈控制及其应用
# 横向驱动下光腔内BEC的动力学
# 双驱动腔磁力学系统中声子激光的产生与调控
# 基于人工等离激元结构的量子光源调控
# 基于非相干泵浦辅助的完美非对称非厄密光学衍射
# 耦合腔光力系统中的振子和原子同步及其非线性效应
# 耦合超导波导中动态Casimir光子的多体EPR导引和单配性关系
# 有限温度下动态Casimir链中EPR导引的研究
# 耦合光力学系统中的随机共振和混沌
# GaAs量子点EIT介质中光孤子存储与读取的调幅研究
# 任意单光子多模W态的统一制备和快速发射研究
# 典型共晶含能材料的太赫兹光谱及温度特性研究
# 柔性碳基电磁屏蔽材料的制备与性能研究
# An error occurred when close window
# 电磁脉冲场对针-板电极静电放电等离子体环境的影响研究
# 强电磁场诱发空间装备静电放电试验系统设计与研究
# 基于物联网技术的人体静电姿态采集系统的设计与实现
# 基于表面等离激元的窄带光吸收及其传感特性研究
# An error occurred
# 基于石墨烯超材料的光谱特性与应用研究
# 基于等离激元共振的完美光吸收超材料的构建及其应用研究
# 基于连续域束缚态和相变材料GST的可调谐超表面研究
# 基于FDTD算法的平面微带结构的仿真与研究
# An error occurred
# 基于InSb超材料的太赫兹电磁波吸收特性研究
# 基于可编程超表面的波束分离器设计
# 基于SoC的海上电磁频谱感知软件设计
# 基于人工表面等离子元的缺陷地及传输线研究
# 基于石墨烯的太赫兹超表面器件设计及其调制特性研究
# 黑磷和石墨烯等离激元特性研究
# 基于VO2超表面的太赫兹波主动调控机理研究
# 磁场调控人工表面等离激元非互易传输特性研究
# 基于Massive MIMO的太赫兹通信定位一体化技术研究
# 焊缝三维应力场的电磁检测技术研究
# An error occurred
# 宽带可重构吸透一体超材料研究
# 基于超表面的电波调控与功能器件设计
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 0
# list index out of range
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 5976
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 基于石墨烯表面等离激元的可调谐太赫兹吸收器研究
# 基于MIM波导的深亚波长尺寸器件的设计研究
# 煤岩混合介质的太赫兹检测技术研究
# 电导率涡流测量方法及仪器开发研究
# 基于太赫兹技术的热障涂层脱粘缺陷识别方法研究
# 基于电磁超材料的低频宽带吸波体研究
# 宽角度多波束传输阵列及涡旋电磁波产生研究
# 基于环形偶极谐振的太赫兹全介质超表面传感方法研究
# 应用磁通聚集调制方法的氮-空位色心系综磁测量技术研究
# 物联网用磁电天线设计与制备
# 基于PVD/CVD法制备石墨烯及石墨烯太赫兹器件研究
# 考虑霾电性质影响的电磁波衰减模型及其在霾预警方面的应用
# 适配绝缘空间电荷椭偏测量的太赫兹激励发生方法与等效性研究
# 低复杂度太赫兹基带信号处理方法研究
# 有源智能反射表面关键技术研究
# 20Gbps太赫兹无线数据传输关键技术与验证
# 复杂电磁环境下信号全概率感知技术的研究
# 基于交替方向乘子法的分布式电磁目标识别
# 基于电磁透镜的波束方向估计技术研究与实现算法设计
# 基于数值模拟的肿瘤治疗电场作用机制研究
# An error occurred when close window
# An error occurred when close window
# 晶体结构对二维太赫兹超材料各向异性影响的研究
# 基于超薄人工材料的柔性宽带太赫兹吸收器
# K波段宽带可重构超表面设计及应用研究
# An error occurred
# 基于多层人工微结构的太赫兹动态调控器件
# 基于平面传输线的太赫兹移相器研究
# 太赫兹片上化相位调控机理的基础研究
# An error occurred
# 基于太赫兹成像的无损检测技术研究
# 基于深度学习的太赫兹超表面按需设计
# 基于双频编码调控的多功能智能电磁表面
# 基于相控单元特性提取的毫米波编码电磁表面研究
# 基于SuperLU的二维静电粒子模拟方法研究
# 基于新型二维拓扑材料的太赫兹光电探测器
# NiTe2和GeSn的时间分辨太赫兹光谱研究
# 自适应网格技术在计算电磁学中的研究及应用
# 320GHz全双工高速通信系统前端关键器件研究
# 基于广义薄片传输条件的天线—超表面设计方法研究
# 太赫兹自旋波频率梳
# 基于EMLAB的后处理研究与软件验证
# 基于高频方法的涡旋电磁波目标散射特性研究
# TDFIT电磁算法的异构并行与仿真应用
# 0 6016
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 6016
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 6016
# 0 0
# list index out of range
# 0 6016
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 6016
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 6016
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 6016
# 0 243
# year month has pdfs:0
# 'NoneType' object has no attribute 'find_elements'
# 0 6016
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 晶体结构对二维太赫兹超材料各向异性影响的研究
# 基于超薄人工材料的柔性宽带太赫兹吸收器
# K波段宽带可重构超表面设计及应用研究
# 基于多层人工微结构的太赫兹动态调控器件
# 基于平面传输线的太赫兹移相器研究
# 太赫兹片上化相位调控机理的基础研究
# 基于太赫兹成像的无损检测技术研究
# 基于深度学习的太赫兹超表面按需设计
# 基于双频编码调控的多功能智能电磁表面
# 基于相控单元特性提取的毫米波编码电磁表面研究
# 基于SuperLU的二维静电粒子模拟方法研究
# 基于新型二维拓扑材料的太赫兹光电探测器
# NiTe2和GeSn的时间分辨太赫兹光谱研究
# 自适应网格技术在计算电磁学中的研究及应用
# 320GHz全双工高速通信系统前端关键器件研究
# 基于广义薄片传输条件的天线—超表面设计方法研究
# 太赫兹自旋波频率梳
# 基于EMLAB的后处理研究与软件验证
# 基于高频方法的涡旋电磁波目标散射特性研究
# TDFIT电磁算法的异构并行与仿真应用
# An error occurred when close window
# An error occurred when close window
# 基于机器学习和优化算法的连续域束缚态超构表面设计研究
# An error occurred
# 新型太赫兹介质超表面器件设计
# 基于石墨烯复合结构的极化可重构太赫兹天线的研究
# 非侵入式生物体内电磁聚焦关键技术研究
# 面向星间太赫兹通信的高效窄波束传输方法研究
# 基于全介质超表面多Fano共振的特性及其应用研究
# 基于超表面的多重Fano共振及其传感特性研究
# 基于表面等离激元的近中红外超材料吸收器设计及研究
# 微纳超表面的传输特性及其传感应用研究
# 基于石墨烯的可切换太赫兹极化转换器的研究
# 基于神经网络的三维介质数值格林函数的计算
# 应用于天线罩的电磁隐身超材料理论与设计方法研究
# An error occurred
# 适用于G波段带状注行波管的多级降压收集极
# TDFIT算法高精度边界模拟关键技术研究
# 平面薄介质结构电磁散射计算方法的研究与应用
# 复杂阵列天线电磁辐射/散射高效建模方法研究
# 太赫兹电真空器件大功率宽带输能系统研究
# D波段辐射计前端研究
# An error occurred
# 应用于微波生物学效应实验的X/Ka/W波段辐射源研究
# 基于OFDM的太赫兹高速实时通信系统及相关调制器件的研究
# 0 6056
# 0 243
# year month has pdfs:4296
# year month has pdfs:4750
# 量子点与等离激元在中等耦合区杂化的高偏振光发射
# 太赫兹波输能窗研究
# 220GHz三次谐波混频技术研究
# 碱金属原子磁力仪控制方法研究
# 基于InP DHBT工艺的太赫兹功率放大器研究
# 基于二维碲基材料的太赫兹探测器的设计与制备
# 基于水下主动和被动电场的探测定位方法优化研究
# 磁异常信号的特征分析与抑噪方法研究
# 基于SIW和超材料的宽带Vivaldi天线及其紧耦合阵列的研究
# 基于里德堡原子的电场测量关键技术
# 太赫兹成像仿真技术研究及计算软件开发
